# %%
import pandas as pd
import numpy as np
import os
print("文件列表：",os.listdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921"))
data = pd.ExcelFile("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/348cases_1921_FS_results.xlsx")#, sheet_name='g1rfegb12'
sheet_names = data.sheet_names
print("列表名：",sheet_names )
# Out:
# 文件列表： ['348cases_1921_FS_results.xlsx', 'FINAL3CENTER349_COMBAT1921.csv', 'FS-RFE', 'FUSCC-zscore-MI.csv', 'FUSCC.csv', 'hrfs', 'hrfs_clinic', 'HRFS_CLINIC_FS', 'HRFS_FS', 'internaltest.csv', 'internaltest1921new.csv', 'internaltest1921new_zscore-MI.csv', 'internaltest1921new_zscore.csv', 'internaltest_fe.csv', 'internaltest_label.csv', 'MIzsore1921-new20231.csv', 'new2023', 'raw', 'RFselect1921-auc-MI2023.csv', 'testrj.csv', 'testrj1921new.csv', 'testrj1921new_zscore.csv', 'testxk.csv', 'testxk1921new.csv', 'testxk1921new_zscore.csv', 'train.csv', 'train1921new.csv', 'train1921newZscore-MI.csv', 'train1921new_zscore1.csv', 'trainZscore-MI-SBS-LGB2023.csv', 'trainZscore-MI-SBS-LR2023.csv', 'trainZscore-MI-SBS-RF2023.csv', 'trainZscore-MI-SBS-XGB2023.csv', 'trainZscore-MI-SFS-LR2023.csv', 'trainZscore-MI-SFS-RF2023.csv', 'trainZscore-MI-SFS-XGB2023.csv', 'train_fe.csv', 'train_label.csv', 'XtrainZscore-MI-RFE.csv', '~$348cases_1921_FS_results.xlsx']
# 列表名： ['preprossess', 'MI', 'mrmr50', 'LASSO', 'RFE-LIGBTGBM', 'RFE-XGB10', 'RFE-RF', 'RFE-LR', 'SFS-LIGHTGBM', 'SFS-XGB', 'SFS-RF', 'SFS-LR', 'SBS-LIGHTGBM', 'SBS-XGB', 'SBS-RF', 'SBS-LR', 'MI2', 'MRMR50-1', 'RFE-NGB19', 'RFE-CGB14', 'RFE-GB25', 'RFE-XGB27', 'RFE-XGB4', 'RFE-DT7', 'RFE-ADB25', 'LASSO20', 'RF30', 'RF20', 'RFE-Ridge', 'RF2-20']

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test_label.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
name = 'RF30'
data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/348cases_1921_FS_results.xlsx", sheet_name=name)

data.keys()
train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/FUSCC-zscore-MI.csv")
test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxk1921new_zscore.csv")
test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj1921new_zscore.csv")
train=train[data.keys()]
train.shape
test=test[data.keys()]
test.shape
test1=test1[data.keys()]
test1.shape

train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/trainZscore-RF30.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF11.csv",index=None)


# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF19.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF5.csv",index=None)
test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testxkZscore-RF30.csv",index=None)


# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testrjZscore-RF30.csv",index=None)

# %%
test.shape
# Out:
# (63, 31)

# %%
test1.shape
# Out:
# (46, 31)

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxkraw-fs-preprosess.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj-fs-preprosess.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# # data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
# data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/EGFR1921-767cases-FS-results.xlsx", sheet_name='RFERF19')
# data.keys()
# train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore.csv")
# test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxk1921new_zscore.csv")
# test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj1921new_zscore.csv")
# train=train[data.keys()]
# train.shape
# test=test[data.keys()]
# test.shape
# test1=test1[data.keys()]
# test1.shape

# # train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-1.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF14.csv",index=None)
# # train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-42.csv",index=None)


# # test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-1.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF14.csv",index=None)
# # test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-42.csv",index=None)


# # test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-1.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF14.csv",index=None)
# # test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-42.csv",index=None)

# %%
#%% load liabrary
import os
import numpy as np
import xlrd
import scipy.io as io
import pandas as pd
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFE
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit, train_test_split
from sklearn.linear_model import Lasso, Ridge, LassoCV,LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn import metrics
import itertools
import joblib
from scipy import stats
from sklearn import preprocessing
print("Import library done.\n")
# Out:
# Import library done.

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test_label.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# DIABETES PREDICTION MODEL

# CLASSIFICATION MODELS - HOLDOUT

'''
Steps to follow:
    - Load the saved dataset
    - General View
    - Modeling
        - Base models: LogisticRegression, GaussianNB, KNeighborsClassifier, SVC, MLPClassifier, DecisionTreeClassifier,
                       BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,
                       XGBClassifier, LGBMClassifier, CatBoostClassifier, NGBClassifier
    - Model Evaluation
    - Model Tuning
    - Model Results
'''

# Import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


# Load the preprocessed dataset
# diabetes_preprocessed = pd.read_csv('./diabetes_prepared.csv')

# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-1.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFEGB8.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-42.csv",index=None)

# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rferf17.csv")
# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rfegb5.csv")
diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/trainZscore-RF30.csv")




# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/Results_HRFS01/catboost/train.csv")
df = diabetes_preprocessed.copy()
# df = df.drop(columns="id",axis=1)

## GENERAL VIEW

df.head()
df.shape
df.info()
df.columns
df.index
df.describe([0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 31 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   CT_gradient_firstorder_Maximum                                239 non-null    float64
#  1   CT_wavelet.LLH_glcm_Idmn                                      239 non-null    float64
#  2   PET_wavelet.LHH_ngtdm_Contrast                                239 non-null    float64
#  3   CT_wavelet2.HLH_firstorder_Skewness                           239 non-null    float64
#  4   CT_wavelet.HHH_glcm_Correlation                               239 non-null    float64
#  5   CT_wavelet2.HLH_firstorder_Median                             239 non-null    float64
#  6   PET_wavelet2.HLL_firstorder_Median                            239 non-null    float64
#  7   CT_wavelet.LHH_firstorder_Kurtosis                            239 non-null    float64
#  8   CT_wavelet2.LHL_glcm_ClusterShade                             239 non-null    float64
#  9   PET_wavelet.LHL_glcm_Correlation                              239 non-null    float64
#  10  PET_gradient_firstorder_Skewness                              239 non-null    float64
#  11  PET_wavelet2.LHH_glcm_ClusterShade                            239 non-null    float64
#  12  CT_square_ngtdm_Busyness                                      239 non-null    float64
#  13  PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis                   239 non-null    float64
#  14  CT_log.sigma.1.0.mm.3D_firstorder_10Percentile                239 non-null    float64
#  15  CT_wavelet2.HLL_firstorder_Skewness                           239 non-null    float64
#  16  PET_wavelet.HHH_firstorder_Mean                               239 non-null    float64
#  17  CT_log.sigma.3.0.mm.3D_glcm_Correlation                       239 non-null    float64
#  18  CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniformityNormalized  239 non-null    float64
#  19  CT_wavelet.HHL_glcm_Imc1                                      239 non-null    float64
#  20  PET_lbp.3D.k_firstorder_Maximum                               239 non-null    float64
#  21  PET_lbp.3D.m1_firstorder_Skewness                             239 non-null    float64
#  22  CT_wavelet2.HHH_firstorder_Mean                               239 non-null    float64
#  23  CT_wavelet.HHH_glcm_DifferenceEntropy                         239 non-null    float64
#  24  PET_lbp.3D.m1_firstorder_Kurtosis                             239 non-null    float64
#  25  CT_wavelet.HHL_firstorder_Skewness                            239 non-null    float64
#  26  PET_wavelet.HHL_glszm_SizeZoneNonUniformityNormalized         239 non-null    float64
#  27  CT_wavelet.HHH_glszm_GrayLevelNonUniformity                   239 non-null    float64
#  28  PET_wavelet2.HHH_glszm_SizeZoneNonUniformityNormalized        239 non-null    float64
#  29  CT_gradient_glcm_Imc1                                         239 non-null    float64
#  30  label                                                         239 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 58.0 KB
#                                                      count   mean   std  \
# CT_gradient_firstorder_Maximum                     239.000 -0.000 1.002
# CT_wavelet.LLH_glcm_Idmn                           239.000  0.000 1.002
# PET_wavelet.LHH_ngtdm_Contrast                     239.000  0.000 1.002
# CT_wavelet2.HLH_firstorder_Skewness                239.000  0.000 1.002
# CT_wavelet.HHH_glcm_Correlation                    239.000  0.000 1.002
# CT_wavelet2.HLH_firstorder_Median                  239.000  0.000 1.002
# PET_wavelet2.HLL_firstorder_Median                 239.000  0.000 1.002
# CT_wavelet.LHH_firstorder_Kurtosis                 239.000  0.000 1.002
# CT_wavelet2.LHL_glcm_ClusterShade                  239.000  0.000 1.002
# PET_wavelet.LHL_glcm_Correlation                   239.000 -0.000 1.002
# PET_gradient_firstorder_Skewness                   239.000  0.000 1.002
# PET_wavelet2.LHH_glcm_ClusterShade                 239.000  0.000 1.002
# CT_square_ngtdm_Busyness                           239.000  0.000 1.002
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        239.000 -0.000 1.002
# CT_log.sigma.1.0.mm.3D_firstorder_10Percentile     239.000 -0.000 1.002
# CT_wavelet2.HLL_firstorder_Skewness                239.000  0.000 1.002
# PET_wavelet.HHH_firstorder_Mean                    239.000  0.000 1.002
# CT_log.sigma.3.0.mm.3D_glcm_Correlation            239.000  0.000 1.002
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... 239.000  0.000 1.002
# CT_wavelet.HHL_glcm_Imc1                           239.000  0.000 1.002
# PET_lbp.3D.k_firstorder_Maximum                    239.000 -0.000 1.002
# PET_lbp.3D.m1_firstorder_Skewness                  239.000  0.000 1.002
# CT_wavelet2.HHH_firstorder_Mean                    239.000 -0.000 1.002
# CT_wavelet.HHH_glcm_DifferenceEntropy              239.000  0.000 1.002
# PET_lbp.3D.m1_firstorder_Kurtosis                  239.000 -0.000 1.002
# CT_wavelet.HHL_firstorder_Skewness                 239.000  0.000 1.002
# PET_wavelet.HHL_glszm_SizeZoneNonUniformityNorm... 239.000  0.000 1.002
# CT_wavelet.HHH_glszm_GrayLevelNonUniformity        239.000  0.000 1.002
# PET_wavelet2.HHH_glszm_SizeZoneNonUniformityNor... 239.000  0.000 1.002
# CT_gradient_glcm_Imc1                              239.000 -0.000 1.002
# label                                              239.000  0.552 0.498
#
#                                                       min    10%    25%  \
# CT_gradient_firstorder_Maximum                     -3.506 -1.100 -0.599
# CT_wavelet.LLH_glcm_Idmn                           -4.935 -1.179 -0.416
# PET_wavelet.LHH_ngtdm_Contrast                     -1.083 -0.671 -0.493
# CT_wavelet2.HLH_firstorder_Skewness                -5.429 -0.713 -0.314
# CT_wavelet.HHH_glcm_Correlation                    -5.050 -0.676 -0.260
# CT_wavelet2.HLH_firstorder_Median                  -4.784 -0.994 -0.327
# PET_wavelet2.HLL_firstorder_Median                 -5.788 -0.891 -0.451
# CT_wavelet.LHH_firstorder_Kurtosis                 -1.272 -0.839 -0.610
# CT_wavelet2.LHL_glcm_ClusterShade                  -4.779 -0.511 -0.151
# PET_wavelet.LHL_glcm_Correlation                   -5.288 -1.086 -0.438
# PET_gradient_firstorder_Skewness                   -3.027 -1.237 -0.584
# PET_wavelet2.LHH_glcm_ClusterShade                 -9.158 -0.271 -0.202
# CT_square_ngtdm_Busyness                           -0.720 -0.476 -0.394
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        -1.676 -0.875 -0.665
# CT_log.sigma.1.0.mm.3D_firstorder_10Percentile     -3.033 -1.244 -0.664
# CT_wavelet2.HLL_firstorder_Skewness                -7.404 -0.798 -0.279
# PET_wavelet.HHH_firstorder_Mean                    -5.707 -0.839 -0.344
# CT_log.sigma.3.0.mm.3D_glcm_Correlation            -7.137 -0.894 -0.320
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... -2.364 -1.191 -0.672
# CT_wavelet.HHL_glcm_Imc1                           -6.100 -1.000 -0.193
# PET_lbp.3D.k_firstorder_Maximum                    -2.145 -1.031 -0.677
# PET_lbp.3D.m1_firstorder_Skewness                  -3.072 -1.360 -0.610
# CT_wavelet2.HHH_firstorder_Mean                    -6.523 -0.781 -0.327
# CT_wavelet.HHH_glcm_DifferenceEntropy              -6.379 -0.641 -0.198
# PET_lbp.3D.m1_firstorder_Kurtosis                  -1.722 -1.220 -0.737
# CT_wavelet.HHL_firstorder_Skewness                 -7.632 -0.569 -0.204
# PET_wavelet.HHL_glszm_SizeZoneNonUniformityNorm... -1.933 -1.212 -0.779
# CT_wavelet.HHH_glszm_GrayLevelNonUniformity        -1.011 -1.011 -0.592
# PET_wavelet2.HHH_glszm_SizeZoneNonUniformityNor... -1.578 -1.023 -0.608
# CT_gradient_glcm_Imc1                              -4.699 -1.242 -0.285
# label                                               0.000  0.000  0.000
#
#                                                       50%    75%   90%   95%  \
# CT_gradient_firstorder_Maximum                     -0.020  0.490 1.239 1.671
# CT_wavelet.LLH_glcm_Idmn                            0.175  0.648 0.992 1.151
# PET_wavelet.LHH_ngtdm_Contrast                     -0.219  0.121 0.778 1.490
# CT_wavelet2.HLH_firstorder_Skewness                -0.044  0.244 0.709 1.058
# CT_wavelet.HHH_glcm_Correlation                     0.059  0.335 0.766 1.289
# CT_wavelet2.HLH_firstorder_Median                   0.005  0.381 1.099 1.759
# PET_wavelet2.HLL_firstorder_Median                  0.054  0.514 0.989 1.351
# CT_wavelet.LHH_firstorder_Kurtosis                 -0.291  0.164 1.236 2.125
# CT_wavelet2.LHL_glcm_ClusterShade                  -0.039  0.118 0.411 0.897
# PET_wavelet.LHL_glcm_Correlation                    0.059  0.638 1.121 1.266
# PET_gradient_firstorder_Skewness                    0.021  0.517 1.273 1.630
# PET_wavelet2.LHH_glcm_ClusterShade                 -0.026 -0.006 0.218 0.980
# CT_square_ngtdm_Busyness                           -0.248  0.027 0.729 1.096
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        -0.279  0.337 1.216 2.116
# CT_log.sigma.1.0.mm.3D_firstorder_10Percentile     -0.059  0.673 1.310 1.661
# CT_wavelet2.HLL_firstorder_Skewness                 0.117  0.370 0.859 1.258
# PET_wavelet.HHH_firstorder_Mean                     0.007  0.381 0.804 1.314
# CT_log.sigma.3.0.mm.3D_glcm_Correlation             0.200  0.501 0.874 1.064
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... -0.105  0.622 1.301 1.732
# CT_wavelet.HHL_glcm_Imc1                            0.302  0.582 0.739 0.825
# PET_lbp.3D.k_firstorder_Maximum                    -0.141  0.475 1.359 1.782
# PET_lbp.3D.m1_firstorder_Skewness                   0.113  0.749 1.152 1.376
# CT_wavelet2.HHH_firstorder_Mean                    -0.006  0.297 0.905 1.572
# CT_wavelet.HHH_glcm_DifferenceEntropy               0.059  0.165 0.438 1.360
# PET_lbp.3D.m1_firstorder_Kurtosis                  -0.109  0.617 1.211 1.868
# CT_wavelet.HHL_firstorder_Skewness                  0.025  0.260 0.730 1.300
# PET_wavelet.HHL_glszm_SizeZoneNonUniformityNorm... -0.028  0.671 1.208 1.596
# CT_wavelet.HHH_glszm_GrayLevelNonUniformity        -0.243  0.446 1.403 1.904
# PET_wavelet2.HHH_glszm_SizeZoneNonUniformityNor... -0.145  0.530 0.753 1.153
# CT_gradient_glcm_Imc1                               0.223  0.629 0.965 1.249
# label                                               1.000  1.000 1.000 1.000
#
#                                                      99%    max
# CT_gradient_firstorder_Maximum                     2.555  3.011
# CT_wavelet.LLH_glcm_Idmn                           1.499  1.804
# PET_wavelet.LHH_ngtdm_Contrast                     4.234  9.068
# CT_wavelet2.HLH_firstorder_Skewness                3.663  7.718
# CT_wavelet.HHH_glcm_Correlation                    2.681  4.776
# CT_wavelet2.HLH_firstorder_Median                  2.621  3.452
# PET_wavelet2.HLL_firstorder_Median                 2.510  4.190
# CT_wavelet.LHH_firstorder_Kurtosis                 3.966  4.753
# CT_wavelet2.LHL_glcm_ClusterShade                  2.231 10.966
# PET_wavelet.LHL_glcm_Correlation                   1.894  2.042
# PET_gradient_firstorder_Skewness                   2.538  3.186
# PET_wavelet2.LHH_glcm_ClusterShade                 3.619  6.790
# CT_square_ngtdm_Busyness                           3.015 11.145
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        3.786  4.519
# CT_log.sigma.1.0.mm.3D_firstorder_10Percentile     2.495  3.357
# CT_wavelet2.HLL_firstorder_Skewness                2.400  2.879
# PET_wavelet.HHH_firstorder_Mean                    3.533  4.685
# CT_log.sigma.3.0.mm.3D_glcm_Correlation            1.548  1.696
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... 2.656  3.702
# CT_wavelet.HHL_glcm_Imc1                           0.996  1.112
# PET_lbp.3D.k_firstorder_Maximum                    3.005  4.683
# PET_lbp.3D.m1_firstorder_Skewness                  1.998  2.433
# CT_wavelet2.HHH_firstorder_Mean                    2.465  5.629
# CT_wavelet.HHH_glcm_DifferenceEntropy              3.835  4.808
# PET_lbp.3D.m1_firstorder_Kurtosis                  2.791  3.738
# CT_wavelet.HHL_firstorder_Skewness                 2.850  3.628
# PET_wavelet.HHL_glszm_SizeZoneNonUniformityNorm... 2.219  5.296
# CT_wavelet.HHH_glszm_GrayLevelNonUniformity        3.060  5.651
# PET_wavelet2.HHH_glszm_SizeZoneNonUniformityNor... 4.304  4.304
# CT_gradient_glcm_Imc1                              1.337  1.607
# label                                              1.000  1.000

# %%
# Check for missing values
df.isnull().values.any()
df.isnull().sum().sort_values(ascending=False)
# Out:
# CT_gradient_firstorder_Maximum                                  0
# PET_wavelet.HHH_firstorder_Mean                                 0
# CT_gradient_glcm_Imc1                                           0
# PET_wavelet2.HHH_glszm_SizeZoneNonUniformityNormalized          0
# CT_wavelet.HHH_glszm_GrayLevelNonUniformity                     0
# PET_wavelet.HHL_glszm_SizeZoneNonUniformityNormalized           0
# CT_wavelet.HHL_firstorder_Skewness                              0
# PET_lbp.3D.m1_firstorder_Kurtosis                               0
# CT_wavelet.HHH_glcm_DifferenceEntropy                           0
# CT_wavelet2.HHH_firstorder_Mean                                 0
# PET_lbp.3D.m1_firstorder_Skewness                               0
# PET_lbp.3D.k_firstorder_Maximum                                 0
# CT_wavelet.HHL_glcm_Imc1                                        0
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniformityNormalized    0
# CT_log.sigma.3.0.mm.3D_glcm_Correlation                         0
# CT_wavelet2.HLL_firstorder_Skewness                             0
# CT_wavelet.LLH_glcm_Idmn                                        0
# CT_log.sigma.1.0.mm.3D_firstorder_10Percentile                  0
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis                     0
# CT_square_ngtdm_Busyness                                        0
# PET_wavelet2.LHH_glcm_ClusterShade                              0
# PET_gradient_firstorder_Skewness                                0
# PET_wavelet.LHL_glcm_Correlation                                0
# CT_wavelet2.LHL_glcm_ClusterShade                               0
# CT_wavelet.LHH_firstorder_Kurtosis                              0
# PET_wavelet2.HLL_firstorder_Median                              0
# CT_wavelet2.HLH_firstorder_Median                               0
# CT_wavelet.HHH_glcm_Correlation                                 0
# CT_wavelet2.HLH_firstorder_Skewness                             0
# PET_wavelet.LHH_ngtdm_Contrast                                  0
# label                                                           0
# dtype: int64

# %%
# MODELING


# Define dependent and independent variables
y = df["label"]
X = df.drop(["label"], axis=1)

# y = df["Outcome"]
# X = df.drop(["Outcome"], axis=1)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# See the results for base models

base_models = [('LogisticRegression', LogisticRegression()),
               ('Naive Bayes', GaussianNB()),
               ('KNN', KNeighborsClassifier()),
               ('SVM', SVC()),
               ('ANN', MLPClassifier()),
               ('CART', DecisionTreeClassifier()),
               ('BaggedTrees', BaggingClassifier()),
               ('RF', RandomForestClassifier()),
               ('AdaBoost', AdaBoostClassifier()),
               ('GBM', GradientBoostingClassifier()),
               ("XGBoost", XGBClassifier()),
               ("LightGBM", LGBMClassifier()),
               ("CatBoost", CatBoostClassifier(verbose=False)),
               ("NGBoost", NGBClassifier(verbose=False))]

# %%
evaluate_classification_model_holdout(base_models)
# LogisticRegression: 0.445560
# Naive Bayes: 0.451351
# KNN: 0.466409
# SVM: 0.479151
# ANN: 0.458301
# CART: 0.538610
# BaggedTrees: 0.511583
# RF: 0.496525
# AdaBoost: 0.623552
# GBM: 0.552124
# XGBoost: 0.580695
# LightGBM: 0.567181
# CatBoost: 0.618147
# NGBoost: 0.508494
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.445560
# Naive Bayes: 0.451351
# KNN: 0.466409
# SVM: 0.479151
# ANN: 0.456757
# CART: 0.580695
# BaggedTrees: 0.537838
# RF: 0.552124
# AdaBoost: 0.623552
# GBM: 0.552124
# XGBoost: 0.580695
# LightGBM: 0.567181
# CatBoost: 0.618147
# NGBoost: 0.508494
#
# ################ Train and test results for the model: ################
#
#                 models  accuracy_train  accuracy_test
# 0   LogisticRegression           0.664          0.446
# 1          Naive Bayes           0.631          0.451
# 2                  KNN           0.614          0.466
# 3                  SVM           0.767          0.479
# 4                  ANN           0.993          0.457
# 5                 CART           1.000          0.581
# 6          BaggedTrees           0.974          0.538
# 7                   RF           1.000          0.552
# 8             AdaBoost           1.000          0.624
# 9                  GBM           1.000          0.552
# 10             XGBoost           1.000          0.581
# 11            LightGBM           1.000          0.567
# 12            CatBoost           1.000          0.618
# 13             NGBoost           0.967          0.508

# %%
# Final Model
logreg_tuned = LogisticRegression(**logreg_cv_model.best_params_).fit(X_train, y_train)
y_pred = logreg_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8051948051948052
roc_auc_score(y_test, y_pred)
# Out:
# 0.5

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-RF30-LR73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-RF30-LR73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.00      0.00      0.00        35
#     EGFR E21       0.51      1.00      0.68        37
#
#     accuracy                           0.51        72
#    macro avg       0.26      0.50      0.34        72
# weighted avg       0.26      0.51      0.35        72
#
# precision 0.5138888888888888 accuracy 0.5138888888888888 recall 1.0 auc 0.5

# %%
# Visualization of Results
# plot_feature_importances(logreg_tuned)
plot_results(logreg_tuned)
report_results_quickly(logreg_tuned)
plot_learning_curve(logreg_tuned)

# %%
# Final Model
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
rf_tuned = RandomForestClassifier(**rf_cv_model.best_params_).fit(X_train, y_train)
y_pred = rf_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8831168831168831
roc_auc_score(y_test, y_pred)
# Out:
# 0.5204633204633204

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-RF30-RF73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-RF30-RF73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.53      0.26      0.35        35
#     EGFR E21       0.53      0.78      0.63        37
#
#     accuracy                           0.53        72
#    macro avg       0.53      0.52      0.49        72
# weighted avg       0.53      0.53      0.49        72
#
# precision 0.5272727272727272 accuracy 0.5277777777777778 recall 0.7837837837837838 auc 0.5204633204633204

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(rf_tuned)
report_results_quickly(rf_tuned)
plot_results(rf_tuned)
plot_learning_curve(rf_tuned)

# %%
# Final Model
xgb_tuned = XGBClassifier(**xgb_cv_model.best_params_).fit(X_train, y_train)
y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.6111111111111112

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-RF30-XGB73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-RF30-XGB73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.59      0.63      0.61        35
#     EGFR E21       0.63      0.59      0.61        37
#
#     accuracy                           0.61        72
#    macro avg       0.61      0.61      0.61        72
# weighted avg       0.61      0.61      0.61        72
#
# precision 0.6285714285714286 accuracy 0.6111111111111112 recall 0.5945945945945946 auc 0.6115830115830116

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(xgb_tuned)
report_results_quickly(xgb_tuned)
plot_results(xgb_tuned)
# plot_learning_curve(xgb_tuned)

# %%
# Final Model
lgbm_tuned = LGBMClassifier(**lgbm_cv_model.best_params_).fit(X_train, y_train)
y_pred = lgbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.5694444444444444

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-RF30-lgb73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-RF30-lgb73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.55      0.60      0.58        35
#     EGFR E21       0.59      0.54      0.56        37
#
#     accuracy                           0.57        72
#    macro avg       0.57      0.57      0.57        72
# weighted avg       0.57      0.57      0.57        72
#
# precision 0.5882352941176471 accuracy 0.5694444444444444 recall 0.5405405405405406 auc 0.5702702702702702

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(lgbm_tuned)
# report_results_quickly(lgbm_tuned)
plot_results(lgbm_tuned)
# plot_learning_curve(lgbm_tuned)

# %%
# Comparison of tuned models
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
# 479:	learn: 0.0405488	total: 309ms	remaining: 12.9ms
# 480:	learn: 0.0404969	total: 310ms	remaining: 12.2ms
# 481:	learn: 0.0403534	total: 310ms	remaining: 11.6ms
# 482:	learn: 0.0401460	total: 311ms	remaining: 10.9ms
# 483:	learn: 0.0400717	total: 312ms	remaining: 10.3ms
# 484:	learn: 0.0398667	total: 312ms	remaining: 9.66ms
# 485:	learn: 0.0396769	total: 313ms	remaining: 9.03ms
# 486:	learn: 0.0394887	total: 314ms	remaining: 8.38ms
# 487:	learn: 0.0393025	total: 315ms	remaining: 7.74ms
# 488:	learn: 0.0392065	total: 315ms	remaining: 7.09ms
# 489:	learn: 0.0389785	total: 316ms	remaining: 6.45ms
# 490:	learn: 0.0389785	total: 317ms	remaining: 5.8ms
# 491:	learn: 0.0389256	total: 317ms	remaining: 5.16ms
# 492:	learn: 0.0388027	total: 318ms	remaining: 4.51ms
# 493:	learn: 0.0386915	total: 319ms	remaining: 3.87ms
# 494:	learn: 0.0385446	total: 319ms	remaining: 3.23ms
# 495:	learn: 0.0383521	total: 320ms	remaining: 2.58ms
# 496:	learn: 0.0382952	total: 321ms	remaining: 1.94ms
# 497:	learn: 0.0382183	total: 321ms	remaining: 1.29ms
# 498:	learn: 0.0381276	total: 322ms	remaining: 644us
# 499:	learn: 0.0380673	total: 323ms	remaining: 0us
# CatBoost: 0.622780
# GBDT: 0.638610
#
# ################ Train and test results for the model: ################
#
#                models  accuracy_train  accuracy_test
# 0  LogisticRegression           0.500          0.500
# 1                  RF           0.979          0.548
# 2             XGBoost           1.000          0.612
# 3            LightGBM           1.000          0.570
# 4            CatBoost           1.000          0.623
# 5                GBDT           0.989          0.639

# %%
# Pickle Models --> Saving tuned models

# Create a folder named 'Models'
# save working directory
#
# cur_dir = os.getcwd()
# cur_dir
#
# # change working directory:
os.chdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RF30")
#
# # Save the models
for model in tuned_models:
    pickle.dump(model[1], open(str(model[0]) + ".pkl", 'wb'))

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-1.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFEGB8.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-42.csv",index=None)


external_test=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testxkZscore-RF30.csv")
external_test_label = external_test.label
# print(external_test_label)
external_test=external_test.drop(columns=['label'])

# %%
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-1.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFEGB8.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-42.csv",index=None)


external_test1=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testrjZscore-RF30.csv")
external_test_label1 = external_test1.label
# print(external_test_label)
external_test1=external_test1.drop(columns=['label'])

# %%
OSPath = 'C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS'

# %%
######XGB  测试集1
import numpy as np
# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/RF30/XGBoost.pkl'
finalpkl =  OSPath + pathpkl
xgb = pickle.load(open(finalpkl, 'rb'))
external_test_pred=xgb.predict(external_test)
path = '/RFE-RF-GB/ex-test-for-auc-dca-xgb-RF30-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred, delimiter = ',')


# xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/XGBoost.pkl', 'rb'))
# external_test_pred=xgb.predict(external_test)
# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-xgb-RFERF19-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.50      0.60      0.55        30
#     EGFR_E21       0.56      0.45      0.50        33
#
#     accuracy                           0.52        63
#    macro avg       0.53      0.53      0.52        63
# weighted avg       0.53      0.52      0.52        63
#
# precision 0.5555555555555556 accuracy 0.5238095238095238 recall 0.45454545454545453 auc 0.5272727272727272

# %%
######XGB  测试集1
#############画图部分
# from sklearn.datasets import load_breast_cancer
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
import pylab as plt
import warnings;warnings.filterwarnings('ignore')
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for XGBClassifier')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
######XGB  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[18 12]
#  [18 15]]
# Normalized confusion matrix
# [[0.6  0.4 ]
#  [0.55 0.45]]

# %%
#####XGB  测试集2

import numpy as np

# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/RF30/XGBoost.pkl'
finalpkl =  OSPath + pathpkl
xgb = pickle.load(open(finalpkl, 'rb'))
external_test_pred1=xgb.predict(external_test1)
path = '/RFE-RF-GB/ex-test1-for-auc-dca-xgb-RF30-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred1, delimiter = ',')

# xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/XGBoost.pkl', 'rb'))

# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-xgb-RFERF19-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.86      0.70      0.78        27
#     EGFR_E21       0.67      0.84      0.74        19
#
#     accuracy                           0.76        46
#    macro avg       0.77      0.77      0.76        46
# weighted avg       0.78      0.76      0.76        46
#
# precision 0.6666666666666666 accuracy 0.7608695652173914 recall 0.8421052631578947 auc 0.7729044834307992

# %%
#####XGB  测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for XGBClassifier')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####XGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[19  8]
#  [ 3 16]]
# Normalized confusion matrix
# [[0.7  0.3 ]
#  [0.16 0.84]]

# %%
#####RF  测试集1
import numpy as np
# # Load the model that we saved before
import numpy as np
# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/RF30/RF.pkl'
finalpkl =  OSPath + pathpkl
rft = pickle.load(open(finalpkl, 'rb'))
external_test_pred=rft.predict(external_test)
path = '/RFE-RF-GB/ex-test-for-auc-dca-RF-RF30-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred, delimiter = ',')
# rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/RF.pkl', 'rb'))
# external_test_pred=rft.predict(external_test)
# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-RF-RFERF19-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.47      0.27      0.34        30
#     EGFR_E21       0.52      0.73      0.61        33
#
#     accuracy                           0.51        63
#    macro avg       0.50      0.50      0.47        63
# weighted avg       0.50      0.51      0.48        63
#
# precision 0.5217391304347826 accuracy 0.5079365079365079 recall 0.7272727272727273 auc 0.496969696969697

# %%
#####RF  测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####RF  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 8 22]
#  [ 9 24]]
# Normalized confusion matrix
# [[0.27 0.73]
#  [0.27 0.73]]

# %%
#####RF  测试集2
import numpy as np
# # Load the model that we saved before

pathpkl = '/RFE-RF-GB/RF30/RF.pkl'
finalpkl =  OSPath + pathpkl
rft = pickle.load(open(finalpkl, 'rb'))
external_test_pred1=rft.predict(external_test1)
# external_test_pred=rft.predict(external_test)
path = '/RFE-RF-GB/ex-test1-for-auc-dca-RF-RF30-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred1, delimiter = ',')
# rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/RF.pkl', 'rb'))

# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-RF-RFERF19-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# precision 0.5135135135135135 accuracy 0.49206349206349204 recall 0.5757575757575758 auc 0.5696969696969697
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.82      0.33      0.47        27
#     EGFR_E21       0.49      0.89      0.63        19
#
#     accuracy                           0.57        46
#    macro avg       0.65      0.61      0.55        46
# weighted avg       0.68      0.57      0.54        46
#
# precision 0.4857142857142857 accuracy 0.5652173913043478 recall 0.8947368421052632 auc 0.6140350877192983

# %%
#####rf  测试集2

fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####rf  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 9 18]
#  [ 2 17]]
# Normalized confusion matrix
# [[0.33 0.67]
#  [0.11 0.89]]

# %%
######LR 测试集1
import numpy as np
# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/RF30/LogisticRegression.pkl'
finalpkl =  OSPath + pathpkl
lrt = pickle.load(open(finalpkl, 'rb'))
external_test_pred=lrt.predict(external_test)
path = '/RFE-RF-GB/ex-test-for-auc-dca-lr-RF30-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred, delimiter = ',')
# lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/LogisticRegression.pkl', 'rb'))
# external_test_pred=lrt.predict(external_test)
# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-lr-RFERF19-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.00      0.00      0.00        30
#     EGFR_E21       0.52      1.00      0.69        33
#
#     accuracy                           0.52        63
#    macro avg       0.26      0.50      0.34        63
# weighted avg       0.27      0.52      0.36        63
#
# precision 0.5238095238095238 accuracy 0.5238095238095238 recall 1.0 auc 0.5

# %%
######LR 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 0 30]
#  [ 0 33]]
# Normalized confusion matrix
# [[0. 1.]
#  [0. 1.]]

# %%
######LR 测试集2
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/RF30/LogisticRegression.pkl'
finalpkl =  OSPath + pathpkl
lrt = pickle.load(open(finalpkl, 'rb'))
external_test_pred1=lrt.predict(external_test1)
path = '/RFE-RF-GB/ex-test1-for-auc-dca-lr-RF30-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred1, delimiter = ',')

# lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/LogisticRegression.pkl', 'rb'))

# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-lr-RFERF19-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.00      0.00      0.00        27
#     EGFR_E21       0.41      1.00      0.58        19
#
#     accuracy                           0.41        46
#    macro avg       0.21      0.50      0.29        46
# weighted avg       0.17      0.41      0.24        46
#
# precision 0.41304347826086957 accuracy 0.41304347826086957 recall 1.0 auc 0.5

# %%
######LR 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 0 27]
#  [ 0 19]]
# Normalized confusion matrix
# [[0. 1.]
#  [0. 1.]]

# %%
##lgb 测试集1
import numpy as np
# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/RF30/LightGBM.pkl'
finalpkl =  OSPath + pathpkl
lgbt = pickle.load(open(finalpkl, 'rb'))
external_test_pred=lgbt.predict(external_test)
path = '/RFE-RF-GB/ex-test-for-auc-dca-lgb-RF30-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred, delimiter = ',')
# lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/LightGBM.pkl', 'rb'))
# external_test_pred=lgbt.predict(external_test)
# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-lgb-RFERF19-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.48      0.43      0.46        30
#     EGFR_E21       0.53      0.58      0.55        33
#
#     accuracy                           0.51        63
#    macro avg       0.50      0.50      0.50        63
# weighted avg       0.51      0.51      0.51        63
#
# precision 0.5277777777777778 accuracy 0.5079365079365079 recall 0.5757575757575758 auc 0.5045454545454545

# %%
##lgb 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
##lgb 测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[13 17]
#  [14 19]]
# Normalized confusion matrix
# [[0.43 0.57]
#  [0.42 0.58]]

# %%
#lgb 测试集2
import numpy as np
# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/RF30/LightGBM.pkl'
finalpkl =  OSPath + pathpkl
lgbt = pickle.load(open(finalpkl, 'rb'))
external_test_pred1=lgbt.predict(external_test1)
path = '/RFE-RF-GB/ex-test1-for-auc-dca-lgb-RF30-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred1, delimiter = ',')

# lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/LightGBM.pkl', 'rb'))
# external_test_pred1=lgbt.predict(external_test1)

# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-lgb-RFERF19-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.67      0.74      0.70        27
#     EGFR_E21       0.56      0.47      0.51        19
#
#     accuracy                           0.63        46
#    macro avg       0.61      0.61      0.61        46
# weighted avg       0.62      0.63      0.62        46
#
# precision 0.5625 accuracy 0.6304347826086957 recall 0.47368421052631576 auc 0.6072124756335282

# %%
#lgb 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[20  7]
#  [10  9]]
# Normalized confusion matrix
# [[0.74 0.26]
#  [0.53 0.47]]

# %%
# # Visualization of Results --> Feature Importances
# plot_feature_importances(lgbt)
# # report_results_quickly(lgbm_tuned)
# plot_results(lgbt)
# # plot_learning_curve(lgbm_tuned)
