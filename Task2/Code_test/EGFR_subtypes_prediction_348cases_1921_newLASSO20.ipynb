# %%
import pandas as pd
import numpy as np
import os
print("文件列表：",os.listdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921"))
data = pd.ExcelFile("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/348cases_1921_FS_results.xlsx")#, sheet_name='g1rfegb12'
sheet_names = data.sheet_names
print("列表名：",sheet_names )
# Out:
# 文件列表： ['348cases_1921_FS_results.xlsx', 'FINAL3CENTER349_COMBAT1921.csv', 'FS-RFE', 'FUSCC-zscore-MI.csv', 'FUSCC.csv', 'hrfs', 'hrfs_clinic', 'HRFS_CLINIC_FS', 'HRFS_FS', 'internaltest.csv', 'internaltest1921new.csv', 'internaltest1921new_zscore-MI.csv', 'internaltest1921new_zscore.csv', 'internaltest_fe.csv', 'internaltest_label.csv', 'MIzsore1921-new20231.csv', 'new2023', 'raw', 'RFselect1921-auc-MI2023.csv', 'testrj.csv', 'testrj1921new.csv', 'testrj1921new_zscore.csv', 'testxk.csv', 'testxk1921new.csv', 'testxk1921new_zscore.csv', 'train.csv', 'train1921new.csv', 'train1921newZscore-MI.csv', 'train1921new_zscore1.csv', 'trainZscore-MI-SBS-LGB2023.csv', 'trainZscore-MI-SBS-LR2023.csv', 'trainZscore-MI-SBS-RF2023.csv', 'trainZscore-MI-SBS-XGB2023.csv', 'trainZscore-MI-SFS-LR2023.csv', 'trainZscore-MI-SFS-RF2023.csv', 'trainZscore-MI-SFS-XGB2023.csv', 'train_fe.csv', 'train_label.csv', 'XtrainZscore-MI-RFE.csv', '~$348cases_1921_FS_results.xlsx']
# 列表名： ['preprossess', 'MI', 'mrmr50', 'LASSO', 'RFE-LIGBTGBM', 'RFE-XGB10', 'RFE-RF', 'RFE-LR', 'SFS-LIGHTGBM', 'SFS-XGB', 'SFS-RF', 'SFS-LR', 'SBS-LIGHTGBM', 'SBS-XGB', 'SBS-RF', 'SBS-LR', 'MI2', 'MRMR50-1', 'RFE-NGB19', 'RFE-CGB14', 'RFE-GB25', 'RFE-XGB27', 'RFE-XGB4', 'RFE-DT7', 'RFE-ADB25', 'LASSO20']

# %%
# data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
name = 'LASSO20'
data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/348cases_1921_FS_results.xlsx", sheet_name=name)

data.keys()
train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/FUSCC-zscore-MI.csv")
test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxk1921new_zscore.csv")
test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj1921new_zscore.csv")
train=train[data.keys()]
train.shape
test=test[data.keys()]
test.shape
test1=test1[data.keys()]
test1.shape

train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/trainZscore-LASSO20.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF11.csv",index=None)


# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF19.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF5.csv",index=None)
test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testxkZscore-LASSO20.csv",index=None)


# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testrjZscore-LASSO20.csv",index=None)

# %%
test.shape
# Out:
# (63, 21)

# %%
test1.shape
# Out:
# (46, 21)

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxkraw-fs-preprosess.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj-fs-preprosess.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# # data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
# data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/EGFR1921-767cases-FS-results.xlsx", sheet_name='RFERF19')
# data.keys()
# train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore.csv")
# test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxk1921new_zscore.csv")
# test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj1921new_zscore.csv")
# train=train[data.keys()]
# train.shape
# test=test[data.keys()]
# test.shape
# test1=test1[data.keys()]
# test1.shape

# # train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-1.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF14.csv",index=None)
# # train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-42.csv",index=None)


# # test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-1.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF14.csv",index=None)
# # test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-42.csv",index=None)


# # test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-1.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF14.csv",index=None)
# # test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-42.csv",index=None)

# %%
#%% load liabrary
import os
import numpy as np
import xlrd
import scipy.io as io
import pandas as pd
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFE
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit, train_test_split
from sklearn.linear_model import Lasso, Ridge, LassoCV,LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn import metrics
import itertools
import joblib
from scipy import stats
from sklearn import preprocessing
print("Import library done.\n")
# Out:
# Import library done.

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test_label.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# DIABETES PREDICTION MODEL

# CLASSIFICATION MODELS - HOLDOUT

'''
Steps to follow:
    - Load the saved dataset
    - General View
    - Modeling
        - Base models: LogisticRegression, GaussianNB, KNeighborsClassifier, SVC, MLPClassifier, DecisionTreeClassifier,
                       BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,
                       XGBClassifier, LGBMClassifier, CatBoostClassifier, NGBClassifier
    - Model Evaluation
    - Model Tuning
    - Model Results
'''

# Import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


# Load the preprocessed dataset
# diabetes_preprocessed = pd.read_csv('./diabetes_prepared.csv')

# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-1.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFEGB8.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-42.csv",index=None)

# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rferf17.csv")
# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rfegb5.csv")
diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/trainZscore-LASSO20.csv")




# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/Results_HRFS01/catboost/train.csv")
df = diabetes_preprocessed.copy()
# df = df.drop(columns="id",axis=1)

## GENERAL VIEW

df.head()
df.shape
df.info()
df.columns
df.index
df.describe([0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 21 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis                  239 non-null    float64
#  1   CT_logarithm_glcm_Contrast                                  239 non-null    float64
#  2   CT_original_shape_Elongation                                239 non-null    float64
#  3   PET_lbp.3D.m2_firstorder_90Percentile                       239 non-null    float64
#  4   CT_wavelet.LLH_firstorder_90Percentile                      239 non-null    float64
#  5   PET_wavelet.LHL_firstorder_Kurtosis                         239 non-null    float64
#  6   CT_log.sigma.3.0.mm.3D_firstorder_10Percentile              239 non-null    float64
#  7   CT_wavelet2.HHH_firstorder_Mean                             239 non-null    float64
#  8   PET_lbp.3D.k_ngtdm_Strength                                 239 non-null    float64
#  9   CT_logarithm_firstorder_Maximum                             239 non-null    float64
#  10  PET_wavelet2.LHL_firstorder_Skewness                        239 non-null    float64
#  11  PET_wavelet.HLH_glszm_ZoneVariance                          239 non-null    float64
#  12  CT_wavelet2.HHH_glcm_ClusterShade                           239 non-null    float64
#  13  CT_lbp.3D.m1_firstorder_10Percentile                        239 non-null    float64
#  14  CT_wavelet.HLL_firstorder_Maximum                           239 non-null    float64
#  15  CT_wavelet.HHH_firstorder_Median                            239 non-null    float64
#  16  PET_exponential_glszm_SmallAreaLowGrayLevelEmphasis         239 non-null    float64
#  17  CT_wavelet2.HLH_firstorder_Mean                             239 non-null    float64
#  18  CT_log.sigma.3.0.mm.3D_glszm_SmallAreaLowGrayLevelEmphasis  239 non-null    float64
#  19  PET_wavelet.HLH_firstorder_Mean                             239 non-null    float64
#  20  label                                                       239 non-null    int64
# dtypes: float64(20), int64(1)
# memory usage: 39.3 KB
#                                                      count   mean   std  \
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         239.000 -0.000 1.002
# CT_logarithm_glcm_Contrast                         239.000 -0.000 1.002
# CT_original_shape_Elongation                       239.000  0.000 1.002
# PET_lbp.3D.m2_firstorder_90Percentile              239.000  0.000 1.002
# CT_wavelet.LLH_firstorder_90Percentile             239.000 -0.000 1.002
# PET_wavelet.LHL_firstorder_Kurtosis                239.000 -0.000 1.002
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     239.000 -0.000 1.002
# CT_wavelet2.HHH_firstorder_Mean                    239.000 -0.000 1.002
# PET_lbp.3D.k_ngtdm_Strength                        239.000 -0.000 1.002
# CT_logarithm_firstorder_Maximum                    239.000 -0.000 1.002
# PET_wavelet2.LHL_firstorder_Skewness               239.000 -0.000 1.002
# PET_wavelet.HLH_glszm_ZoneVariance                 239.000  0.000 1.002
# CT_wavelet2.HHH_glcm_ClusterShade                  239.000 -0.000 1.002
# CT_lbp.3D.m1_firstorder_10Percentile               239.000  0.000 1.002
# CT_wavelet.HLL_firstorder_Maximum                  239.000 -0.000 1.002
# CT_wavelet.HHH_firstorder_Median                   239.000 -0.000 1.002
# PET_exponential_glszm_SmallAreaLowGrayLevelEmph... 239.000  0.000 1.002
# CT_wavelet2.HLH_firstorder_Mean                    239.000 -0.000 1.002
# CT_log.sigma.3.0.mm.3D_glszm_SmallAreaLowGrayLe... 239.000  0.000 1.002
# PET_wavelet.HLH_firstorder_Mean                    239.000 -0.000 1.002
# label                                              239.000  0.552 0.498
#
#                                                       min    10%    25%  \
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         -1.788 -0.978 -0.697
# CT_logarithm_glcm_Contrast                         -1.803 -1.422 -0.659
# CT_original_shape_Elongation                       -3.701 -1.272 -0.683
# PET_lbp.3D.m2_firstorder_90Percentile              -3.116 -1.458 -0.489
# CT_wavelet.LLH_firstorder_90Percentile             -1.797 -1.135 -0.639
# PET_wavelet.LHL_firstorder_Kurtosis                -0.864 -0.733 -0.629
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     -2.861 -1.140 -0.605
# CT_wavelet2.HHH_firstorder_Mean                    -6.523 -0.781 -0.327
# PET_lbp.3D.k_ngtdm_Strength                        -0.777 -0.723 -0.638
# CT_logarithm_firstorder_Maximum                    -4.874 -0.273 -0.080
# PET_wavelet2.LHL_firstorder_Skewness               -3.986 -0.787 -0.291
# PET_wavelet.HLH_glszm_ZoneVariance                 -0.293 -0.284 -0.254
# CT_wavelet2.HHH_glcm_ClusterShade                  -5.053 -0.804 -0.423
# CT_lbp.3D.m1_firstorder_10Percentile               -1.943 -1.147 -0.741
# CT_wavelet.HLL_firstorder_Maximum                  -1.690 -1.150 -0.733
# CT_wavelet.HHH_firstorder_Median                   -6.762 -0.717 -0.225
# PET_exponential_glszm_SmallAreaLowGrayLevelEmph... -1.245 -0.763 -0.543
# CT_wavelet2.HLH_firstorder_Mean                    -4.142 -0.981 -0.339
# CT_log.sigma.3.0.mm.3D_glszm_SmallAreaLowGrayLe... -0.779 -0.495 -0.422
# PET_wavelet.HLH_firstorder_Mean                    -3.261 -1.057 -0.465
# label                                               0.000  0.000  0.000
#
#                                                       50%    75%   90%   95%  \
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         -0.189  0.546 1.057 1.820
# CT_logarithm_glcm_Contrast                         -0.008  0.662 1.319 1.762
# CT_original_shape_Elongation                        0.131  0.719 1.245 1.378
# PET_lbp.3D.m2_firstorder_90Percentile               0.231  0.678 0.997 1.183
# CT_wavelet.LLH_firstorder_90Percentile             -0.202  0.516 1.572 1.913
# PET_wavelet.LHL_firstorder_Kurtosis                -0.382  0.349 1.076 1.563
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     -0.077  0.560 1.238 1.724
# CT_wavelet2.HHH_firstorder_Mean                    -0.006  0.297 0.905 1.572
# PET_lbp.3D.k_ngtdm_Strength                        -0.403  0.236 1.357 2.460
# CT_logarithm_firstorder_Maximum                     0.096  0.339 0.715 1.098
# PET_wavelet2.LHL_firstorder_Skewness                0.011  0.232 0.479 0.967
# PET_wavelet.HLH_glszm_ZoneVariance                 -0.204 -0.128 0.162 0.524
# CT_wavelet2.HHH_glcm_ClusterShade                  -0.076  0.439 1.069 1.506
# CT_lbp.3D.m1_firstorder_10Percentile                0.060  0.461 1.262 1.308
# CT_wavelet.HLL_firstorder_Maximum                  -0.122  0.606 1.333 1.821
# CT_wavelet.HHH_firstorder_Median                    0.058  0.354 0.793 1.219
# PET_exponential_glszm_SmallAreaLowGrayLevelEmph... -0.252  0.203 0.871 2.026
# CT_wavelet2.HLH_firstorder_Mean                    -0.023  0.317 0.870 1.684
# CT_log.sigma.3.0.mm.3D_glszm_SmallAreaLowGrayLe... -0.301  0.001 0.638 1.757
# PET_wavelet.HLH_firstorder_Mean                    -0.105  0.441 1.096 1.721
# label                                               1.000  1.000 1.000 1.000
#
#                                                      99%    max
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         2.810  5.732
# CT_logarithm_glcm_Contrast                         2.303  2.852
# CT_original_shape_Elongation                       1.680  1.811
# PET_lbp.3D.m2_firstorder_90Percentile              1.476  1.977
# CT_wavelet.LLH_firstorder_90Percentile             2.715  3.079
# PET_wavelet.LHL_firstorder_Kurtosis                4.190  5.439
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     2.835  3.083
# CT_wavelet2.HHH_firstorder_Mean                    2.465  5.629
# PET_lbp.3D.k_ngtdm_Strength                        3.443  3.742
# CT_logarithm_firstorder_Maximum                    1.570  2.570
# PET_wavelet2.LHL_firstorder_Skewness               4.184  8.929
# PET_wavelet.HLH_glszm_ZoneVariance                 4.015 11.140
# CT_wavelet2.HHH_glcm_ClusterShade                  2.683  4.475
# CT_lbp.3D.m1_firstorder_10Percentile               3.547  4.067
# CT_wavelet.HLL_firstorder_Maximum                  2.599  4.902
# CT_wavelet.HHH_firstorder_Median                   2.451  6.037
# PET_exponential_glszm_SmallAreaLowGrayLevelEmph... 3.808  6.598
# CT_wavelet2.HLH_firstorder_Mean                    3.370  4.303
# CT_log.sigma.3.0.mm.3D_glszm_SmallAreaLowGrayLe... 4.583  6.857
# PET_wavelet.HLH_firstorder_Mean                    2.805  4.929
# label                                              1.000  1.000

# %%
# Check for missing values
df.isnull().values.any()
df.isnull().sum().sort_values(ascending=False)
# Out:
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis                    0
# PET_wavelet.HLH_glszm_ZoneVariance                            0
# PET_wavelet.HLH_firstorder_Mean                               0
# CT_log.sigma.3.0.mm.3D_glszm_SmallAreaLowGrayLevelEmphasis    0
# CT_wavelet2.HLH_firstorder_Mean                               0
# PET_exponential_glszm_SmallAreaLowGrayLevelEmphasis           0
# CT_wavelet.HHH_firstorder_Median                              0
# CT_wavelet.HLL_firstorder_Maximum                             0
# CT_lbp.3D.m1_firstorder_10Percentile                          0
# CT_wavelet2.HHH_glcm_ClusterShade                             0
# PET_wavelet2.LHL_firstorder_Skewness                          0
# CT_logarithm_glcm_Contrast                                    0
# CT_logarithm_firstorder_Maximum                               0
# PET_lbp.3D.k_ngtdm_Strength                                   0
# CT_wavelet2.HHH_firstorder_Mean                               0
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile                0
# PET_wavelet.LHL_firstorder_Kurtosis                           0
# CT_wavelet.LLH_firstorder_90Percentile                        0
# PET_lbp.3D.m2_firstorder_90Percentile                         0
# CT_original_shape_Elongation                                  0
# label                                                         0
# dtype: int64

# %%
# MODELING


# Define dependent and independent variables
y = df["label"]
X = df.drop(["label"], axis=1)

# y = df["Outcome"]
# X = df.drop(["Outcome"], axis=1)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# See the results for base models

base_models = [('LogisticRegression', LogisticRegression()),
               ('Naive Bayes', GaussianNB()),
               ('KNN', KNeighborsClassifier()),
               ('SVM', SVC()),
               ('ANN', MLPClassifier()),
               ('CART', DecisionTreeClassifier()),
               ('BaggedTrees', BaggingClassifier()),
               ('RF', RandomForestClassifier()),
               ('AdaBoost', AdaBoostClassifier()),
               ('GBM', GradientBoostingClassifier()),
               ("XGBoost", XGBClassifier()),
               ("LightGBM", LGBMClassifier()),
               ("CatBoost", CatBoostClassifier(verbose=False)),
               ("NGBoost", NGBClassifier(verbose=False))]

# %%
evaluate_classification_model_holdout(base_models)
# LogisticRegression: 0.805195
# Naive Bayes: 0.603896
# KNN: 0.850649
# SVM: 0.837662
# ANN: 0.850649
# CART: 0.824675
# BaggedTrees: 0.857143
# RF: 0.876623
# AdaBoost: 0.883117
# GBM: 0.870130
# XGBoost: 0.883117
# LightGBM: 0.857143
# CatBoost: 0.863636
# NGBoost: 0.863636
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.692664
# Naive Bayes: 0.606178
# KNN: 0.567181
# SVM: 0.550579
# ANN: 0.691120
# CART: 0.567954
# BaggedTrees: 0.527413
# RF: 0.662548
# AdaBoost: 0.565637
# GBM: 0.579923
# XGBoost: 0.580695
# LightGBM: 0.666409
# CatBoost: 0.619691
# NGBoost: 0.633205
#
# ################ Train and test results for the model: ################
#
#                 models  accuracy_train  accuracy_test
# 0   LogisticRegression           0.719          0.693
# 1          Naive Bayes           0.597          0.606
# 2                  KNN           0.718          0.567
# 3                  SVM           0.842          0.551
# 4                  ANN           0.943          0.691
# 5                 CART           1.000          0.568
# 6          BaggedTrees           0.984          0.527
# 7                   RF           1.000          0.663
# 8             AdaBoost           0.983          0.566
# 9                  GBM           1.000          0.580
# 10             XGBoost           1.000          0.581
# 11            LightGBM           1.000          0.666
# 12            CatBoost           1.000          0.620
# 13             NGBoost           0.953          0.633

# %%
# Final Model
logreg_tuned = LogisticRegression(**logreg_cv_model.best_params_).fit(X_train, y_train)
y_pred = logreg_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8051948051948052
roc_auc_score(y_test, y_pred)
# Out:
# 0.6911196911196911

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LASSO20-LR73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-LASSO20-LR73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.74      0.57      0.65        35
#     EGFR E21       0.67      0.81      0.73        37
#
#     accuracy                           0.69        72
#    macro avg       0.70      0.69      0.69        72
# weighted avg       0.70      0.69      0.69        72
#
# precision 0.6666666666666666 accuracy 0.6944444444444444 recall 0.8108108108108109 auc 0.6911196911196911

# %%
# Visualization of Results
# plot_feature_importances(logreg_tuned)
plot_results(logreg_tuned)
report_results_quickly(logreg_tuned)
plot_learning_curve(logreg_tuned)

# %%
# Final Model
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
rf_tuned = RandomForestClassifier(**rf_cv_model.best_params_).fit(X_train, y_train)
y_pred = rf_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8831168831168831
roc_auc_score(y_test, y_pred)
# Out:
# 0.5760617760617761

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LASSO20-RF73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-LASSO20-RF73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.65      0.31      0.42        35
#     EGFR E21       0.56      0.84      0.67        37
#
#     accuracy                           0.58        72
#    macro avg       0.61      0.58      0.55        72
# weighted avg       0.60      0.58      0.55        72
#
# precision 0.5636363636363636 accuracy 0.5833333333333334 recall 0.8378378378378378 auc 0.5760617760617761

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(rf_tuned)
report_results_quickly(rf_tuned)
plot_results(rf_tuned)
plot_learning_curve(rf_tuned)

# %%
# Final Model
xgb_tuned = XGBClassifier(**xgb_cv_model.best_params_).fit(X_train, y_train)
y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.6388888888888888

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LASSO20-XGB73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-LASSO20-XGB73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.65      0.57      0.61        35
#     EGFR E21       0.63      0.70      0.67        37
#
#     accuracy                           0.64        72
#    macro avg       0.64      0.64      0.64        72
# weighted avg       0.64      0.64      0.64        72
#
# precision 0.6341463414634146 accuracy 0.6388888888888888 recall 0.7027027027027027 auc 0.637065637065637

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(xgb_tuned)
report_results_quickly(xgb_tuned)
plot_results(xgb_tuned)
# plot_learning_curve(xgb_tuned)

# %%
# Final Model
lgbm_tuned = LGBMClassifier(**lgbm_cv_model.best_params_).fit(X_train, y_train)
y_pred = lgbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.6111111111111112

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LASSO20-lgb73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-LASSO20-lgb73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.61      0.57      0.59        35
#     EGFR E21       0.62      0.65      0.63        37
#
#     accuracy                           0.61        72
#    macro avg       0.61      0.61      0.61        72
# weighted avg       0.61      0.61      0.61        72
#
# precision 0.6153846153846154 accuracy 0.6111111111111112 recall 0.6486486486486487 auc 0.61003861003861

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(lgbm_tuned)
# report_results_quickly(lgbm_tuned)
plot_results(lgbm_tuned)
# plot_learning_curve(lgbm_tuned)

# %%
# Comparison of tuned models
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
tuned_models = [('LogisticRegression', logreg_tuned),
                ('RF', rf_tuned),
                ('XGBoost', xgb_tuned),
                ('LightGBM', lgbm_tuned),
               ('CatBoost', cb_tuned),
                ('SVM', svm_tuned),
                ('GBDT', gbdt_tuned),
                ('NGBoost', ngb_tuned),
                ('DT', dt_tuned),
                ('AdaBoost', adb_tuned)
               ]


evaluate_classification_model_holdout(tuned_models)
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.691120
# RF: 0.562548
# XGBoost: 0.637066
# LightGBM: 0.610039
# 0:	learn: 0.6634759	total: 965us	remaining: 192ms
# 1:	learn: 0.6465007	total: 1.92ms	remaining: 190ms
# 2:	learn: 0.6235217	total: 2.74ms	remaining: 180ms
# 3:	learn: 0.6007228	total: 3.51ms	remaining: 172ms
# 4:	learn: 0.5811274	total: 4.34ms	remaining: 169ms
# 5:	learn: 0.5656805	total: 5.18ms	remaining: 167ms
# 6:	learn: 0.5450292	total: 5.96ms	remaining: 164ms
# 7:	learn: 0.5224793	total: 6.71ms	remaining: 161ms
# 8:	learn: 0.5090230	total: 7.47ms	remaining: 158ms
# 9:	learn: 0.4930933	total: 8.28ms	remaining: 157ms
val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 100] loss=0.1000 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 200] loss=0.1000 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 300] loss=0.1000 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 400] loss=0.1000 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 500] loss=0.1000 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 600] loss=0.1000 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 700] loss=0.0985 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 800] loss=0.0985 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 900] loss=0.0985 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 1000] loss=0.0985 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 1100] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 1200] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 1300] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 1400] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 1500] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 1600] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 1700] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 1800] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 1900] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 2000] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 2100] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 2200] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 2300] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 2400] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 2500] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 2600] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 2700] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 2800] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 2900] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 3000] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 3100] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 3200] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 3300] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 3400] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 3500] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 3600] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 3700] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 3800] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 3900] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 4000] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 4100] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 4200] loss=0.0986 val_loss=0.0000 scale=0.0001 norm=0.0001
# [iter 4300] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 4400] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 4500] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 4600] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 4700] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 4800] loss=0.0986 val_loss=0.0000 scale=0.0002 norm=0.0003
# [iter 4900] loss=0.0986 val_loss=0.0000 scale=0.0010 norm=0.0011
# NGBoost: 0.592664
# DT: 0.500000
# AdaBoost: 0.610811
#
# ################ Train and test results for the model: ################
#
#                models  accuracy_train  accuracy_test
# 0  LogisticRegression           0.702          0.691
# 1                  RF           0.972          0.563
# 2             XGBoost           1.000          0.637
# 3            LightGBM           1.000          0.610
# 4            CatBoost           1.000          0.609
# 5                 SVM           0.726          0.693
# 6                GBDT           1.000          0.693
# 7             NGBoost           0.974          0.593
# 8                  DT           0.500          0.500
# 9            AdaBoost           1.000          0.611

# %%
# Pickle Models --> Saving tuned models

# Create a folder named 'Models'
# save working directory
#
# cur_dir = os.getcwd()
# cur_dir
#
# # change working directory:
os.chdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/LASSO20")
#
# # Save the models
for model in tuned_models:
    pickle.dump(model[1], open(str(model[0]) + ".pkl", 'wb'))

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-1.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFEGB8.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-42.csv",index=None)


external_test=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testxkZscore-LASSO20.csv")
external_test_label = external_test.label
# print(external_test_label)
external_test=external_test.drop(columns=['label'])

# %%
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-1.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFEGB8.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-42.csv",index=None)


external_test1=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testrjZscore-LASSO20.csv")
external_test_label1 = external_test1.label
# print(external_test_label)
external_test1=external_test1.drop(columns=['label'])

# %%
OSPath = 'C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS'

# %%
######XGB  测试集1
import numpy as np
# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/LASSO20/XGBoost.pkl'
finalpkl =  OSPath + pathpkl
xgb = pickle.load(open(finalpkl, 'rb'))
external_test_pred=xgb.predict(external_test)
path = '/RFE-RF-GB/ex-test-for-auc-dca-xgb-LASSO20-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred, delimiter = ',')


# xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/XGBoost.pkl', 'rb'))
# external_test_pred=xgb.predict(external_test)
# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-xgb-RFERF19-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.57      0.40      0.47        30
#     EGFR_E21       0.57      0.73      0.64        33
#
#     accuracy                           0.57        63
#    macro avg       0.57      0.56      0.56        63
# weighted avg       0.57      0.57      0.56        63
#
# precision 0.5714285714285714 accuracy 0.5714285714285714 recall 0.7272727272727273 auc 0.5636363636363636

# %%
######XGB  测试集1
#############画图部分
# from sklearn.datasets import load_breast_cancer
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
import pylab as plt
import warnings;warnings.filterwarnings('ignore')
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for XGBClassifier')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
######XGB  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[12 18]
#  [ 9 24]]
# Normalized confusion matrix
# [[0.4  0.6 ]
#  [0.27 0.73]]

# %%
#####XGB  测试集2

import numpy as np

# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/LASSO20/XGBoost.pkl'
finalpkl =  OSPath + pathpkl
xgb = pickle.load(open(finalpkl, 'rb'))
external_test_pred1=xgb.predict(external_test1)
path = '/RFE-RF-GB/ex-test1-for-auc-dca-xgb-LASSO20-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred1, delimiter = ',')

# xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/XGBoost.pkl', 'rb'))

# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-xgb-RFERF19-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.86      0.22      0.35        27
#     EGFR_E21       0.46      0.95      0.62        19
#
#     accuracy                           0.52        46
#    macro avg       0.66      0.58      0.49        46
# weighted avg       0.69      0.52      0.46        46
#
# precision 0.46153846153846156 accuracy 0.5217391304347826 recall 0.9473684210526315 auc 0.5847953216374269

# %%
#####XGB  测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for XGBClassifier')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####XGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 6 21]
#  [ 1 18]]
# Normalized confusion matrix
# [[0.22 0.78]
#  [0.05 0.95]]

# %%
#####RF  测试集1
import numpy as np
# # Load the model that we saved before
import numpy as np
# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/LASSO20/RF.pkl'
finalpkl =  OSPath + pathpkl
rft = pickle.load(open(finalpkl, 'rb'))
external_test_pred=rft.predict(external_test)
path = '/RFE-RF-GB/ex-test-for-auc-dca-RF-LASSO20-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred, delimiter = ',')
# rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/RF.pkl', 'rb'))
# external_test_pred=rft.predict(external_test)
# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-RF-RFERF19-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.43      0.20      0.27        30
#     EGFR_E21       0.51      0.76      0.61        33
#
#     accuracy                           0.49        63
#    macro avg       0.47      0.48      0.44        63
# weighted avg       0.47      0.49      0.45        63
#
# precision 0.5102040816326531 accuracy 0.49206349206349204 recall 0.7575757575757576 auc 0.47878787878787876

# %%
#####RF  测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####RF  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 6 24]
#  [ 8 25]]
# Normalized confusion matrix
# [[0.2  0.8 ]
#  [0.24 0.76]]

# %%
#####RF  测试集2
import numpy as np
# # Load the model that we saved before

pathpkl = '/RFE-RF-GB/LASSO20/RF.pkl'
finalpkl =  OSPath + pathpkl
rft = pickle.load(open(finalpkl, 'rb'))
external_test_pred1=rft.predict(external_test1)
# external_test_pred=rft.predict(external_test)
path = '/RFE-RF-GB/ex-test1-for-auc-dca-RF-LASSO20-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred1, delimiter = ',')
# rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/RF.pkl', 'rb'))

# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-RF-RFERF19-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# precision 0.5135135135135135 accuracy 0.49206349206349204 recall 0.5757575757575758 auc 0.5696969696969697
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.62      0.19      0.29        27
#     EGFR_E21       0.42      0.84      0.56        19
#
#     accuracy                           0.46        46
#    macro avg       0.52      0.51      0.42        46
# weighted avg       0.54      0.46      0.40        46
#
# precision 0.42105263157894735 accuracy 0.45652173913043476 recall 0.8421052631578947 auc 0.51364522417154

# %%
#####rf  测试集2

fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####rf  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 5 22]
#  [ 3 16]]
# Normalized confusion matrix
# [[0.19 0.81]
#  [0.16 0.84]]

# %%
######LR 测试集1
import numpy as np
# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/LASSO20/LogisticRegression.pkl'
finalpkl =  OSPath + pathpkl
lrt = pickle.load(open(finalpkl, 'rb'))
external_test_pred=lrt.predict(external_test)
path = '/RFE-RF-GB/ex-test-for-auc-dca-lr-LASSO20-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred, delimiter = ',')
# lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/LogisticRegression.pkl', 'rb'))
# external_test_pred=lrt.predict(external_test)
# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-lr-RFERF19-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.38      0.33      0.36        30
#     EGFR_E21       0.46      0.52      0.49        33
#
#     accuracy                           0.43        63
#    macro avg       0.42      0.42      0.42        63
# weighted avg       0.42      0.43      0.42        63
#
# precision 0.4594594594594595 accuracy 0.42857142857142855 recall 0.5151515151515151 auc 0.42424242424242425

# %%
######LR 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[10 20]
#  [16 17]]
# Normalized confusion matrix
# [[0.33 0.67]
#  [0.48 0.52]]

# %%
######LR 测试集2
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/LASSO20/LogisticRegression.pkl'
finalpkl =  OSPath + pathpkl
lrt = pickle.load(open(finalpkl, 'rb'))
external_test_pred1=lrt.predict(external_test1)
path = '/RFE-RF-GB/ex-test1-for-auc-dca-lr-LASSO20-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred1, delimiter = ',')

# lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/LogisticRegression.pkl', 'rb'))

# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-lr-RFERF19-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.50      0.26      0.34        27
#     EGFR_E21       0.38      0.63      0.47        19
#
#     accuracy                           0.41        46
#    macro avg       0.44      0.45      0.41        46
# weighted avg       0.45      0.41      0.39        46
#
# precision 0.375 accuracy 0.41304347826086957 recall 0.631578947368421 auc 0.44541910331384016

# %%
######LR 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 7 20]
#  [ 7 12]]
# Normalized confusion matrix
# [[0.26 0.74]
#  [0.37 0.63]]

# %%
##lgb 测试集1
import numpy as np
# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/LASSO20/LightGBM.pkl'
finalpkl =  OSPath + pathpkl
lgbt = pickle.load(open(finalpkl, 'rb'))
external_test_pred=lgbt.predict(external_test)
path = '/RFE-RF-GB/ex-test-for-auc-dca-lgb-LASSO20-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred, delimiter = ',')
# lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/LightGBM.pkl', 'rb'))
# external_test_pred=lgbt.predict(external_test)
# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-lgb-RFERF19-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.41      0.23      0.30        30
#     EGFR_E21       0.50      0.70      0.58        33
#
#     accuracy                           0.48        63
#    macro avg       0.46      0.47      0.44        63
# weighted avg       0.46      0.48      0.45        63
#
# precision 0.5 accuracy 0.47619047619047616 recall 0.696969696969697 auc 0.4651515151515152

# %%
##lgb 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
##lgb 测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 7 23]
#  [10 23]]
# Normalized confusion matrix
# [[0.23 0.77]
#  [0.3  0.7 ]]

# %%
#lgb 测试集2
import numpy as np
# # Load the model that we saved before
pathpkl = '/RFE-RF-GB/LASSO20/LightGBM.pkl'
finalpkl =  OSPath + pathpkl
lgbt = pickle.load(open(finalpkl, 'rb'))
external_test_pred1=lgbt.predict(external_test1)
path = '/RFE-RF-GB/ex-test1-for-auc-dca-lgb-LASSO20-73.csv'
pathaucfinal = OSPath + path
np.savetxt(pathaucfinal, external_test_pred1, delimiter = ',')

# lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFERF19/LightGBM.pkl', 'rb'))
# external_test_pred1=lgbt.predict(external_test1)

# np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-lgb-RFERF19-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.33      0.07      0.12        27
#     EGFR_E21       0.38      0.79      0.51        19
#
#     accuracy                           0.37        46
#    macro avg       0.35      0.43      0.31        46
# weighted avg       0.35      0.37      0.28        46
#
# precision 0.375 accuracy 0.3695652173913043 recall 0.7894736842105263 auc 0.4317738791423002

# %%
#lgb 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 2 25]
#  [ 4 15]]
# Normalized confusion matrix
# [[0.07 0.93]
#  [0.21 0.79]]

# %%
# # Visualization of Results --> Feature Importances
# plot_feature_importances(lgbt)
# # report_results_quickly(lgbm_tuned)
# plot_results(lgbt)
# # plot_learning_curve(lgbm_tuned)
