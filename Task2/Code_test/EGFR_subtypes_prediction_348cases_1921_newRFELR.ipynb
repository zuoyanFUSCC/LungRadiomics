# %%
import pandas as pd
import numpy as np
import os
print("文件列表：",os.listdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921"))
data = pd.ExcelFile("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/348cases_1921_FS_results.xlsx")#, sheet_name='g1rfegb12'
sheet_names = data.sheet_names
print("列表名：",sheet_names )
# Out:
# 文件列表： ['348cases_1921_FS_results.xlsx', 'FINAL3CENTER349_COMBAT1921.csv', 'FS-RFE', 'FUSCC-zscore-MI.csv', 'FUSCC.csv', 'hrfs', 'hrfs_clinic', 'HRFS_CLINIC_FS', 'HRFS_FS', 'internaltest.csv', 'internaltest1921new.csv', 'internaltest1921new_zscore-MI.csv', 'internaltest1921new_zscore.csv', 'internaltest_fe.csv', 'internaltest_label.csv', 'MIzsore1921-new20231.csv', 'new2023', 'raw', 'RFselect1921-auc-MI2023.csv', 'testrj.csv', 'testrj1921new.csv', 'testrj1921new_zscore.csv', 'testxk.csv', 'testxk1921new.csv', 'testxk1921new_zscore.csv', 'train.csv', 'train1921new.csv', 'train1921newZscore-MI.csv', 'train1921new_zscore1.csv', 'trainZscore-MI-1921-LGBfeatureimportance-1.csv', 'trainZscore-MI-1921-RFfeatureimportance-1.csv', 'trainZscore-MI-1921-XGBfeatureimportance-1.csv', 'trainZscore-MI-SBS-LGB2023.csv', 'trainZscore-MI-SBS-LR2023.csv', 'trainZscore-MI-SBS-RF2023.csv', 'trainZscore-MI-SBS-XGB2023.csv', 'trainZscore-MI-SFS-LGBM2023.csv', 'trainZscore-MI-SFS-LR2023.csv', 'trainZscore-MI-SFS-RF2023.csv', 'trainZscore-MI-SFS-XGB2023.csv', 'train_fe.csv', 'train_label.csv', 'XtrainZscore-MI-RFE.csv']
# 列表名： ['preprossess', 'MI', 'mrmr50', 'LASSO', 'RFE-LIGBTGBM', 'RFE-XGB10', 'RFE-RF', 'RFE-LR', 'SFS-LIGHTGBM', 'SFS-XGB', 'SFS-RF', 'SFS-LR', 'SBS-LIGHTGBM', 'SBS-XGB', 'SBS-RF', 'SBS-LR', 'MI2', 'MRMR50-1', 'RFE-NGB19', 'RFE-CGB14', 'RFE-GB25', 'RFE-XGB27', 'RFE-XGB4', 'RFE-DT7', 'RFE-ADB25', 'LASSO20', 'RF30', 'RF20', 'RFE-Ridge', 'RF2-20', 'RF-FI', 'XGB-FI', 'LGB-FI', 'XGB-FI21', 'KNN20', 'RF2', 'STACK']

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test_label.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
name = 'RFE-LR'
data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/348cases_1921_FS_results.xlsx", sheet_name=name)

data.keys()
train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/FUSCC-zscore-MI.csv")
test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxk1921new_zscore.csv")
test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj1921new_zscore.csv")
train=train[data.keys()]
train.shape
test=test[data.keys()]
test.shape
test1=test1[data.keys()]
test1.shape

train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/trainZscore-RFE-LR.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF11.csv",index=None)


# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF19.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF5.csv",index=None)
test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testxkZscore-RFE-LR.csv",index=None)


# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testrjZscore-RFE-LR.csv",index=None)

# %%
test.shape
# Out:
# (63, 27)

# %%
test1.shape
# Out:
# (46, 27)

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxkraw-fs-preprosess.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj-fs-preprosess.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# # data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
# data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/EGFR1921-767cases-FS-results.xlsx", sheet_name='RFERF19')
# data.keys()
# train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore.csv")
# test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxk1921new_zscore.csv")
# test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj1921new_zscore.csv")
# train=train[data.keys()]
# train.shape
# test=test[data.keys()]
# test.shape
# test1=test1[data.keys()]
# test1.shape

# # train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-1.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF14.csv",index=None)
# # train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-42.csv",index=None)


# # test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-1.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF14.csv",index=None)
# # test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-42.csv",index=None)


# # test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-1.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF14.csv",index=None)
# # test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-42.csv",index=None)

# %%
#%% load liabrary
import os
import numpy as np
import xlrd
import scipy.io as io
import pandas as pd
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFE
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit, train_test_split
from sklearn.linear_model import Lasso, Ridge, LassoCV,LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn import metrics
import itertools
import joblib
from scipy import stats
from sklearn import preprocessing
print("Import library done.\n")
# Out:
# Import library done.

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test_label.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# DIABETES PREDICTION MODEL

# CLASSIFICATION MODELS - HOLDOUT

'''
Steps to follow:
    - Load the saved dataset
    - General View
    - Modeling
        - Base models: LogisticRegression, GaussianNB, KNeighborsClassifier, SVC, MLPClassifier, DecisionTreeClassifier,
                       BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,
                       XGBClassifier, LGBMClassifier, CatBoostClassifier, NGBClassifier
    - Model Evaluation
    - Model Tuning
    - Model Results
'''

# Import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


# Load the preprocessed dataset
# diabetes_preprocessed = pd.read_csv('./diabetes_prepared.csv')

# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-1.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFEGB8.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-42.csv",index=None)

# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rferf17.csv")
# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rfegb5.csv")
pathfuscc="C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/trainZscore-RFE-LR.csv"
diabetes_preprocessed = pd.read_csv(pathfuscc)




# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/Results_HRFS01/catboost/train.csv")
df = diabetes_preprocessed.copy()
# df = df.drop(columns="id",axis=1)

## GENERAL VIEW

df.head()
df.shape
df.info()
df.columns
df.index
df.describe([0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 27 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   PET_wavelet.LHL_firstorder_Kurtosis                           239 non-null    float64
#  1   CT_wavelet2.LHH_glszm_SizeZoneNonUniformityNormalized         239 non-null    float64
#  2   PET_wavelet.HLL_glcm_ClusterShade                             239 non-null    float64
#  3   CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniformityNormalized  239 non-null    float64
#  4   PET_wavelet.LLH_firstorder_Skewness                           239 non-null    float64
#  5   CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis                    239 non-null    float64
#  6   PET_wavelet.HLH_firstorder_Mean                               239 non-null    float64
#  7   PET_exponential_glszm_SizeZoneNonUniformityNormalized         239 non-null    float64
#  8   PET_wavelet2.LLL_gldm_LargeDependenceLowGrayLevelEmphasis     239 non-null    float64
#  9   PET_lbp.3D.m2_firstorder_InterquartileRange                   239 non-null    float64
#  10  PET_wavelet.HLL_ngtdm_Contrast                                239 non-null    float64
#  11  PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis                   239 non-null    float64
#  12  CT_wavelet.HLH_glcm_Idmn                                      239 non-null    float64
#  13  PET_square_gldm_DependenceVariance                            239 non-null    float64
#  14  PET_wavelet.HHH_glcm_Imc1                                     239 non-null    float64
#  15  CT_wavelet2.HLH_glszm_SizeZoneNonUniformityNormalized         239 non-null    float64
#  16  CT_wavelet.HHH_firstorder_Median                              239 non-null    float64
#  17  PET_lbp.3D.m2_firstorder_90Percentile                         239 non-null    float64
#  18  CT_wavelet2.HHH_glszm_SmallAreaEmphasis                       239 non-null    float64
#  19  CT_log.sigma.3.0.mm.3D_firstorder_10Percentile                239 non-null    float64
#  20  PET_lbp.3D.m1_firstorder_InterquartileRange                   239 non-null    float64
#  21  CT_logarithm_firstorder_Maximum                               239 non-null    float64
#  22  CT_wavelet.LLH_firstorder_90Percentile                        239 non-null    float64
#  23  CT_logarithm_glcm_Contrast                                    239 non-null    float64
#  24  CT_original_shape_Elongation                                  239 non-null    float64
#  25  CT_wavelet.LHL_firstorder_Median                              239 non-null    float64
#  26  label                                                         239 non-null    int64
# dtypes: float64(26), int64(1)
# memory usage: 50.5 KB
#                                                      count   mean   std  \
# PET_wavelet.LHL_firstorder_Kurtosis                239.000 -0.000 1.002
# CT_wavelet2.LHH_glszm_SizeZoneNonUniformityNorm... 239.000 -0.000 1.002
# PET_wavelet.HLL_glcm_ClusterShade                  239.000  0.000 1.002
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... 239.000  0.000 1.002
# PET_wavelet.LLH_firstorder_Skewness                239.000  0.000 1.002
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         239.000 -0.000 1.002
# PET_wavelet.HLH_firstorder_Mean                    239.000 -0.000 1.002
# PET_exponential_glszm_SizeZoneNonUniformityNorm... 239.000  0.000 1.002
# PET_wavelet2.LLL_gldm_LargeDependenceLowGrayLev... 239.000 -0.000 1.002
# PET_lbp.3D.m2_firstorder_InterquartileRange        239.000 -0.000 1.002
# PET_wavelet.HLL_ngtdm_Contrast                     239.000 -0.000 1.002
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        239.000 -0.000 1.002
# CT_wavelet.HLH_glcm_Idmn                           239.000  0.000 1.002
# PET_square_gldm_DependenceVariance                 239.000 -0.000 1.002
# PET_wavelet.HHH_glcm_Imc1                          239.000 -0.000 1.002
# CT_wavelet2.HLH_glszm_SizeZoneNonUniformityNorm... 239.000  0.000 1.002
# CT_wavelet.HHH_firstorder_Median                   239.000 -0.000 1.002
# PET_lbp.3D.m2_firstorder_90Percentile              239.000  0.000 1.002
# CT_wavelet2.HHH_glszm_SmallAreaEmphasis            239.000  0.000 1.002
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     239.000 -0.000 1.002
# PET_lbp.3D.m1_firstorder_InterquartileRange        239.000  0.000 1.002
# CT_logarithm_firstorder_Maximum                    239.000 -0.000 1.002
# CT_wavelet.LLH_firstorder_90Percentile             239.000 -0.000 1.002
# CT_logarithm_glcm_Contrast                         239.000 -0.000 1.002
# CT_original_shape_Elongation                       239.000  0.000 1.002
# CT_wavelet.LHL_firstorder_Median                   239.000  0.000 1.002
# label                                              239.000  0.552 0.498
#
#                                                       min    10%    25%  \
# PET_wavelet.LHL_firstorder_Kurtosis                -0.864 -0.733 -0.629
# CT_wavelet2.LHH_glszm_SizeZoneNonUniformityNorm... -2.282 -1.333 -0.666
# PET_wavelet.HLL_glcm_ClusterShade                  -9.143 -0.248  0.064
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... -2.364 -1.191 -0.672
# PET_wavelet.LLH_firstorder_Skewness                -3.769 -0.996 -0.453
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         -1.788 -0.978 -0.697
# PET_wavelet.HLH_firstorder_Mean                    -3.261 -1.057 -0.465
# PET_exponential_glszm_SizeZoneNonUniformityNorm... -2.757 -1.294 -0.622
# PET_wavelet2.LLL_gldm_LargeDependenceLowGrayLev... -0.644 -0.549 -0.407
# PET_lbp.3D.m2_firstorder_InterquartileRange        -1.866 -1.133 -0.512
# PET_wavelet.HLL_ngtdm_Contrast                     -0.536 -0.360 -0.315
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        -1.676 -0.875 -0.665
# CT_wavelet.HLH_glcm_Idmn                           -4.743 -1.116 -0.462
# PET_square_gldm_DependenceVariance                 -0.689 -0.569 -0.446
# PET_wavelet.HHH_glcm_Imc1                          -5.513 -1.106 -0.163
# CT_wavelet2.HLH_glszm_SizeZoneNonUniformityNorm... -2.319 -1.108 -0.564
# CT_wavelet.HHH_firstorder_Median                   -6.762 -0.717 -0.225
# PET_lbp.3D.m2_firstorder_90Percentile              -3.116 -1.458 -0.489
# CT_wavelet2.HHH_glszm_SmallAreaEmphasis            -1.716 -1.557 -0.636
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     -2.861 -1.140 -0.605
# PET_lbp.3D.m1_firstorder_InterquartileRange        -1.723 -0.830 -0.781
# CT_logarithm_firstorder_Maximum                    -4.874 -0.273 -0.080
# CT_wavelet.LLH_firstorder_90Percentile             -1.797 -1.135 -0.639
# CT_logarithm_glcm_Contrast                         -1.803 -1.422 -0.659
# CT_original_shape_Elongation                       -3.701 -1.272 -0.683
# CT_wavelet.LHL_firstorder_Median                   -5.576 -0.768 -0.259
# label                                               0.000  0.000  0.000
#
#                                                       50%    75%   90%   95%  \
# PET_wavelet.LHL_firstorder_Kurtosis                -0.382  0.349 1.076 1.563
# CT_wavelet2.LHH_glszm_SizeZoneNonUniformityNorm...  0.004  0.648 1.306 1.568
# PET_wavelet.HLL_glcm_ClusterShade                   0.087  0.198 0.322 0.366
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... -0.105  0.622 1.301 1.732
# PET_wavelet.LLH_firstorder_Skewness                -0.042  0.353 1.217 1.631
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         -0.189  0.546 1.057 1.820
# PET_wavelet.HLH_firstorder_Mean                    -0.105  0.441 1.096 1.721
# PET_exponential_glszm_SizeZoneNonUniformityNorm...  0.076  0.651 1.102 1.526
# PET_wavelet2.LLL_gldm_LargeDependenceLowGrayLev... -0.262 -0.003 0.497 1.406
# PET_lbp.3D.m2_firstorder_InterquartileRange        -0.113  0.346 1.064 2.035
# PET_wavelet.HLL_ngtdm_Contrast                     -0.251 -0.093 0.286 1.230
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        -0.279  0.337 1.216 2.116
# CT_wavelet.HLH_glcm_Idmn                            0.196  0.673 0.997 1.220
# PET_square_gldm_DependenceVariance                 -0.287  0.084 0.752 1.382
# PET_wavelet.HHH_glcm_Imc1                           0.282  0.594 0.717 0.796
# CT_wavelet2.HLH_glszm_SizeZoneNonUniformityNorm... -0.062  0.479 1.172 1.775
# CT_wavelet.HHH_firstorder_Median                    0.058  0.354 0.793 1.219
# PET_lbp.3D.m2_firstorder_90Percentile               0.231  0.678 0.997 1.183
# CT_wavelet2.HHH_glszm_SmallAreaEmphasis            -0.023  0.715 1.343 1.604
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     -0.077  0.560 1.238 1.724
# PET_lbp.3D.m1_firstorder_InterquartileRange        -0.348  0.508 1.401 2.246
# CT_logarithm_firstorder_Maximum                     0.096  0.339 0.715 1.098
# CT_wavelet.LLH_firstorder_90Percentile             -0.202  0.516 1.572 1.913
# CT_logarithm_glcm_Contrast                         -0.008  0.662 1.319 1.762
# CT_original_shape_Elongation                        0.131  0.719 1.245 1.378
# CT_wavelet.LHL_firstorder_Median                    0.002  0.302 0.828 1.320
# label                                               1.000  1.000 1.000 1.000
#
#                                                      99%   max
# PET_wavelet.LHL_firstorder_Kurtosis                4.190 5.439
# CT_wavelet2.LHH_glszm_SizeZoneNonUniformityNorm... 2.023 3.559
# PET_wavelet.HLL_glcm_ClusterShade                  2.499 4.735
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... 2.656 3.702
# PET_wavelet.LLH_firstorder_Skewness                3.157 3.803
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         2.810 5.732
# PET_wavelet.HLH_firstorder_Mean                    2.805 4.929
# PET_exponential_glszm_SizeZoneNonUniformityNorm... 2.814 2.814
# PET_wavelet2.LLL_gldm_LargeDependenceLowGrayLev... 4.631 7.786
# PET_lbp.3D.m2_firstorder_InterquartileRange        3.596 3.943
# PET_wavelet.HLL_ngtdm_Contrast                     5.051 9.074
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        3.786 4.519
# CT_wavelet.HLH_glcm_Idmn                           1.504 1.583
# PET_square_gldm_DependenceVariance                 4.915 7.252
# PET_wavelet.HHH_glcm_Imc1                          0.871 0.890
# CT_wavelet2.HLH_glszm_SizeZoneNonUniformityNorm... 2.888 3.268
# CT_wavelet.HHH_firstorder_Median                   2.451 6.037
# PET_lbp.3D.m2_firstorder_90Percentile              1.476 1.977
# CT_wavelet2.HHH_glszm_SmallAreaEmphasis            2.025 2.112
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     2.835 3.083
# PET_lbp.3D.m1_firstorder_InterquartileRange        3.032 3.652
# CT_logarithm_firstorder_Maximum                    1.570 2.570
# CT_wavelet.LLH_firstorder_90Percentile             2.715 3.079
# CT_logarithm_glcm_Contrast                         2.303 2.852
# CT_original_shape_Elongation                       1.680 1.811
# CT_wavelet.LHL_firstorder_Median                   2.924 5.248
# label                                              1.000 1.000

# %%
# Check for missing values
df.isnull().values.any()
df.isnull().sum().sort_values(ascending=False)
# Out:
# PET_wavelet.LHL_firstorder_Kurtosis                             0
# PET_wavelet.HHH_glcm_Imc1                                       0
# CT_wavelet.LHL_firstorder_Median                                0
# CT_original_shape_Elongation                                    0
# CT_logarithm_glcm_Contrast                                      0
# CT_wavelet.LLH_firstorder_90Percentile                          0
# CT_logarithm_firstorder_Maximum                                 0
# PET_lbp.3D.m1_firstorder_InterquartileRange                     0
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile                  0
# CT_wavelet2.HHH_glszm_SmallAreaEmphasis                         0
# PET_lbp.3D.m2_firstorder_90Percentile                           0
# CT_wavelet.HHH_firstorder_Median                                0
# CT_wavelet2.HLH_glszm_SizeZoneNonUniformityNormalized           0
# PET_square_gldm_DependenceVariance                              0
# CT_wavelet2.LHH_glszm_SizeZoneNonUniformityNormalized           0
# CT_wavelet.HLH_glcm_Idmn                                        0
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis                     0
# PET_wavelet.HLL_ngtdm_Contrast                                  0
# PET_lbp.3D.m2_firstorder_InterquartileRange                     0
# PET_wavelet2.LLL_gldm_LargeDependenceLowGrayLevelEmphasis       0
# PET_exponential_glszm_SizeZoneNonUniformityNormalized           0
# PET_wavelet.HLH_firstorder_Mean                                 0
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis                      0
# PET_wavelet.LLH_firstorder_Skewness                             0
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniformityNormalized    0
# PET_wavelet.HLL_glcm_ClusterShade                               0
# label                                                           0
# dtype: int64

# %%
# MODELING


# Define dependent and independent variables
y = df["label"]
X = df.drop(["label"], axis=1)

# y = df["Outcome"]
# X = df.drop(["Outcome"], axis=1)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# See the results for base models

base_models = [('LogisticRegression', LogisticRegression()),
               ('Naive Bayes', GaussianNB()),
               ('KNN', KNeighborsClassifier()),
               ('SVM', SVC()),
               ('ANN', MLPClassifier()),
               ('CART', DecisionTreeClassifier()),
               ('BaggedTrees', BaggingClassifier()),
               ('RF', RandomForestClassifier()),
               ('AdaBoost', AdaBoostClassifier()),
               ('GBM', GradientBoostingClassifier()),
               ("XGBoost", XGBClassifier()),
               ("LightGBM", LGBMClassifier()),
               ("CatBoost", CatBoostClassifier(verbose=False)),
               ("NGBoost", NGBClassifier(verbose=False))]

# %%
evaluate_classification_model_holdout(base_models)
# LogisticRegression: 0.805195
# Naive Bayes: 0.603896
# KNN: 0.850649
# SVM: 0.837662
# ANN: 0.850649
# CART: 0.824675
# BaggedTrees: 0.857143
# RF: 0.876623
# AdaBoost: 0.883117
# GBM: 0.870130
# XGBoost: 0.883117
# LightGBM: 0.857143
# CatBoost: 0.863636
# NGBoost: 0.863636
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.582239
# Naive Bayes: 0.658301
# KNN: 0.583784
# SVM: 0.594208
# ANN: 0.581467
# CART: 0.579923
# BaggedTrees: 0.540927
# RF: 0.674517
# AdaBoost: 0.513127
# GBM: 0.525869
# XGBoost: 0.525097
# LightGBM: 0.554440
# CatBoost: 0.592664
# NGBoost: 0.633205
#
# ################ Train and test results for the model: ################
#
#                 models  accuracy_train  accuracy_test
# 0   LogisticRegression           0.841          0.582
# 1          Naive Bayes           0.657          0.658
# 2                  KNN           0.752          0.584
# 3                  SVM           0.934          0.594
# 4                  ANN           0.995          0.581
# 5                 CART           1.000          0.580
# 6          BaggedTrees           0.984          0.541
# 7                   RF           1.000          0.675
# 8             AdaBoost           0.995          0.513
# 9                  GBM           1.000          0.526
# 10             XGBoost           1.000          0.525
# 11            LightGBM           1.000          0.554
# 12            CatBoost           1.000          0.593
# 13             NGBoost           0.972          0.633

# %%
# Final Model
logreg_tuned = LogisticRegression(**logreg_cv_model.best_params_).fit(X_train, y_train)
y_pred = logreg_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8051948051948052
roc_auc_score(y_test, y_pred)
# Out:
# 0.5409266409266409

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-RFE-LR-LR73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-RFE-LR-LR73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.53      0.51      0.52        35
#     EGFR E21       0.55      0.57      0.56        37
#
#     accuracy                           0.54        72
#    macro avg       0.54      0.54      0.54        72
# weighted avg       0.54      0.54      0.54        72
#
# precision 0.5526315789473685 accuracy 0.5416666666666666 recall 0.5675675675675675 auc 0.5409266409266409

# %%
# Visualization of Results
# plot_feature_importances(logreg_tuned)
plot_results(logreg_tuned)
report_results_quickly(logreg_tuned)
plot_learning_curve(logreg_tuned)

# %%
# Final Model
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
rf_tuned = RandomForestClassifier(**rf_cv_model.best_params_).fit(X_train, y_train)
y_pred = rf_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8831168831168831
roc_auc_score(y_test, y_pred)
# Out:
# 0.5474903474903474

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-RFE-LR-RF73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-RFE-LR-RF73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.60      0.26      0.36        35
#     EGFR E21       0.54      0.84      0.66        37
#
#     accuracy                           0.56        72
#    macro avg       0.57      0.55      0.51        72
# weighted avg       0.57      0.56      0.51        72
#
# precision 0.543859649122807 accuracy 0.5555555555555556 recall 0.8378378378378378 auc 0.5474903474903474

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(rf_tuned)
report_results_quickly(rf_tuned)
plot_results(rf_tuned)
plot_learning_curve(rf_tuned)

# %%
# Final Model
xgb_tuned = XGBClassifier(**xgb_cv_model.best_params_).fit(X_train, y_train)
y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.5416666666666666

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-RFE-LR-XGB73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-RFE-LR-XGB73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.53      0.49      0.51        35
#     EGFR E21       0.55      0.59      0.57        37
#
#     accuracy                           0.54        72
#    macro avg       0.54      0.54      0.54        72
# weighted avg       0.54      0.54      0.54        72
#
# precision 0.55 accuracy 0.5416666666666666 recall 0.5945945945945946 auc 0.5401544401544403

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(xgb_tuned)
report_results_quickly(xgb_tuned)
plot_results(xgb_tuned)
# plot_learning_curve(xgb_tuned)

# %%
# Final Model
lgbm_tuned = LGBMClassifier(**lgbm_cv_model.best_params_).fit(X_train, y_train)
y_pred = lgbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.5277777777777778

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-RFE-LR-lgb73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-RFE-LR-lgb73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.52      0.46      0.48        35
#     EGFR E21       0.54      0.59      0.56        37
#
#     accuracy                           0.53        72
#    macro avg       0.53      0.53      0.52        72
# weighted avg       0.53      0.53      0.53        72
#
# precision 0.5365853658536586 accuracy 0.5277777777777778 recall 0.5945945945945946 auc 0.5258687258687259

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(lgbm_tuned)
# report_results_quickly(lgbm_tuned)
plot_results(lgbm_tuned)
# plot_learning_curve(lgbm_tuned)

# %%
# Pickle Models --> Saving tuned models

# Create a folder named 'Models'
# save working directory
#
# cur_dir = os.getcwd()
# cur_dir
#
# # change working directory:
os.chdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFE-LR")
#
# # Save the models
for model in tuned_models:
    pickle.dump(model[1], open(str(model[0]) + ".pkl", 'wb'))

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-1.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFEGB8.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-42.csv",index=None)


external_test=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testxkZscore-RFE-LR.csv")
external_test_label = external_test.label
# print(external_test_label)
external_test=external_test.drop(columns=['label'])

# %%
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-1.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFEGB8.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-42.csv",index=None)


external_test1=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testrjZscore-RFE-LR.csv")
external_test_label1 = external_test1.label
# print(external_test_label)
external_test1=external_test1.drop(columns=['label'])

# %%
######XGB  测试集1
import numpy as np
import pickle
# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFE-LR/XGBoost.pkl', 'rb'))
external_test_pred=xgb.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-xgb-RFE-LR-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.44      0.53      0.48        30
#     EGFR_E21       0.48      0.39      0.43        33
#
#     accuracy                           0.46        63
#    macro avg       0.46      0.46      0.46        63
# weighted avg       0.46      0.46      0.46        63
#
# precision 0.48148148148148145 accuracy 0.4603174603174603 recall 0.3939393939393939 auc 0.4636363636363636

# %%
######XGB  测试集1
#############画图部分
# from sklearn.datasets import load_breast_cancer
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
import pylab as plt
import warnings;warnings.filterwarnings('ignore')
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for XGBClassifier')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
######XGB  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[16 14]
#  [20 13]]
# Normalized confusion matrix
# [[0.53 0.47]
#  [0.61 0.39]]

# %%
#####XGB  测试集2

import numpy as np

# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFE-LR/XGBoost.pkl', 'rb'))
external_test_pred1=xgb.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-xgb-RFE-LR-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.77      0.37      0.50        27
#     EGFR_E21       0.48      0.84      0.62        19
#
#     accuracy                           0.57        46
#    macro avg       0.63      0.61      0.56        46
# weighted avg       0.65      0.57      0.55        46
#
# precision 0.48484848484848486 accuracy 0.5652173913043478 recall 0.8421052631578947 auc 0.6062378167641325

# %%
#####XGB  测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for XGBClassifier')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####XGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[10 17]
#  [ 3 16]]
# Normalized confusion matrix
# [[0.37 0.63]
#  [0.16 0.84]]

# %%
#####RF  测试集1
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFE-LR/RF.pkl', 'rb'))
external_test_pred=rft.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-RF-RFE-LR-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.50      0.27      0.35        30
#     EGFR_E21       0.53      0.76      0.62        33
#
#     accuracy                           0.52        63
#    macro avg       0.52      0.51      0.49        63
# weighted avg       0.52      0.52      0.49        63
#
# precision 0.5319148936170213 accuracy 0.5238095238095238 recall 0.7575757575757576 auc 0.5121212121212121

# %%
#####RF  测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####RF  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 8 22]
#  [ 8 25]]
# Normalized confusion matrix
# [[0.27 0.73]
#  [0.24 0.76]]

# %%
#####RF  测试集2
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFE-LR/RF.pkl', 'rb'))
external_test_pred1=rft.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-RF-RFE-LR-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# precision 0.5135135135135135 accuracy 0.49206349206349204 recall 0.5757575757575758 auc 0.5696969696969697
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.80      0.30      0.43        27
#     EGFR_E21       0.47      0.89      0.62        19
#
#     accuracy                           0.54        46
#    macro avg       0.64      0.60      0.53        46
# weighted avg       0.66      0.54      0.51        46
#
# precision 0.4722222222222222 accuracy 0.5434782608695652 recall 0.8947368421052632 auc 0.5955165692007798

# %%
#####rf  测试集2

fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####rf  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 8 19]
#  [ 2 17]]
# Normalized confusion matrix
# [[0.3  0.7 ]
#  [0.11 0.89]]

# %%
######LR 测试集1
import numpy as np
# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFE-LR/LogisticRegression.pkl', 'rb'))
external_test_pred=lrt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-lr-RFE-LR-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.42      0.37      0.39        30
#     EGFR_E21       0.49      0.55      0.51        33
#
#     accuracy                           0.46        63
#    macro avg       0.45      0.46      0.45        63
# weighted avg       0.46      0.46      0.46        63
#
# precision 0.4864864864864865 accuracy 0.4603174603174603 recall 0.5454545454545454 auc 0.45606060606060606

# %%
######LR 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[11 19]
#  [15 18]]
# Normalized confusion matrix
# [[0.37 0.63]
#  [0.45 0.55]]

# %%
######LR 测试集2
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFE-LR/LogisticRegression.pkl', 'rb'))
external_test_pred1=lrt.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-lr-RFE-LR-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.61      0.41      0.49        27
#     EGFR_E21       0.43      0.63      0.51        19
#
#     accuracy                           0.50        46
#    macro avg       0.52      0.52      0.50        46
# weighted avg       0.54      0.50      0.50        46
#
# precision 0.42857142857142855 accuracy 0.5 recall 0.631578947368421 auc 0.5194931773879142

# %%
######LR 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[11 16]
#  [ 7 12]]
# Normalized confusion matrix
# [[0.41 0.59]
#  [0.37 0.63]]

# %%
##lgb 测试集1
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFE-LR/LightGBM.pkl', 'rb'))
external_test_pred=lgbt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-lgb-RFE-LR-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.55      0.60      0.57        30
#     EGFR_E21       0.60      0.55      0.57        33
#
#     accuracy                           0.57        63
#    macro avg       0.57      0.57      0.57        63
# weighted avg       0.57      0.57      0.57        63
#
# precision 0.6 accuracy 0.5714285714285714 recall 0.5454545454545454 auc 0.5727272727272728

# %%
##lgb 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
##lgb 测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[18 12]
#  [15 18]]
# Normalized confusion matrix
# [[0.6  0.4 ]
#  [0.45 0.55]]

# %%
#lgb 测试集2
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/RFE-LR/LightGBM.pkl', 'rb'))
external_test_pred1=lgbt.predict(external_test1)

np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-lgb-RFE-LR-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.58      0.26      0.36        27
#     EGFR_E21       0.41      0.74      0.53        19
#
#     accuracy                           0.46        46
#    macro avg       0.50      0.50      0.44        46
# weighted avg       0.51      0.46      0.43        46
#
# precision 0.4117647058823529 accuracy 0.45652173913043476 recall 0.7368421052631579 auc 0.49805068226120863

# %%
#lgb 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 7 20]
#  [ 5 14]]
# Normalized confusion matrix
# [[0.26 0.74]
#  [0.26 0.74]]

# %%
# # Visualization of Results --> Feature Importances
# plot_feature_importances(lgbt)
# # report_results_quickly(lgbm_tuned)
# plot_results(lgbt)
# # plot_learning_curve(lgbm_tuned)
