# %%
import pandas as pd
import numpy as np
import os
print("文件列表：",os.listdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921"))
data = pd.ExcelFile("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/348cases_1921_FS_results.xlsx")#, sheet_name='g1rfegb12'
sheet_names = data.sheet_names
print("列表名：",sheet_names )
# Out:
# 文件列表： ['348cases_1921_FS_results.xlsx', 'FINAL3CENTER349_COMBAT1921.csv', 'FS-RFE', 'FUSCC-zscore-MI.csv', 'FUSCC.csv', 'hrfs', 'hrfs_clinic', 'HRFS_CLINIC_FS', 'HRFS_FS', 'internaltest.csv', 'internaltest1921new.csv', 'internaltest1921new_zscore-MI.csv', 'internaltest1921new_zscore.csv', 'internaltest_fe.csv', 'internaltest_label.csv', 'MIzsore1921-new20231.csv', 'new2023', 'raw', 'RFselect1921-auc-MI2023.csv', 'testrj.csv', 'testrj1921new.csv', 'testrj1921new_zscore.csv', 'testxk.csv', 'testxk1921new.csv', 'testxk1921new_zscore.csv', 'train.csv', 'train1921new.csv', 'train1921newZscore-MI.csv', 'train1921new_zscore1.csv', 'trainZscore-MI-1921-LGBfeatureimportance-1.csv', 'trainZscore-MI-1921-RFfeatureimportance-1.csv', 'trainZscore-MI-1921-XGBfeatureimportance-1.csv', 'trainZscore-MI-SBS-LGB2023.csv', 'trainZscore-MI-SBS-LR2023.csv', 'trainZscore-MI-SBS-RF2023.csv', 'trainZscore-MI-SBS-XGB2023.csv', 'trainZscore-MI-SFS-LGBM2023.csv', 'trainZscore-MI-SFS-LR2023.csv', 'trainZscore-MI-SFS-RF2023.csv', 'trainZscore-MI-SFS-XGB2023.csv', 'train_fe.csv', 'train_label.csv', 'XtrainZscore-MI-RFE.csv', '~$348cases_1921_FS_results.xlsx']
# 列表名： ['preprossess', 'MI', 'mrmr50', 'LASSO', 'RFE-LIGBTGBM', 'RFE-XGB10', 'RFE-RF', 'RFE-LR', 'SFS-LIGHTGBM', 'SFS-XGB', 'SFS-RF', 'SFS-LR', 'SBS-LIGHTGBM', 'SBS-XGB', 'SBS-RF', 'SBS-LR', 'MI2', 'MRMR50-1', 'RFE-NGB19', 'RFE-CGB14', 'RFE-GB25', 'RFE-XGB27', 'RFE-XGB4', 'RFE-DT7', 'RFE-ADB25', 'LASSO20', 'RF30', 'RF20', 'RFE-Ridge', 'RF2-20', 'RF-FI', 'XGB-FI', 'LGB-FI', 'XGB-FI21', 'KNN20', 'RF2', 'STACK', 'LGB20', 'LGB26', 'XGB20', 'XGB20-1', 'RF26', 'SVM13', 'XGB11', 'RF17', 'LGB17', 'LR15']

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test_label.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
name = 'LR20'
data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/348cases_1921_FS_results.xlsx", sheet_name=name)

data.keys()
train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/FUSCC-zscore-MI.csv")
test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxk1921new_zscore.csv")
test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj1921new_zscore.csv")
train=train[data.keys()]
train.shape
test=test[data.keys()]
test.shape
test1=test1[data.keys()]
test1.shape

train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/trainZscore-LR15.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF11.csv",index=None)


# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF19.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF5.csv",index=None)
test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testxkZscore-LR15.csv",index=None)


# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testrjZscore-LR15.csv",index=None)

# %%
test.shape
# Out:
# (63, 21)

# %%
test1.shape
# Out:
# (46, 21)

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxkraw-fs-preprosess.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj-fs-preprosess.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# # data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
# data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/EGFR1921-767cases-FS-results.xlsx", sheet_name='RFERF19')
# data.keys()
# train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore.csv")
# test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testxk1921new_zscore.csv")
# test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testrj1921new_zscore.csv")
# train=train[data.keys()]
# train.shape
# test=test[data.keys()]
# test.shape
# test1=test1[data.keys()]
# test1.shape

# # train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-1.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF14.csv",index=None)
# # train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-42.csv",index=None)


# # test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-1.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF14.csv",index=None)
# # test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-42.csv",index=None)


# # test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-1.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF14.csv",index=None)
# # test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-42.csv",index=None)

# %%
#%% load liabrary
import os
import numpy as np
import xlrd
import scipy.io as io
import pandas as pd
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFE
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit, train_test_split
from sklearn.linear_model import Lasso, Ridge, LassoCV,LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn import metrics
import itertools
import joblib
from scipy import stats
from sklearn import preprocessing
print("Import library done.\n")
# Out:
# Import library done.

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test_label.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# DIABETES PREDICTION MODEL

# CLASSIFICATION MODELS - HOLDOUT

'''
Steps to follow:
    - Load the saved dataset
    - General View
    - Modeling
        - Base models: LogisticRegression, GaussianNB, KNeighborsClassifier, SVC, MLPClassifier, DecisionTreeClassifier,
                       BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,
                       XGBClassifier, LGBMClassifier, CatBoostClassifier, NGBClassifier
    - Model Evaluation
    - Model Tuning
    - Model Results
'''

# Import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


# Load the preprocessed dataset
# diabetes_preprocessed = pd.read_csv('./diabetes_prepared.csv')

# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-1.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFEGB8.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/trainZscore-RFERF17-42.csv",index=None)

# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rferf17.csv")
# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rfegb5.csv")
pathfuscc="C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/trainZscore-LR15.csv"
diabetes_preprocessed = pd.read_csv(pathfuscc)




# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/Results_HRFS01/catboost/train.csv")
df = diabetes_preprocessed.copy()
# df = df.drop(columns="id",axis=1)

## GENERAL VIEW

df.head()
df.shape
df.info()
df.columns
df.index
df.describe([0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 21 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis                    239 non-null    float64
#  1   PET_wavelet.HLH_glcm_Correlation                              239 non-null    float64
#  2   PET_wavelet.HHL_firstorder_Kurtosis                           239 non-null    float64
#  3   CT_wavelet2.HHL_firstorder_Skewness                           239 non-null    float64
#  4   PET_wavelet.HHL_glszm_SizeZoneNonUniformityNormalized         239 non-null    float64
#  5   PET_wavelet2.HLL_firstorder_Skewness                          239 non-null    float64
#  6   CT_log.sigma.3.0.mm.3D_firstorder_10Percentile                239 non-null    float64
#  7   CT_wavelet2.HLH_firstorder_Mean                               239 non-null    float64
#  8   CT_wavelet2.HLH_glcm_ClusterShade                             239 non-null    float64
#  9   CT_original_shape_Elongation                                  239 non-null    float64
#  10  CT_original_shape_Flatness                                    239 non-null    float64
#  11  CT_logarithm_firstorder_Maximum                               239 non-null    float64
#  12  CT_wavelet2.LHH_glcm_ClusterShade                             239 non-null    float64
#  13  PET_wavelet.LHH_firstorder_Kurtosis                           239 non-null    float64
#  14  CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniformityNormalized  239 non-null    float64
#  15  PET_wavelet2.HLH_glszm_SizeZoneNonUniformityNormalized        239 non-null    float64
#  16  CT_wavelet2.HHH_firstorder_Mean                               239 non-null    float64
#  17  PET_square_gldm_DependenceVariance                            239 non-null    float64
#  18  PET_wavelet.LHL_firstorder_Kurtosis                           239 non-null    float64
#  19  CT_wavelet.HHH_firstorder_Median                              239 non-null    float64
#  20  label                                                         239 non-null    int64
# dtypes: float64(20), int64(1)
# memory usage: 39.3 KB
#                                                      count   mean   std  \
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         239.000 -0.000 1.002
# PET_wavelet.HLH_glcm_Correlation                   239.000  0.000 1.002
# PET_wavelet.HHL_firstorder_Kurtosis                239.000  0.000 1.002
# CT_wavelet2.HHL_firstorder_Skewness                239.000 -0.000 1.002
# PET_wavelet.HHL_glszm_SizeZoneNonUniformityNorm... 239.000  0.000 1.002
# PET_wavelet2.HLL_firstorder_Skewness               239.000  0.000 1.002
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     239.000 -0.000 1.002
# CT_wavelet2.HLH_firstorder_Mean                    239.000 -0.000 1.002
# CT_wavelet2.HLH_glcm_ClusterShade                  239.000  0.000 1.002
# CT_original_shape_Elongation                       239.000  0.000 1.002
# CT_original_shape_Flatness                         239.000  0.000 1.002
# CT_logarithm_firstorder_Maximum                    239.000 -0.000 1.002
# CT_wavelet2.LHH_glcm_ClusterShade                  239.000 -0.000 1.002
# PET_wavelet.LHH_firstorder_Kurtosis                239.000  0.000 1.002
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... 239.000  0.000 1.002
# PET_wavelet2.HLH_glszm_SizeZoneNonUniformityNor... 239.000  0.000 1.002
# CT_wavelet2.HHH_firstorder_Mean                    239.000 -0.000 1.002
# PET_square_gldm_DependenceVariance                 239.000 -0.000 1.002
# PET_wavelet.LHL_firstorder_Kurtosis                239.000 -0.000 1.002
# CT_wavelet.HHH_firstorder_Median                   239.000 -0.000 1.002
# label                                              239.000  0.552 0.498
#
#                                                       min    10%    25%  \
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         -1.788 -0.978 -0.697
# PET_wavelet.HLH_glcm_Correlation                   -5.931 -1.149 -0.216
# PET_wavelet.HHL_firstorder_Kurtosis                -1.246 -0.925 -0.668
# CT_wavelet2.HHL_firstorder_Skewness                -8.323 -0.611 -0.255
# PET_wavelet.HHL_glszm_SizeZoneNonUniformityNorm... -1.933 -1.212 -0.779
# PET_wavelet2.HLL_firstorder_Skewness               -4.538 -1.216 -0.292
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     -2.861 -1.140 -0.605
# CT_wavelet2.HLH_firstorder_Mean                    -4.142 -0.981 -0.339
# CT_wavelet2.HLH_glcm_ClusterShade                  -4.905 -0.427 -0.189
# CT_original_shape_Elongation                       -3.701 -1.272 -0.683
# CT_original_shape_Flatness                         -2.196 -1.180 -0.661
# CT_logarithm_firstorder_Maximum                    -4.874 -0.273 -0.080
# CT_wavelet2.LHH_glcm_ClusterShade                  -6.670 -0.480 -0.113
# PET_wavelet.LHH_firstorder_Kurtosis                -1.133 -0.816 -0.665
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... -2.364 -1.191 -0.672
# PET_wavelet2.HLH_glszm_SizeZoneNonUniformityNor... -1.740 -1.160 -0.669
# CT_wavelet2.HHH_firstorder_Mean                    -6.523 -0.781 -0.327
# PET_square_gldm_DependenceVariance                 -0.689 -0.569 -0.446
# PET_wavelet.LHL_firstorder_Kurtosis                -0.864 -0.733 -0.629
# CT_wavelet.HHH_firstorder_Median                   -6.762 -0.717 -0.225
# label                                               0.000  0.000  0.000
#
#                                                       50%   75%   90%   95%  \
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         -0.189 0.546 1.057 1.820
# PET_wavelet.HLH_glcm_Correlation                    0.214 0.520 0.873 1.085
# PET_wavelet.HHL_firstorder_Kurtosis                -0.274 0.325 1.197 2.121
# CT_wavelet2.HHL_firstorder_Skewness                -0.017 0.225 0.701 1.022
# PET_wavelet.HHL_glszm_SizeZoneNonUniformityNorm... -0.028 0.671 1.208 1.596
# PET_wavelet2.HLL_firstorder_Skewness                0.118 0.521 0.905 1.357
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     -0.077 0.560 1.238 1.724
# CT_wavelet2.HLH_firstorder_Mean                    -0.023 0.317 0.870 1.684
# CT_wavelet2.HLH_glcm_ClusterShade                  -0.041 0.104 0.495 1.157
# CT_original_shape_Elongation                        0.131 0.719 1.245 1.378
# CT_original_shape_Flatness                         -0.077 0.479 1.317 1.978
# CT_logarithm_firstorder_Maximum                     0.096 0.339 0.715 1.098
# CT_wavelet2.LHH_glcm_ClusterShade                   0.036 0.158 0.488 0.830
# PET_wavelet.LHH_firstorder_Kurtosis                -0.316 0.332 1.280 2.045
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... -0.105 0.622 1.301 1.732
# PET_wavelet2.HLH_glszm_SizeZoneNonUniformityNor... -0.126 0.615 1.148 1.587
# CT_wavelet2.HHH_firstorder_Mean                    -0.006 0.297 0.905 1.572
# PET_square_gldm_DependenceVariance                 -0.287 0.084 0.752 1.382
# PET_wavelet.LHL_firstorder_Kurtosis                -0.382 0.349 1.076 1.563
# CT_wavelet.HHH_firstorder_Median                    0.058 0.354 0.793 1.219
# label                                               1.000 1.000 1.000 1.000
#
#                                                      99%   max
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis         2.810 5.732
# PET_wavelet.HLH_glcm_Correlation                   1.637 2.065
# PET_wavelet.HHL_firstorder_Kurtosis                3.221 4.933
# CT_wavelet2.HHL_firstorder_Skewness                2.695 6.032
# PET_wavelet.HHL_glszm_SizeZoneNonUniformityNorm... 2.219 5.296
# PET_wavelet2.HLL_firstorder_Skewness               2.340 3.286
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile     2.835 3.083
# CT_wavelet2.HLH_firstorder_Mean                    3.370 4.303
# CT_wavelet2.HLH_glcm_ClusterShade                  3.297 7.827
# CT_original_shape_Elongation                       1.680 1.811
# CT_original_shape_Flatness                         2.904 3.915
# CT_logarithm_firstorder_Maximum                    1.570 2.570
# CT_wavelet2.LHH_glcm_ClusterShade                  3.594 6.669
# PET_wavelet.LHH_firstorder_Kurtosis                3.662 5.779
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniform... 2.656 3.702
# PET_wavelet2.HLH_glszm_SizeZoneNonUniformityNor... 2.758 4.716
# CT_wavelet2.HHH_firstorder_Mean                    2.465 5.629
# PET_square_gldm_DependenceVariance                 4.915 7.252
# PET_wavelet.LHL_firstorder_Kurtosis                4.190 5.439
# CT_wavelet.HHH_firstorder_Median                   2.451 6.037
# label                                              1.000 1.000

# %%
# Check for missing values
df.isnull().values.any()
df.isnull().sum().sort_values(ascending=False)
# Out:
# CT_log.sigma.3.0.mm.3D_firstorder_Kurtosis                      0
# CT_logarithm_firstorder_Maximum                                 0
# CT_wavelet.HHH_firstorder_Median                                0
# PET_wavelet.LHL_firstorder_Kurtosis                             0
# PET_square_gldm_DependenceVariance                              0
# CT_wavelet2.HHH_firstorder_Mean                                 0
# PET_wavelet2.HLH_glszm_SizeZoneNonUniformityNormalized          0
# CT_log.sigma.3.0.mm.3D_glszm_SizeZoneNonUniformityNormalized    0
# PET_wavelet.LHH_firstorder_Kurtosis                             0
# CT_wavelet2.LHH_glcm_ClusterShade                               0
# CT_original_shape_Flatness                                      0
# PET_wavelet.HLH_glcm_Correlation                                0
# CT_original_shape_Elongation                                    0
# CT_wavelet2.HLH_glcm_ClusterShade                               0
# CT_wavelet2.HLH_firstorder_Mean                                 0
# CT_log.sigma.3.0.mm.3D_firstorder_10Percentile                  0
# PET_wavelet2.HLL_firstorder_Skewness                            0
# PET_wavelet.HHL_glszm_SizeZoneNonUniformityNormalized           0
# CT_wavelet2.HHL_firstorder_Skewness                             0
# PET_wavelet.HHL_firstorder_Kurtosis                             0
# label                                                           0
# dtype: int64

# %%
# MODELING


# Define dependent and independent variables
y = df["label"]
X = df.drop(["label"], axis=1)

# y = df["Outcome"]
# X = df.drop(["Outcome"], axis=1)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# See the results for base models

base_models = [('LogisticRegression', LogisticRegression()),
               ('Naive Bayes', GaussianNB()),
               ('KNN', KNeighborsClassifier()),
               ('SVM', SVC()),
               ('ANN', MLPClassifier()),
               ('CART', DecisionTreeClassifier()),
               ('BaggedTrees', BaggingClassifier()),
               ('RF', RandomForestClassifier()),
               ('AdaBoost', AdaBoostClassifier()),
               ('GBM', GradientBoostingClassifier()),
               ("XGBoost", XGBClassifier()),
               ("LightGBM", LGBMClassifier()),
               ("CatBoost", CatBoostClassifier(verbose=False)),
               ("NGBoost", NGBClassifier(verbose=False))]

# %%
evaluate_classification_model_holdout(base_models)
# LogisticRegression: 0.622008
# Naive Bayes: 0.524324
# KNN: 0.559459
# SVM: 0.591892
# ANN: 0.605405
# CART: 0.387645
# BaggedTrees: 0.553668
# RF: 0.607722
# AdaBoost: 0.500386
# GBM: 0.539382
# XGBoost: 0.595753
# LightGBM: 0.568726
# CatBoost: 0.676834
# NGBoost: 0.455985
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.622008
# Naive Bayes: 0.524324
# KNN: 0.559459
# SVM: 0.591892
# ANN: 0.633977
# CART: 0.413127
# BaggedTrees: 0.583012
# RF: 0.609266
# AdaBoost: 0.500386
# GBM: 0.565637
# XGBoost: 0.595753
# LightGBM: 0.568726
# CatBoost: 0.676834
# NGBoost: 0.455985
#
# ################ Train and test results for the model: ################
#
#                 models  accuracy_train  accuracy_test
# 0   LogisticRegression           0.636          0.622
# 1          Naive Bayes           0.629          0.524
# 2                  KNN           0.725          0.559
# 3                  SVM           0.833          0.592
# 4                  ANN           0.911          0.634
# 5                 CART           1.000          0.413
# 6          BaggedTrees           0.993          0.583
# 7                   RF           1.000          0.609
# 8             AdaBoost           0.993          0.500
# 9                  GBM           1.000          0.566
# 10             XGBoost           1.000          0.596
# 11            LightGBM           1.000          0.569
# 12            CatBoost           1.000          0.677
# 13             NGBoost           0.946          0.456

# %%
# For some distance-based models, we need to scale the features in order to
# increase the speed and the performance/accuracy level of the model.
# We can also see the effect of scaling type by changing the sclaer function.
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler

# %%
# Final Model
logreg_tuned = LogisticRegression(**logreg_cv_model.best_params_).fit(X_train, y_train)
y_pred = logreg_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8051948051948052
roc_auc_score(y_test, y_pred)
# Out:
# 0.5444015444015444

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LR15-LR73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-LR15-LR73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.71      0.14      0.24        35
#     EGFR E21       0.54      0.95      0.69        37
#
#     accuracy                           0.56        72
#    macro avg       0.63      0.54      0.46        72
# weighted avg       0.62      0.56      0.47        72
#
# precision 0.5384615384615384 accuracy 0.5555555555555556 recall 0.9459459459459459 auc 0.5444015444015444

# %%
# Visualization of Results
# plot_feature_importances(logreg_tuned)
plot_results(logreg_tuned)
report_results_quickly(logreg_tuned)
plot_learning_curve(logreg_tuned)

# %%
# Final Model
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
rf_tuned = RandomForestClassifier(**rf_cv_model.best_params_).fit(X_train, y_train)
y_pred = rf_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8831168831168831
roc_auc_score(y_test, y_pred)
# Out:
# 0.5656370656370656

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LR15-RF73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-LR15-RF73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.58      0.43      0.49        35
#     EGFR E21       0.57      0.70      0.63        37
#
#     accuracy                           0.57        72
#    macro avg       0.57      0.57      0.56        72
# weighted avg       0.57      0.57      0.56        72
#
# precision 0.5652173913043478 accuracy 0.5694444444444444 recall 0.7027027027027027 auc 0.5656370656370656

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(rf_tuned)
report_results_quickly(rf_tuned)
plot_results(rf_tuned)
plot_learning_curve(rf_tuned)

# %%
# Final Model
xgb_tuned = XGBClassifier(**xgb_cv_model.best_params_).fit(X_train, y_train)
y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.5555555555555556

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LR15-XGB73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-LR15-XGB73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.56      0.43      0.48        35
#     EGFR E21       0.56      0.68      0.61        37
#
#     accuracy                           0.56        72
#    macro avg       0.56      0.55      0.55        72
# weighted avg       0.56      0.56      0.55        72
#
# precision 0.5555555555555556 accuracy 0.5555555555555556 recall 0.6756756756756757 auc 0.5521235521235521

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(xgb_tuned)
report_results_quickly(xgb_tuned)
plot_results(xgb_tuned)
# plot_learning_curve(xgb_tuned)

# %%
# Final Model
lgbm_tuned = LGBMClassifier(**lgbm_cv_model.best_params_).fit(X_train, y_train)
y_pred = lgbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.6388888888888888

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LR15-lgb73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-LR15-lgb73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR E19', 'EGFR E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR E19       0.70      0.46      0.55        35
#     EGFR E21       0.61      0.81      0.70        37
#
#     accuracy                           0.64        72
#    macro avg       0.65      0.63      0.62        72
# weighted avg       0.65      0.64      0.63        72
#
# precision 0.6122448979591837 accuracy 0.6388888888888888 recall 0.8108108108108109 auc 0.6339768339768341

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(lgbm_tuned)
# report_results_quickly(lgbm_tuned)
plot_results(lgbm_tuned)
# plot_learning_curve(lgbm_tuned)

# %%
# Comparison of tuned models
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
tuned_models = [('LogisticRegression', logreg_tuned),
                ('RF', rf_tuned),
                ('XGBoost', xgb_tuned),
                ('LightGBM', lgbm_tuned)
#                ('CatBoost', cb_tuned)
               ]


evaluate_classification_model_holdout(tuned_models)
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.544402
# RF: 0.634749
# XGBoost: 0.552124
# LightGBM: 0.633977
#
# ################ Train and test results for the model: ################
#
#                models  accuracy_train  accuracy_test
# 0  LogisticRegression           0.543          0.544
# 1                  RF           1.000          0.635
# 2             XGBoost           0.986          0.552
# 3            LightGBM           0.837          0.634

# %%
# Pickle Models --> Saving tuned models

# Create a folder named 'Models'
# save working directory
#
# cur_dir = os.getcwd()
# cur_dir
#
# # change working directory:
os.chdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/LR15")
#
# # Save the models
for model in tuned_models:
    pickle.dump(model[1], open(str(model[0]) + ".pkl", 'wb'))

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-1.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFEGB8.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/testZscore-RFERF17-42.csv",index=None)


external_test=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testxkZscore-LR15.csv")
external_test_label = external_test.label
# print(external_test_label)
external_test=external_test.drop(columns=['label'])

# %%
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-1.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFEGB8.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/test1Zscore-RFERF17-42.csv",index=None)


external_test1=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/EGFR1921/new2023/testrjZscore-LR15.csv")
external_test_label1 = external_test1.label
# print(external_test_label)
external_test1=external_test1.drop(columns=['label'])

# %%
######XGB  测试集1
import numpy as np
import pickle
# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/LR15/XGBoost.pkl', 'rb'))
external_test_pred=xgb.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-xgb-LR15-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.52      0.47      0.49        30
#     EGFR_E21       0.56      0.61      0.58        33
#
#     accuracy                           0.54        63
#    macro avg       0.54      0.54      0.54        63
# weighted avg       0.54      0.54      0.54        63
#
# precision 0.5555555555555556 accuracy 0.5396825396825397 recall 0.6060606060606061 auc 0.5363636363636364

# %%
######XGB  测试集1
#############画图部分
# from sklearn.datasets import load_breast_cancer
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
import pylab as plt
import warnings;warnings.filterwarnings('ignore')
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for XGBClassifier')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
######XGB  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[14 16]
#  [13 20]]
# Normalized confusion matrix
# [[0.47 0.53]
#  [0.39 0.61]]

# %%
#####XGB  测试集2

import numpy as np

# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/LR15/XGBoost.pkl', 'rb'))
external_test_pred1=xgb.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-xgb-LR15-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.61      0.41      0.49        27
#     EGFR_E21       0.43      0.63      0.51        19
#
#     accuracy                           0.50        46
#    macro avg       0.52      0.52      0.50        46
# weighted avg       0.54      0.50      0.50        46
#
# precision 0.42857142857142855 accuracy 0.5 recall 0.631578947368421 auc 0.5194931773879142

# %%
#####XGB  测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for XGBClassifier')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####XGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[11 16]
#  [ 7 12]]
# Normalized confusion matrix
# [[0.41 0.59]
#  [0.37 0.63]]

# %%
#####RF  测试集1
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/LR15/RF.pkl', 'rb'))
external_test_pred=rft.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-RF-LR15-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.42      0.27      0.33        30
#     EGFR_E21       0.50      0.67      0.57        33
#
#     accuracy                           0.48        63
#    macro avg       0.46      0.47      0.45        63
# weighted avg       0.46      0.48      0.45        63
#
# precision 0.5 accuracy 0.47619047619047616 recall 0.6666666666666666 auc 0.4666666666666667

# %%
#####RF  测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####RF  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 8 22]
#  [11 22]]
# Normalized confusion matrix
# [[0.27 0.73]
#  [0.33 0.67]]

# %%
#####RF  测试集2
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/LR15/RF.pkl', 'rb'))
external_test_pred1=rft.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-RF-LR15-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# precision 0.5135135135135135 accuracy 0.49206349206349204 recall 0.5757575757575758 auc 0.5696969696969697
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.58      0.26      0.36        27
#     EGFR_E21       0.41      0.74      0.53        19
#
#     accuracy                           0.46        46
#    macro avg       0.50      0.50      0.44        46
# weighted avg       0.51      0.46      0.43        46
#
# precision 0.4117647058823529 accuracy 0.45652173913043476 recall 0.7368421052631579 auc 0.49805068226120863

# %%
#####rf  测试集2

fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####rf  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 7 20]
#  [ 5 14]]
# Normalized confusion matrix
# [[0.26 0.74]
#  [0.26 0.74]]

# %%
######LR 测试集1
import numpy as np
# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/LR15/LogisticRegression.pkl', 'rb'))
external_test_pred=lrt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-lr-LR15-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.40      0.07      0.11        30
#     EGFR_E21       0.52      0.91      0.66        33
#
#     accuracy                           0.51        63
#    macro avg       0.46      0.49      0.39        63
# weighted avg       0.46      0.51      0.40        63
#
# precision 0.5172413793103449 accuracy 0.5079365079365079 recall 0.9090909090909091 auc 0.4878787878787879

# %%
######LR 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 2 28]
#  [ 3 30]]
# Normalized confusion matrix
# [[0.07 0.93]
#  [0.09 0.91]]

# %%
######LR 测试集2
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/LR15/LogisticRegression.pkl', 'rb'))
external_test_pred1=lrt.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-lr-LR15-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.60      0.11      0.19        27
#     EGFR_E21       0.41      0.89      0.57        19
#
#     accuracy                           0.43        46
#    macro avg       0.51      0.50      0.38        46
# weighted avg       0.52      0.43      0.34        46
#
# precision 0.4146341463414634 accuracy 0.43478260869565216 recall 0.8947368421052632 auc 0.5029239766081872

# %%
######LR 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 3 24]
#  [ 2 17]]
# Normalized confusion matrix
# [[0.11 0.89]
#  [0.11 0.89]]

# %%
##lgb 测试集1
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/LR15/LightGBM.pkl', 'rb'))
external_test_pred=lgbt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test-for-auc-dca-lgb-LR15-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.47      0.27      0.34        30
#     EGFR_E21       0.52      0.73      0.61        33
#
#     accuracy                           0.51        63
#    macro avg       0.50      0.50      0.47        63
# weighted avg       0.50      0.51      0.48        63
#
# precision 0.5217391304347826 accuracy 0.5079365079365079 recall 0.7272727272727273 auc 0.496969696969697

# %%
##lgb 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
##lgb 测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 8 22]
#  [ 9 24]]
# Normalized confusion matrix
# [[0.27 0.73]
#  [0.27 0.73]]

# %%
#lgb 测试集2
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/LR15/LightGBM.pkl', 'rb'))
external_test_pred1=lgbt.predict(external_test1)

np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-1921-FS/RFE-RF-GB/ex-test1-for-auc-dca-lgb-LR15-73.csv', external_test_pred1, delimiter = ',')
auc = roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR_E19', 'EGFR_E21']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall,'auc',auc)
# Out:
#               precision    recall  f1-score   support
#
#     EGFR_E19       0.54      0.26      0.35        27
#     EGFR_E21       0.39      0.68      0.50        19
#
#     accuracy                           0.43        46
#    macro avg       0.47      0.47      0.43        46
# weighted avg       0.48      0.43      0.41        46
#
# precision 0.3939393939393939 accuracy 0.43478260869565216 recall 0.6842105263157895 auc 0.47173489278752434

# %%
#lgb 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 7 20]
#  [ 6 13]]
# Normalized confusion matrix
# [[0.26 0.74]
#  [0.32 0.68]]

# %%
# # Visualization of Results --> Feature Importances
# plot_feature_importances(lgbt)
# # report_results_quickly(lgbm_tuned)
# plot_results(lgbt)
# # plot_learning_curve(lgbm_tuned)
