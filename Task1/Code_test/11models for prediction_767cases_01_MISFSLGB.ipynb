# %%
# data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
import pandas as pd
import numpy as np
import os
data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/EGFR01-767cases-FS-results.xlsx",
                     sheet_name='MISFSLGB10-28')
data.keys()
train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore.csv")
test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv")
test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore.csv")
train=train[data.keys()]
train.shape
test=test[data.keys()]
test.shape
test1=test1[data.keys()]
test1.shape
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB10.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17-42.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF19.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-MISFSLGB10-28.csv",index=None)

# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF17.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFEGB10.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFEGB18.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF17-42.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF18.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF19.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF5.csv",index=None)
test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-MISFSLGB10-28.csv",index=None)

# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB10.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17-42.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-MISFSLGB10-28.csv",index=None)

# %%
#%% load liabrary
import os
import numpy as np
import xlrd
import scipy.io as io
import pandas as pd
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFE
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit, train_test_split
from sklearn.linear_model import Lasso, Ridge, LassoCV,LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn import metrics
import itertools
import joblib
from scipy import stats
from sklearn import preprocessing
print("Import library done.\n")
# Out:
# Import library done.

# %%
# DIABETES PREDICTION MODEL

# CLASSIFICATION MODELS - HOLDOUT

'''
Steps to follow:
    - Load the saved dataset
    - General View
    - Modeling
        - Base models: LogisticRegression, GaussianNB, KNeighborsClassifier, SVC, MLPClassifier, DecisionTreeClassifier,
                       BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,
                       XGBClassifier, LGBMClassifier, CatBoostClassifier, NGBClassifier
    - Model Evaluation
    - Model Tuning
    - Model Results
'''

# Import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


# Load the preprocessed dataset
# diabetes_preprocessed = pd.read_csv('./diabetes_prepared.csv')

# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB10.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17-42.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF19.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF11.csv",index=None)

# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rferf17.csv")
# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rfegb5.csv")
diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-MISFSLGB10-28.csv")




# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/Results_HRFS01/catboost/train.csv")
df = diabetes_preprocessed.copy()
# df = df.drop(columns="id",axis=1)

## GENERAL VIEW

df.head()
df.shape
df.info()
df.columns
df.index
df.describe([0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 29 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   CT_lbp.3D.k_firstorder_10Percentile                       587 non-null    float64
#  1   CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized        587 non-null    float64
#  2   CT_lbp.3D.m1_firstorder_10Percentile                      587 non-null    float64
#  3   CT_lbp.3D.m1_firstorder_Minimum                           587 non-null    float64
#  4   CT_lbp.3D.m1_glszm_GrayLevelNonUniformity                 587 non-null    float64
#  5   CT_lbp.3D.m1_glszm_SizeZoneNonUniformity                  587 non-null    float64
#  6   CT_lbp.3D.m1_glszm_ZoneVariance                           587 non-null    float64
#  7   CT_log.sigma.1.0.mm.3D_firstorder_90Percentile            587 non-null    float64
#  8   CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis          587 non-null    float64
#  9   CT_original_shape_Sphericity                              587 non-null    float64
#  10  CT_wavelet.LLH_gldm_LargeDependenceHighGrayLevelEmphasis  587 non-null    float64
#  11  CT_wavelet2.HHH_glcm_ClusterShade                         587 non-null    float64
#  12  CT_wavelet2.HHL_glcm_ClusterShade                         587 non-null    float64
#  13  PET_exponential_glszm_LargeAreaEmphasis                   587 non-null    float64
#  14  PET_exponential_glszm_ZoneVariance                        587 non-null    float64
#  15  PET_log.sigma.1.0.mm.3D_firstorder_90Percentile           587 non-null    float64
#  16  PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis               587 non-null    float64
#  17  PET_log.sigma.1.0.mm.3D_ngtdm_Contrast                    587 non-null    float64
#  18  PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis               587 non-null    float64
#  19  PET_wavelet.HHH_firstorder_10Percentile                   587 non-null    float64
#  20  PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmphasis       587 non-null    float64
#  21  PET_wavelet.HHL_glcm_Idmn                                 587 non-null    float64
#  22  PET_wavelet.HLH_glcm_ClusterShade                         587 non-null    float64
#  23  PET_wavelet.HLL_firstorder_Median                         587 non-null    float64
#  24  PET_wavelet.LHH_firstorder_Kurtosis                       587 non-null    float64
#  25  PET_wavelet2.HHH_glcm_Idmn                                587 non-null    float64
#  26  PET_wavelet2.HLH_glszm_SmallAreaLowGrayLevelEmphasis      587 non-null    float64
#  27  PET_wavelet2.LHH_glszm_SizeZoneNonUniformityNormalized    587 non-null    float64
#  28  label                                                     587 non-null    int64
# dtypes: float64(28), int64(1)
# memory usage: 133.1 KB
#                                                      count   mean   std  \
# CT_lbp.3D.k_firstorder_10Percentile                587.000 -0.000 1.001
# CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized 587.000  0.000 1.001
# CT_lbp.3D.m1_firstorder_10Percentile               587.000  0.000 1.001
# CT_lbp.3D.m1_firstorder_Minimum                    587.000 -0.000 1.001
# CT_lbp.3D.m1_glszm_GrayLevelNonUniformity          587.000  0.000 1.001
# CT_lbp.3D.m1_glszm_SizeZoneNonUniformity           587.000  0.000 1.001
# CT_lbp.3D.m1_glszm_ZoneVariance                    587.000 -0.000 1.001
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile     587.000 -0.000 1.001
# CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis   587.000 -0.000 1.001
# CT_original_shape_Sphericity                       587.000  0.000 1.001
# CT_wavelet.LLH_gldm_LargeDependenceHighGrayLeve... 587.000  0.000 1.001
# CT_wavelet2.HHH_glcm_ClusterShade                  587.000 -0.000 1.001
# CT_wavelet2.HHL_glcm_ClusterShade                  587.000  0.000 1.001
# PET_exponential_glszm_LargeAreaEmphasis            587.000 -0.000 1.001
# PET_exponential_glszm_ZoneVariance                 587.000 -0.000 1.001
# PET_log.sigma.1.0.mm.3D_firstorder_90Percentile    587.000 -0.000 1.001
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        587.000 -0.000 1.001
# PET_log.sigma.1.0.mm.3D_ngtdm_Contrast             587.000 -0.000 1.001
# PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis        587.000  0.000 1.001
# PET_wavelet.HHH_firstorder_10Percentile            587.000 -0.000 1.001
# PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmph... 587.000 -0.000 1.001
# PET_wavelet.HHL_glcm_Idmn                          587.000 -0.000 1.001
# PET_wavelet.HLH_glcm_ClusterShade                  587.000  0.000 1.001
# PET_wavelet.HLL_firstorder_Median                  587.000 -0.000 1.001
# PET_wavelet.LHH_firstorder_Kurtosis                587.000  0.000 1.001
# PET_wavelet2.HHH_glcm_Idmn                         587.000  0.000 1.001
# PET_wavelet2.HLH_glszm_SmallAreaLowGrayLevelEmp... 587.000 -0.000 1.001
# PET_wavelet2.LHH_glszm_SizeZoneNonUniformityNor... 587.000  0.000 1.001
# label                                              587.000  0.576 0.495
#
#                                                       min    10%    25%  \
# CT_lbp.3D.k_firstorder_10Percentile                -2.515 -1.829 -0.125
# CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized -2.875 -1.641 -0.694
# CT_lbp.3D.m1_firstorder_10Percentile               -2.783 -1.165 -0.735
# CT_lbp.3D.m1_firstorder_Minimum                    -0.229 -0.229 -0.229
# CT_lbp.3D.m1_glszm_GrayLevelNonUniformity          -0.428 -0.428 -0.090
# CT_lbp.3D.m1_glszm_SizeZoneNonUniformity           -0.071 -0.071 -0.071
# CT_lbp.3D.m1_glszm_ZoneVariance                    -0.199 -0.199 -0.054
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile     -3.240 -1.192 -0.581
# CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis   -1.661 -0.781 -0.592
# CT_original_shape_Sphericity                       -3.160 -1.278 -0.636
# CT_wavelet.LLH_gldm_LargeDependenceHighGrayLeve... -0.667 -0.399 -0.331
# CT_wavelet2.HHH_glcm_ClusterShade                  -4.300 -0.845 -0.362
# CT_wavelet2.HHL_glcm_ClusterShade                  -7.531 -0.407 -0.102
# PET_exponential_glszm_LargeAreaEmphasis            -0.203 -0.191 -0.120
# PET_exponential_glszm_ZoneVariance                 -0.241 -0.223 -0.184
# PET_log.sigma.1.0.mm.3D_firstorder_90Percentile    -3.281 -0.903 -0.642
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        -1.735 -0.913 -0.668
# PET_log.sigma.1.0.mm.3D_ngtdm_Contrast             -0.441 -0.391 -0.330
# PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis        -2.394 -0.834 -0.517
# PET_wavelet.HHH_firstorder_10Percentile            -7.013 -1.161 -0.350
# PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmph... -1.056 -1.053 -0.875
# PET_wavelet.HHL_glcm_Idmn                          -4.462 -1.524 -0.534
# PET_wavelet.HLH_glcm_ClusterShade                  -9.922 -0.079 -0.054
# PET_wavelet.HLL_firstorder_Median                  -7.215 -1.059 -0.410
# PET_wavelet.LHH_firstorder_Kurtosis                -1.163 -0.898 -0.682
# PET_wavelet2.HHH_glcm_Idmn                         -2.032 -1.413 -0.902
# PET_wavelet2.HLH_glszm_SmallAreaLowGrayLevelEmp... -0.933 -0.735 -0.638
# PET_wavelet2.LHH_glszm_SizeZoneNonUniformityNor... -1.962 -1.254 -0.777
# label                                               0.000  0.000  0.000
#
#                                                       50%    75%    90%  \
# CT_lbp.3D.k_firstorder_10Percentile                 0.284  0.596  0.943
# CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized  0.237  0.780  1.137
# CT_lbp.3D.m1_firstorder_10Percentile                0.085  0.494  1.313
# CT_lbp.3D.m1_firstorder_Minimum                    -0.229 -0.229 -0.229
# CT_lbp.3D.m1_glszm_GrayLevelNonUniformity          -0.090 -0.090 -0.090
# CT_lbp.3D.m1_glszm_SizeZoneNonUniformity           -0.071 -0.071 -0.071
# CT_lbp.3D.m1_glszm_ZoneVariance                    -0.054 -0.054 -0.054
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile      0.005  0.551  1.225
# CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis   -0.258  0.265  1.172
# CT_original_shape_Sphericity                       -0.002  0.670  1.292
# CT_wavelet.LLH_gldm_LargeDependenceHighGrayLeve... -0.259 -0.093  0.504
# CT_wavelet2.HHH_glcm_ClusterShade                  -0.062  0.282  0.974
# CT_wavelet2.HHL_glcm_ClusterShade                  -0.002  0.123  0.438
# PET_exponential_glszm_LargeAreaEmphasis            -0.114 -0.089 -0.025
# PET_exponential_glszm_ZoneVariance                 -0.164 -0.098  0.079
# PET_log.sigma.1.0.mm.3D_firstorder_90Percentile    -0.206  0.382  1.153
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis        -0.298  0.434  1.194
# PET_log.sigma.1.0.mm.3D_ngtdm_Contrast             -0.257 -0.090  0.512
# PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis        -0.182  0.263  1.121
# PET_wavelet.HHH_firstorder_10Percentile             0.219  0.661  0.939
# PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmph... -0.313  0.808  1.438
# PET_wavelet.HHL_glcm_Idmn                           0.247  0.767  1.076
# PET_wavelet.HLH_glcm_ClusterShade                   0.035  0.043  0.098
# PET_wavelet.HLL_firstorder_Median                   0.025  0.398  0.955
# PET_wavelet.LHH_firstorder_Kurtosis                -0.322  0.408  1.279
# PET_wavelet2.HHH_glcm_Idmn                          0.214  0.881  1.228
# PET_wavelet2.HLH_glszm_SmallAreaLowGrayLevelEmp... -0.388  0.220  1.399
# PET_wavelet2.LHH_glszm_SizeZoneNonUniformityNor... -0.036  0.702  1.258
# label                                               1.000  1.000  1.000
#
#                                                       95%    99%    max
# CT_lbp.3D.k_firstorder_10Percentile                 1.221  1.686  1.989
# CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized  1.338  1.624  1.740
# CT_lbp.3D.m1_firstorder_10Percentile                1.350  3.009  4.508
# CT_lbp.3D.m1_firstorder_Minimum                     1.676  5.486  9.295
# CT_lbp.3D.m1_glszm_GrayLevelNonUniformity          -0.090  3.915 11.925
# CT_lbp.3D.m1_glszm_SizeZoneNonUniformity           -0.071 -0.071 15.102
# CT_lbp.3D.m1_glszm_ZoneVariance                    -0.054  0.627 15.653
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile      1.794  2.420  3.731
# CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis    1.787  3.740  9.260
# CT_original_shape_Sphericity                        1.628  2.133  2.697
# CT_wavelet.LLH_gldm_LargeDependenceHighGrayLeve...  1.487  3.733 16.060
# CT_wavelet2.HHH_glcm_ClusterShade                   1.522  3.299  6.244
# CT_wavelet2.HHL_glcm_ClusterShade                   0.765  2.352 15.963
# PET_exponential_glszm_LargeAreaEmphasis             0.126  2.249 19.141
# PET_exponential_glszm_ZoneVariance                  0.318  2.746 13.946
# PET_log.sigma.1.0.mm.3D_firstorder_90Percentile     1.966  3.272  5.714
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis         1.922  3.224  7.121
# PET_log.sigma.1.0.mm.3D_ngtdm_Contrast              0.887  4.994 11.538
# PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis         1.851  3.447  8.861
# PET_wavelet.HHH_firstorder_10Percentile             1.073  1.165  1.219
# PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmph...  1.912  2.548  3.268
# PET_wavelet.HHL_glcm_Idmn                           1.204  1.442  1.568
# PET_wavelet.HLH_glcm_ClusterShade                   0.231  3.429 10.278
# PET_wavelet.HLL_firstorder_Median                   1.498  2.971  4.358
# PET_wavelet.LHH_firstorder_Kurtosis                 2.045  3.795  6.436
# PET_wavelet2.HHH_glcm_Idmn                          1.359  1.554  1.925
# PET_wavelet2.HLH_glszm_SmallAreaLowGrayLevelEmp...  2.136  3.647  6.034
# PET_wavelet2.LHH_glszm_SizeZoneNonUniformityNor...  1.861  2.448  4.073
# label                                               1.000  1.000  1.000

# %%
# Check for missing values
df.isnull().values.any()
df.isnull().sum().sort_values(ascending=False)
# Out:
# CT_lbp.3D.k_firstorder_10Percentile                         0
# PET_log.sigma.1.0.mm.3D_firstorder_90Percentile             0
# PET_wavelet2.LHH_glszm_SizeZoneNonUniformityNormalized      0
# PET_wavelet2.HLH_glszm_SmallAreaLowGrayLevelEmphasis        0
# PET_wavelet2.HHH_glcm_Idmn                                  0
# PET_wavelet.LHH_firstorder_Kurtosis                         0
# PET_wavelet.HLL_firstorder_Median                           0
# PET_wavelet.HLH_glcm_ClusterShade                           0
# PET_wavelet.HHL_glcm_Idmn                                   0
# PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmphasis         0
# PET_wavelet.HHH_firstorder_10Percentile                     0
# PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis                 0
# PET_log.sigma.1.0.mm.3D_ngtdm_Contrast                      0
# PET_log.sigma.1.0.mm.3D_firstorder_Kurtosis                 0
# PET_exponential_glszm_ZoneVariance                          0
# CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized          0
# PET_exponential_glszm_LargeAreaEmphasis                     0
# CT_wavelet2.HHL_glcm_ClusterShade                           0
# CT_wavelet2.HHH_glcm_ClusterShade                           0
# CT_wavelet.LLH_gldm_LargeDependenceHighGrayLevelEmphasis    0
# CT_original_shape_Sphericity                                0
# CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis            0
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile              0
# CT_lbp.3D.m1_glszm_ZoneVariance                             0
# CT_lbp.3D.m1_glszm_SizeZoneNonUniformity                    0
# CT_lbp.3D.m1_glszm_GrayLevelNonUniformity                   0
# CT_lbp.3D.m1_firstorder_Minimum                             0
# CT_lbp.3D.m1_firstorder_10Percentile                        0
# label                                                       0
# dtype: int64

# %%
# MODELING


# Define dependent and independent variables
y = df["label"]
X = df.drop(["label"], axis=1)

# y = df["Outcome"]
# X = df.drop(["Outcome"], axis=1)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# See the results for base models

base_models = [('LogisticRegression', LogisticRegression()),
               ('Naive Bayes', GaussianNB()),
               ('KNN', KNeighborsClassifier()),
               ('SVM', SVC()),
               ('ANN', MLPClassifier()),
               ('CART', DecisionTreeClassifier()),
               ('BaggedTrees', BaggingClassifier()),
               ('RF', RandomForestClassifier()),
               ('AdaBoost', AdaBoostClassifier()),
               ('GBM', GradientBoostingClassifier()),
               ("XGBoost", XGBClassifier()),
               ("LightGBM", LGBMClassifier()),
               ("CatBoost", CatBoostClassifier(verbose=False)),
               ("NGBoost", NGBClassifier(verbose=False))]

# %%
evaluate_classification_model_holdout(base_models)
# LogisticRegression: 0.805195
# Naive Bayes: 0.603896
# KNN: 0.850649
# SVM: 0.837662
# ANN: 0.850649
# CART: 0.824675
# BaggedTrees: 0.857143
# RF: 0.876623
# AdaBoost: 0.883117
# GBM: 0.870130
# XGBoost: 0.883117
# LightGBM: 0.857143
# CatBoost: 0.863636
# NGBoost: 0.863636
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.566299
# Naive Bayes: 0.612532
# KNN: 0.550779
# SVM: 0.573312
# ANN: 0.599740
# CART: 0.573766
# BaggedTrees: 0.605714
# RF: 0.663766
# AdaBoost: 0.572792
# GBM: 0.633766
# XGBoost: 0.613766
# LightGBM: 0.613766
# CatBoost: 0.606299
# NGBoost: 0.606299
#
# ################ Train and test results for the model: ################
#
#                 models  accuracy_train  accuracy_test
# 0   LogisticRegression           0.638          0.566
# 1          Naive Bayes           0.584          0.613
# 2                  KNN           0.722          0.551
# 3                  SVM           0.801          0.573
# 4                  ANN           0.862          0.600
# 5                 CART           1.000          0.574
# 6          BaggedTrees           0.981          0.606
# 7                   RF           1.000          0.664
# 8             AdaBoost           0.903          0.573
# 9                  GBM           0.988          0.634
# 10             XGBoost           1.000          0.614
# 11            LightGBM           1.000          0.614
# 12            CatBoost           1.000          0.606
# 13             NGBoost           0.860          0.606

# %%
# For some distance-based models, we need to scale the features in order to
# increase the speed and the performance/accuracy level of the model.
# We can also see the effect of scaling type by changing the sclaer function.
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler

# %%
# Final Model
logreg_tuned = LogisticRegression(**logreg_cv_model.best_params_).fit(X_train, y_train)
y_pred = logreg_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8051948051948052
roc_auc_score(y_test, y_pred)
# Out:
# 0.5468181818181819

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISFSLGB10-28-LR73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-MISFSLGB10-28-LR73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.51      0.36      0.42        77
#  EGFR mutant       0.60      0.73      0.66       100
#
#     accuracy                           0.57       177
#    macro avg       0.55      0.55      0.54       177
# weighted avg       0.56      0.57      0.56       177
#
# precision 0.5983606557377049 accuracy 0.5706214689265536 recall 0.73

# %%
# Visualization of Results
# plot_feature_importances(logreg_tuned)
plot_results(logreg_tuned)
report_results_quickly(logreg_tuned)
plot_learning_curve(logreg_tuned)

# %%
# Final Model
rf_tuned = RandomForestClassifier(**rf_cv_model.best_params_).fit(X_train, y_train)
y_pred = rf_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8831168831168831
roc_auc_score(y_test, y_pred)
# Out:
# 0.6212987012987012

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISFSLGB10-28-RF73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MISFSLGB10-28-RF73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.66      0.40      0.50        77
#  EGFR mutant       0.65      0.84      0.73       100
#
#     accuracy                           0.65       177
#    macro avg       0.65      0.62      0.62       177
# weighted avg       0.65      0.65      0.63       177
#
# precision 0.6461538461538462 accuracy 0.6497175141242938 recall 0.84

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(rf_tuned)
report_results_quickly(rf_tuned)
plot_results(rf_tuned)
plot_learning_curve(rf_tuned)

# %%
# Final Model
svm_tuned = svm.SVC(**svm_model.best_params_).fit(X_train, y_train)
y_pred = svm_tuned.predict(X_test)
ACC = accuracy_score(y_test, y_pred) # 0.8831168831168831
roc_auc_score = roc_auc_score(y_test, y_pred)

print(ACC,roc_auc_score)
# Out:
# 0.6101694915254238 0.5952597402597403

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISFSLGB10-28-SVM73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MISFSLGB10-28-SVM73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.56      0.48      0.52        77
#  EGFR mutant       0.64      0.71      0.67       100
#
#     accuracy                           0.61       177
#    macro avg       0.60      0.60      0.60       177
# weighted avg       0.61      0.61      0.61       177
#
# precision 0.6396396396396397 accuracy 0.6101694915254238 recall 0.71

# %%
# Visualization of Results --> Feature Importances
# plot_feature_importances(svm_tuned)
# report_results_quickly(svm_tuned)
plot_results(svm_tuned)
# plot_learning_curve(svm_tuned)
# Out:
# ---------------------------------------------------------------------------
# ModelError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20632\1389029473.py in <module>
#       2 # plot_feature_importances(svm_tuned)
#       3 # report_results_quickly(svm_tuned)
# ----> 4 plot_results(svm_tuned)
#       5 # plot_learning_curve(svm_tuned)
#
# ~\AppData\Local\Temp\ipykernel_20632\2712900522.py in plot_results(model)
#       3     plot_confusion_matrix_yb(model)
#       4     plot_classification_report_yb(model)
# ----> 5     plot_roc_auc_curve_yb(model)
#       6     plot_class_prediction_error_yb(model)
#
# ~\AppData\Local\Temp\ipykernel_20632\2207885490.py in plot_roc_auc_curve_yb(model)
#       5     visualizer = ROCAUC(model, classes=["EGFR Wild", "EGFR Mutated"])
#       6     visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
# ----> 7     visualizer.score(X_test, y_test)  # Evaluate the model on the test data
#       8     visualizer.show();  # Finalize and show the figure
#
# ~\.conda\envs\tf\lib\site-packages\yellowbrick\classifier\rocauc.py in score(self, X, y)
#     279             if (self.micro or self.macro) and len(y_pred.shape) == 1:
#     280                 raise ModelError(
# --> 281                     "no curves will be drawn; set binary=True.",
#     282                 )
#     283
#
# ModelError: no curves will be drawn; set binary=True.

# %%
# Final Model
xgb_tuned = XGBClassifier(**xgb_cv_model.best_params_).fit(X_train, y_train)
y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.6271186440677966

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISFSLGB10-28-XGB73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MISFSLGB10-28-XGB73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.59      0.48      0.53        77
#  EGFR mutant       0.65      0.74      0.69       100
#
#     accuracy                           0.63       177
#    macro avg       0.62      0.61      0.61       177
# weighted avg       0.62      0.63      0.62       177
#
# precision 0.6491228070175439 accuracy 0.6271186440677966 recall 0.74

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(xgb_tuned)
report_results_quickly(xgb_tuned)
plot_results(xgb_tuned)
# plot_learning_curve(xgb_tuned)

# %%
# Final Model
lgbm_tuned = LGBMClassifier(**lgbm_cv_model.best_params_).fit(X_train, y_train)
y_pred = lgbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.6384180790960452

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISFSLGB10-28-lgb73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MISFSLGB10-28-lgb73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.61      0.48      0.54        77
#  EGFR mutant       0.66      0.76      0.70       100
#
#     accuracy                           0.64       177
#    macro avg       0.63      0.62      0.62       177
# weighted avg       0.63      0.64      0.63       177
#
# precision 0.6551724137931034 accuracy 0.6384180790960452 recall 0.76

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(lgbm_tuned)
# report_results_quickly(lgbm_tuned)
plot_results(lgbm_tuned)
# plot_learning_curve(lgbm_tuned)

# %%
# Comparison of tuned models
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
tuned_models = [('LogisticRegression', logreg_tuned),
                ('RF', rf_tuned),
                ('XGBoost', xgb_tuned),
                ('LightGBM', lgbm_tuned)]


evaluate_classification_model_holdout(tuned_models)
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.546818
# RF: 0.635779
# XGBoost: 0.610260
# LightGBM: 0.620260
#
# ################ Train and test results for the model: ################
#
#                models  accuracy_train  accuracy_test
# 0  LogisticRegression           0.635          0.547
# 1                  RF           0.966          0.636
# 2             XGBoost           1.000          0.610
# 3            LightGBM           1.000          0.620

# %%
# Stack models
from mlxtend.classifier import StackingCVClassifier
stack_gen = StackingCVClassifier(classifiers=(logreg_tuned, rf_tuned, xgb_tuned, lgbm_tuned), meta_classifier=xgb_tuned)
stack_gen_model = stack_gen.fit(X_train, y_train)

evaluate_classification_model_holdout([('stack model', stack_gen_model)]) # 0.890
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# stack model: 0.622273
#
# ################ Train and test results for the model: ################
#
#         models  accuracy_train  accuracy_test
# 0  stack model           0.966          0.622

# %%
# Function ot blend models
def blend_models_predict(X_test):
    return ((0.1 * logreg_tuned.predict(X_test)) +
            (0.2 * rf_tuned.predict(X_test)) +
            (0.2 * xgb_tuned.predict(X_test)) +
            (0.2 * lgbm_tuned.predict(X_test)) +
#             (0.1 * svm_tuned.predict(X_test)) +
            (0.3 * stack_gen_model.predict(X_test)))

# %%
accuracy_score(y_test, blend_models_predict(X_test).round())# 0.8701298701298701
# aucroc_score(y_test, blend_models_predict(X_test).round())# 0.8701298701298701
roc_auc_score(y_test, blend_models_predict(X_test).round())
# Out:
# 0.6302597402597403

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISFSLGB10-28-stack73', Save_format = 'csv',Save_type = 'col')

# %%
# Pickle Models --> Saving tuned models

# Create a folder named 'Models'
# save working directory
#
# cur_dir = os.getcwd()
# cur_dir
#
# # change working directory:
os.chdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISFSLGB10-28")
#
# # Save the models
for model in tuned_models:
    pickle.dump(model[1], open(str(model[0]) + ".pkl", 'wb'))

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
external_test=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-MISFSLGB10-28.csv")
external_test_label = external_test.label
# print(external_test_label)
external_test=external_test.drop(columns=['label'])

# %%
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB10.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17-42.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF11.csv",index=None)

external_test1=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-MISFSLGB10-28.csv")
external_test_label1 = external_test1.label
# print(external_test_label)
external_test1=external_test1.drop(columns=['label'])

# %%
######XGB  测试集1
import numpy as np
# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISFSLGB10-28/XGBoost.pkl', 'rb'))
external_test_pred=xgb.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-xgb-MISFSLGB10-28-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.30      0.58      0.39        26
#  EGFR mutant       0.74      0.47      0.57        66
#
#     accuracy                           0.50        92
#    macro avg       0.52      0.52      0.48        92
# weighted avg       0.61      0.50      0.52        92
#
# precision 0.7380952380952381 accuracy 0.5 recall 0.4696969696969697

# %%
######XGB  测试集1
#############画图部分
# from sklearn.datasets import load_breast_cancer
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
import pylab as plt
import warnings;warnings.filterwarnings('ignore')
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for XbBoost')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
######XGB  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[15 11]
#  [35 31]]
# Normalized confusion matrix
# [[0.58 0.42]
#  [0.53 0.47]]

# %%
#####XGB  测试集2

import numpy as np

# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISFSLGB10-28/XGBoost.pkl', 'rb'))
external_test_pred1=xgb.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-xgb-MISFSLGB10-28-73.csv', external_test_pred1, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.44      0.64      0.52        42
#  EGFR mutant       0.42      0.24      0.31        46
#
#     accuracy                           0.43        88
#    macro avg       0.43      0.44      0.41        88
# weighted avg       0.43      0.43      0.41        88
#
# precision 0.4230769230769231 accuracy 0.4318181818181818 recall 0.2391304347826087

# %%
#####XGB  测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for XbBoost')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####XGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[27 15]
#  [35 11]]
# Normalized confusion matrix
# [[0.64 0.36]
#  [0.76 0.24]]

# %%
#####RF  测试集1
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISFSLGB10-28/RF.pkl', 'rb'))
external_test_pred=rft.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-RF-MISFSLGB10-28-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.32      0.69      0.43        26
#  EGFR mutant       0.77      0.41      0.53        66
#
#     accuracy                           0.49        92
#    macro avg       0.54      0.55      0.48        92
# weighted avg       0.64      0.49      0.51        92
#
# precision 0.7714285714285715 accuracy 0.4891304347826087 recall 0.4090909090909091

# %%
#####RF  测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####RF  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[18  8]
#  [39 27]]
# Normalized confusion matrix
# [[0.69 0.31]
#  [0.59 0.41]]

# %%
#####RF  测试集2
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISFSLGB10-28/RF.pkl', 'rb'))
external_test_pred1=rft.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-RF-MISFSLGB10-28-73.csv', external_test_pred1, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.51      0.83      0.63        42
#  EGFR mutant       0.63      0.26      0.37        46
#
#     accuracy                           0.53        88
#    macro avg       0.57      0.55      0.50        88
# weighted avg       0.57      0.53      0.49        88
#
# precision 0.631578947368421 accuracy 0.5340909090909091 recall 0.2608695652173913

# %%
#####rf  测试集2

fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####rf  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[35  7]
#  [34 12]]
# Normalized confusion matrix
# [[0.83 0.17]
#  [0.74 0.26]]

# %%
######LR 测试集1
import numpy as np
# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISFSLGB10-28/LogisticRegression.pkl', 'rb'))
external_test_pred=lrt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-lr-MISFSLGB10-28-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.35      0.46      0.40        26
#  EGFR mutant       0.76      0.67      0.71        66
#
#     accuracy                           0.61        92
#    macro avg       0.56      0.56      0.55        92
# weighted avg       0.64      0.61      0.62        92
#
# precision 0.7586206896551724 accuracy 0.6086956521739131 recall 0.6666666666666666

# %%
######LR 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[12 14]
#  [22 44]]
# Normalized confusion matrix
# [[0.46 0.54]
#  [0.33 0.67]]

# %%
######LR 测试集2
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISFSLGB10-28/LogisticRegression.pkl', 'rb'))
external_test_pred1=lrt.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-lr-MISFSLGB10-28-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.58      0.36      0.44        42
#  EGFR mutant       0.56      0.76      0.65        46
#
#     accuracy                           0.57        88
#    macro avg       0.57      0.56      0.54        88
# weighted avg       0.57      0.57      0.55        88
#
# precision 0.5645161290322581 accuracy 0.5681818181818182 recall 0.7608695652173914

# %%
######LR 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[15 27]
#  [11 35]]
# Normalized confusion matrix
# [[0.36 0.64]
#  [0.24 0.76]]

# %%
##lgb 测试集1
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISFSLGB10-28/LightGBM.pkl', 'rb'))
external_test_pred=lgbt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-lgb-MISFSLGB10-28-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.35      0.69      0.46        26
#  EGFR mutant       0.80      0.48      0.60        66
#
#     accuracy                           0.54        92
#    macro avg       0.57      0.59      0.53        92
# weighted avg       0.67      0.54      0.56        92
#
# precision 0.8 accuracy 0.5434782608695652 recall 0.48484848484848486

# %%
##lgb 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
##lgb 测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[18  8]
#  [34 32]]
# Normalized confusion matrix
# [[0.69 0.31]
#  [0.52 0.48]]

# %%
#lgb 测试集2
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISFSLGB10-28/LightGBM.pkl', 'rb'))
external_test_pred1=lgbt.predict(external_test1)

np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-lgb-MISFSLGB10-28-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.50      0.71      0.59        42
#  EGFR mutant       0.57      0.35      0.43        46
#
#     accuracy                           0.52        88
#    macro avg       0.54      0.53      0.51        88
# weighted avg       0.54      0.52      0.51        88
#
# precision 0.5714285714285714 accuracy 0.5227272727272727 recall 0.34782608695652173

# %%
#lgb 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[30 12]
#  [30 16]]
# Normalized confusion matrix
# [[0.71 0.29]
#  [0.65 0.35]]

# %%
# # Visualization of Results --> Feature Importances
# plot_feature_importances(lgbt)
# # report_results_quickly(lgbm_tuned)
# plot_results(lgbt)
# # plot_learning_curve(lgbm_tuned)
