# %%
import pandas as pd
import numpy as np
import os
print("文件列表：",os.listdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB"))
data = pd.ExcelFile("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/EGFR01-767cases-FS-results.xlsx")#, sheet_name='g1rfegb12'
sheet_names = data.sheet_names
print("列表名：",sheet_names )
# Out:
# 文件列表： ['EGFR01-767cases-FS-results.xlsx', 'ex-test-for-auc-dca-lgb-KNN-73.csv', 'ex-test-for-auc-dca-lgb-LASSO-73.csv', 'ex-test-for-auc-dca-lgb-LIGHTGBM-73.csv', 'ex-test-for-auc-dca-lgb-LIGHTGBM-NEW-73.csv', 'ex-test-for-auc-dca-lgb-LR-73.csv', 'ex-test-for-auc-dca-lgb-MIRFEGB11-73.csv', 'ex-test-for-auc-dca-lgb-MIRFEGB4-73.csv', 'ex-test-for-auc-dca-lgb-MIRFEGB7-73.csv', 'ex-test-for-auc-dca-lgb-MIRFELGB12-73.csv', 'ex-test-for-auc-dca-lgb-MIRFELGB29-73.csv', 'ex-test-for-auc-dca-lgb-MIRFELR15-73.csv', 'ex-test-for-auc-dca-lgb-MIRFERF18-73.csv', 'ex-test-for-auc-dca-lgb-MIRFEXGB19-73.csv', 'ex-test-for-auc-dca-lgb-MIRFEXGB20-73.csv', 'ex-test-for-auc-dca-lgb-MISBSLGB24-73.csv', 'ex-test-for-auc-dca-lgb-MISBSLR30-73.csv', 'ex-test-for-auc-dca-lgb-MISBSRF11-73.csv', 'ex-test-for-auc-dca-lgb-MISBSXGB18-73.csv', 'ex-test-for-auc-dca-lgb-MISFSLGB10-28-73.csv', 'ex-test-for-auc-dca-lgb-MISFSLR13-73.csv', 'ex-test-for-auc-dca-lgb-MISFSRF20-73.csv', 'ex-test-for-auc-dca-lgb-MISFSXGB21-73.csv', 'ex-test-for-auc-dca-lgb-RF-3-73.csv', 'ex-test-for-auc-dca-lgb-RF-73.csv', 'ex-test-for-auc-dca-lgb-RF-NEW-73.csv', 'ex-test-for-auc-dca-lgb-RFE12-73.csv', 'ex-test-for-auc-dca-lgb-RFEGB10-73.csv', 'ex-test-for-auc-dca-lgb-RFEGB18-73.csv', 'ex-test-for-auc-dca-lgb-RFERF11-73.csv', 'ex-test-for-auc-dca-lgb-RFERF17-42-82.csv', 'ex-test-for-auc-dca-lgb-RFERF17-42.csv', 'ex-test-for-auc-dca-lgb-RFERF17-73.csv', 'ex-test-for-auc-dca-lgb-RFERF18-73.csv', 'ex-test-for-auc-dca-lgb-RFERF5-73.csv', 'ex-test-for-auc-dca-lgb-SVM-73.csv', 'ex-test-for-auc-dca-lgb-XGBOOST-73.csv', 'ex-test-for-auc-dca-lgb-XGBOOST-NEW-73.csv', 'ex-test-for-auc-dca-lr-KNN-73.csv', 'ex-test-for-auc-dca-lr-LASSO-73.csv', 'ex-test-for-auc-dca-lr-LIGHTGBM-73.csv', 'ex-test-for-auc-dca-lr-LIGHTGBM-NEW-73.csv', 'ex-test-for-auc-dca-lr-LR-73.csv', 'ex-test-for-auc-dca-lr-MIRFEGB11-73.csv', 'ex-test-for-auc-dca-lr-MIRFEGB4-73.csv', 'ex-test-for-auc-dca-lr-MIRFEGB7-73.csv', 'ex-test-for-auc-dca-lr-MIRFELGB12-73.csv', 'ex-test-for-auc-dca-lr-MIRFELGB29-73.csv', 'ex-test-for-auc-dca-lr-MIRFELR15-73.csv', 'ex-test-for-auc-dca-lr-MIRFERF18-73.csv', 'ex-test-for-auc-dca-lr-MIRFEXGB19-73.csv', 'ex-test-for-auc-dca-lr-MIRFEXGB20-73.csv', 'ex-test-for-auc-dca-lr-MISBSLGB24-73.csv', 'ex-test-for-auc-dca-lr-MISBSLR30-73.csv', 'ex-test-for-auc-dca-lr-MISBSRF11-73.csv', 'ex-test-for-auc-dca-lr-MISBSXGB18-73.csv', 'ex-test-for-auc-dca-lr-MISFSLGB10-28-73.csv', 'ex-test-for-auc-dca-lr-MISFSLR13-73.csv', 'ex-test-for-auc-dca-lr-MISFSRF20-73.csv', 'ex-test-for-auc-dca-lr-MISFSXGB21-73.csv', 'ex-test-for-auc-dca-lr-RF-3-73.csv', 'ex-test-for-auc-dca-lr-RF-73.csv', 'ex-test-for-auc-dca-lr-RF-NEW-73.csv', 'ex-test-for-auc-dca-lr-RFE12-73.csv', 'ex-test-for-auc-dca-lr-RFEGB10-73.csv', 'ex-test-for-auc-dca-lr-RFEGB18-73.csv', 'ex-test-for-auc-dca-lr-RFERF11-73.csv', 'ex-test-for-auc-dca-lr-RFERF17-42-82.csv', 'ex-test-for-auc-dca-lr-RFERF17-42.csv', 'ex-test-for-auc-dca-lr-RFERF17-73.csv', 'ex-test-for-auc-dca-lr-RFERF18-73.csv', 'ex-test-for-auc-dca-lr-RFERF5-73.csv', 'ex-test-for-auc-dca-lr-SVM-73.csv', 'ex-test-for-auc-dca-lr-XGBOOST-73.csv', 'ex-test-for-auc-dca-lr-XGBOOST-NEW-73.csv', 'ex-test-for-auc-dca-RF-KNN-73.csv', 'ex-test-for-auc-dca-RF-LASSO-73.csv', 'ex-test-for-auc-dca-RF-LIGHTGBM-73.csv', 'ex-test-for-auc-dca-RF-LIGHTGBM-NEW-73.csv', 'ex-test-for-auc-dca-RF-LR-73.csv', 'ex-test-for-auc-dca-RF-MIRFEGB11-73.csv', 'ex-test-for-auc-dca-RF-MIRFEGB4-73.csv', 'ex-test-for-auc-dca-RF-MIRFEGB7-73.csv', 'ex-test-for-auc-dca-RF-MIRFELGB12-73.csv', 'ex-test-for-auc-dca-RF-MIRFELGB29-73.csv', 'ex-test-for-auc-dca-RF-MIRFELR15-73.csv', 'ex-test-for-auc-dca-RF-MIRFERF18-73.csv', 'ex-test-for-auc-dca-RF-MIRFEXGB19-73.csv', 'ex-test-for-auc-dca-RF-MIRFEXGB20-73.csv', 'ex-test-for-auc-dca-RF-MISBSLGB24-73.csv', 'ex-test-for-auc-dca-RF-MISBSLR30-73.csv', 'ex-test-for-auc-dca-RF-MISBSRF11-73.csv', 'ex-test-for-auc-dca-RF-MISBSXGB18-73.csv', 'ex-test-for-auc-dca-RF-MISFSLGB10-28-73.csv', 'ex-test-for-auc-dc ...
# 列表名： ['RF', 'RFE12', 'RFERF17-42', 'RFERF17', 'RFEGB10', 'RFEGB18', 'RFERF17-42-CLINIC', 'RFERF17-CLINIC', 'RFEGB10-CLINIC', 'RFEGB18-CLINIC', 'RFERF18', 'RFERF19', 'RFERF5', 'RFERF11', 'SFS20', 'MI20', 'new_prepross', 'MI', 'MIRFEGB4', 'MIRFEGB7', 'MIRFEGB11', 'MIRFELGB12', 'MIRFELGB29', 'MIRFELR15', 'MIRFERF18', 'MIRFEXGB19', 'MIRFEXGB20', 'MISFSLGB10-28', 'MISFSXGB21', 'MISFSRF20', 'MISFSLR13', 'MISFSLGB17', 'MISBSXGB18', 'MISBSRF11', 'MISBSLR30', 'MISBSLGB24', 'KNN', 'LR', 'SVM', 'LASSO', 'XGBOOST', 'LIGHTGBM', 'RF-NEW', 'XGBOOST-NEW', 'LIGHTGBM-NEW', 'RF-3', 'MISBSXGB26', 'MISBSRF23', 'MISBSLGBM25', 'MISBSLR27', 'MIRFERF29-NEW', 'SVM2023', 'KNN2023', 'LR2023', 'LGB2023', 'XGB2023', 'RF2023']

# %%
# data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
import pandas as pd
import numpy as np
import os
data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/EGFR01-767cases-FS-results.xlsx",
                     sheet_name='LR2023')
data.keys()
train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore.csv")
test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv")
test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore.csv")
train=train[data.keys()]
train.shape
test=test[data.keys()]
test.shape
test1=test1[data.keys()]
test1.shape
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB10.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17-42.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF19.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-LR.csv",index=None)

# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF17.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFEGB10.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFEGB18.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF17-42.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF18.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF19.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF5.csv",index=None)
test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-LR.csv",index=None)

# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB10.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17-42.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-LR.csv",index=None)

# %%
#%% load liabrary
import os
import numpy as np
import xlrd
import scipy.io as io
import pandas as pd
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFE
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit, train_test_split
from sklearn.linear_model import Lasso, Ridge, LassoCV,LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn import metrics
import itertools
import joblib
from scipy import stats
from sklearn import preprocessing
print("Import library done.\n")
# Out:
# Import library done.

# %%
# data = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test_label.csv")
# y = data.label
# print(y)
# data = data.drop(columns=['id','label'])

# scaler = StandardScaler()#因此选用StandardScaler进行归一化
# scaler.fit(data.values)


# X = pd.DataFrame(data = scaler.transform(data.values), columns=data.columns)
# X['label']=y



# outputpath = "C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv"
# X.to_csv(outputpath,sep=',',index=False,header=True) 
# # df1是你想要输出的的DataFrame
# # index是否要索引，header是否要列名，True就是需要
# X.head()

# %%
# DIABETES PREDICTION MODEL

# CLASSIFICATION MODELS - HOLDOUT

'''
Steps to follow:
    - Load the saved dataset
    - General View
    - Modeling
        - Base models: LogisticRegression, GaussianNB, KNeighborsClassifier, SVC, MLPClassifier, DecisionTreeClassifier,
                       BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,
                       XGBClassifier, LGBMClassifier, CatBoostClassifier, NGBClassifier
    - Model Evaluation
    - Model Tuning
    - Model Results
'''

# Import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


# Load the preprocessed dataset
# diabetes_preprocessed = pd.read_csv('./diabetes_prepared.csv')

# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB10.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17-42.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF19.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF11.csv",index=None)

# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rferf17.csv")
# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rfegb5.csv")
diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-LR.csv")




# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/Results_HRFS01/catboost/train.csv")
df = diabetes_preprocessed.copy()
# df = df.drop(columns="id",axis=1)

## GENERAL VIEW

df.head()
df.shape
df.info()
df.columns
df.index
df.describe([0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 23 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   CT_lbp.3D.k_ngtdm_Coarseness                               587 non-null    float64
#  1   PET_wavelet.LLH_glcm_ClusterProminence                     587 non-null    float64
#  2   PET_wavelet2.LLL_ngtdm_Contrast                            587 non-null    float64
#  3   PET_wavelet.LHL_gldm_LargeDependenceLowGrayLevelEmphasis   587 non-null    float64
#  4   PET_wavelet.HHL_glszm_LargeAreaLowGrayLevelEmphasis        587 non-null    float64
#  5   PET_wavelet.LHH_glcm_ClusterShade                          587 non-null    float64
#  6   PET_exponential_firstorder_10Percentile                    587 non-null    float64
#  7   PET_wavelet.LLH_firstorder_Energy                          587 non-null    float64
#  8   CT_lbp.3D.k_ngtdm_Busyness                                 587 non-null    float64
#  9   PET_wavelet2.HLH_firstorder_Kurtosis                       587 non-null    float64
#  10  PET_wavelet2.LHH_glszm_SmallAreaLowGrayLevelEmphasis       587 non-null    float64
#  11  PET_log.sigma.1.0.mm.3D_firstorder_90Percentile            587 non-null    float64
#  12  PET_wavelet2.LHL_gldm_LargeDependenceLowGrayLevelEmphasis  587 non-null    float64
#  13  PET_wavelet.LLH_firstorder_90Percentile                    587 non-null    float64
#  14  CT_square_ngtdm_Coarseness                                 587 non-null    float64
#  15  PET_wavelet.LHH_gldm_LargeDependenceHighGrayLevelEmphasis  587 non-null    float64
#  16  CT_exponential_firstorder_90Percentile                     587 non-null    float64
#  17  PET_wavelet.HHL_gldm_LargeDependenceLowGrayLevelEmphasis   587 non-null    float64
#  18  PET_exponential_gldm_DependenceNonUniformity               587 non-null    float64
#  19  PET_wavelet2.HLL_gldm_LargeDependenceLowGrayLevelEmphasis  587 non-null    float64
#  20  PET_wavelet2.LLH_ngtdm_Contrast                            587 non-null    float64
#  21  CT_exponential_firstorder_10Percentile                     587 non-null    float64
#  22  label                                                      587 non-null    int64
# dtypes: float64(22), int64(1)
# memory usage: 105.6 KB
#                                                      count   mean   std  \
# CT_lbp.3D.k_ngtdm_Coarseness                       587.000  0.000 1.001
# PET_wavelet.LLH_glcm_ClusterProminence             587.000  0.000 1.001
# PET_wavelet2.LLL_ngtdm_Contrast                    587.000  0.000 1.001
# PET_wavelet.LHL_gldm_LargeDependenceLowGrayLeve... 587.000  0.000 1.001
# PET_wavelet.HHL_glszm_LargeAreaLowGrayLevelEmph... 587.000  0.000 1.001
# PET_wavelet.LHH_glcm_ClusterShade                  587.000  0.000 1.001
# PET_exponential_firstorder_10Percentile            587.000  0.000 1.001
# PET_wavelet.LLH_firstorder_Energy                  587.000 -0.000 1.001
# CT_lbp.3D.k_ngtdm_Busyness                         587.000  0.000 1.001
# PET_wavelet2.HLH_firstorder_Kurtosis               587.000  0.000 1.001
# PET_wavelet2.LHH_glszm_SmallAreaLowGrayLevelEmp... 587.000  0.000 1.001
# PET_log.sigma.1.0.mm.3D_firstorder_90Percentile    587.000 -0.000 1.001
# PET_wavelet2.LHL_gldm_LargeDependenceLowGrayLev... 587.000 -0.000 1.001
# PET_wavelet.LLH_firstorder_90Percentile            587.000  0.000 1.001
# CT_square_ngtdm_Coarseness                         587.000 -0.000 1.001
# PET_wavelet.LHH_gldm_LargeDependenceHighGrayLev... 587.000  0.000 1.001
# CT_exponential_firstorder_90Percentile             587.000  0.000 1.001
# PET_wavelet.HHL_gldm_LargeDependenceLowGrayLeve... 587.000  0.000 1.001
# PET_exponential_gldm_DependenceNonUniformity       587.000  0.000 1.001
# PET_wavelet2.HLL_gldm_LargeDependenceLowGrayLev... 587.000 -0.000 1.001
# PET_wavelet2.LLH_ngtdm_Contrast                    587.000  0.000 1.001
# CT_exponential_firstorder_10Percentile             587.000  0.000 1.001
# label                                              587.000  0.576 0.495
#
#                                                       min    10%    25%  \
# CT_lbp.3D.k_ngtdm_Coarseness                       -0.088 -0.088 -0.047
# PET_wavelet.LLH_glcm_ClusterProminence             -0.151 -0.151 -0.151
# PET_wavelet2.LLL_ngtdm_Contrast                    -0.115 -0.115 -0.114
# PET_wavelet.LHL_gldm_LargeDependenceLowGrayLeve... -0.408 -0.384 -0.293
# PET_wavelet.HHL_glszm_LargeAreaLowGrayLevelEmph... -0.459 -0.444 -0.142
# PET_wavelet.LHH_glcm_ClusterShade                  -7.500 -0.100 -0.080
# PET_exponential_firstorder_10Percentile            -0.553 -0.407 -0.330
# PET_wavelet.LLH_firstorder_Energy                  -0.343 -0.340 -0.332
# CT_lbp.3D.k_ngtdm_Busyness                         -0.330 -0.328 -0.316
# PET_wavelet2.HLH_firstorder_Kurtosis               -0.976 -0.721 -0.602
# PET_wavelet2.LHH_glszm_SmallAreaLowGrayLevelEmp... -0.941 -0.818 -0.684
# PET_log.sigma.1.0.mm.3D_firstorder_90Percentile    -3.281 -0.903 -0.642
# PET_wavelet2.LHL_gldm_LargeDependenceLowGrayLev... -0.518 -0.445 -0.251
# PET_wavelet.LLH_firstorder_90Percentile            -0.731 -0.610 -0.457
# CT_square_ngtdm_Coarseness                         -0.053 -0.053 -0.053
# PET_wavelet.LHH_gldm_LargeDependenceHighGrayLev... -0.644 -0.591 -0.539
# CT_exponential_firstorder_90Percentile             -0.409 -0.095 -0.057
# PET_wavelet.HHL_gldm_LargeDependenceLowGrayLeve... -0.642 -0.480 -0.417
# PET_exponential_gldm_DependenceNonUniformity       -0.570 -0.489 -0.403
# PET_wavelet2.HLL_gldm_LargeDependenceLowGrayLev... -0.464 -0.365 -0.217
# PET_wavelet2.LLH_ngtdm_Contrast                    -0.159 -0.158 -0.155
# CT_exponential_firstorder_10Percentile             -0.519 -0.483 -0.437
# label                                               0.000  0.000  0.000
#
#                                                       50%    75%    90%  \
# CT_lbp.3D.k_ngtdm_Coarseness                       -0.047 -0.047 -0.047
# PET_wavelet.LLH_glcm_ClusterProminence             -0.148 -0.097 -0.069
# PET_wavelet2.LLL_ngtdm_Contrast                    -0.111 -0.036 -0.026
# PET_wavelet.LHL_gldm_LargeDependenceLowGrayLeve... -0.278 -0.152  0.473
# PET_wavelet.HHL_glszm_LargeAreaLowGrayLevelEmph... -0.137 -0.108  0.075
# PET_wavelet.LHH_glcm_ClusterShade                  -0.077  0.039  0.056
# PET_exponential_firstorder_10Percentile            -0.224  0.018  0.490
# PET_wavelet.LLH_firstorder_Energy                  -0.302 -0.143  0.322
# CT_lbp.3D.k_ngtdm_Busyness                         -0.247 -0.129  0.387
# PET_wavelet2.HLH_firstorder_Kurtosis               -0.332  0.244  0.967
# PET_wavelet2.LHH_glszm_SmallAreaLowGrayLevelEmp... -0.366  0.310  1.335
# PET_log.sigma.1.0.mm.3D_firstorder_90Percentile    -0.206  0.382  1.153
# PET_wavelet2.LHL_gldm_LargeDependenceLowGrayLev... -0.231 -0.122  0.352
# PET_wavelet.LLH_firstorder_90Percentile            -0.285  0.054  0.627
# CT_square_ngtdm_Coarseness                         -0.053 -0.053 -0.003
# PET_wavelet.LHH_gldm_LargeDependenceHighGrayLev... -0.372  0.096  1.055
# CT_exponential_firstorder_90Percentile             -0.046 -0.040  0.046
# PET_wavelet.HHL_gldm_LargeDependenceLowGrayLeve... -0.338 -0.034  0.757
# PET_exponential_gldm_DependenceNonUniformity       -0.274 -0.024  0.540
# PET_wavelet2.HLL_gldm_LargeDependenceLowGrayLev... -0.194 -0.106  0.244
# PET_wavelet2.LLH_ngtdm_Contrast                    -0.148 -0.055 -0.026
# CT_exponential_firstorder_10Percentile             -0.331 -0.092  0.515
# label                                               1.000  1.000  1.000
#
#                                                       95%    99%    max
# CT_lbp.3D.k_ngtdm_Coarseness                       -0.047 -0.047 21.031
# PET_wavelet.LLH_glcm_ClusterProminence              0.109  2.476 16.456
# PET_wavelet2.LLL_ngtdm_Contrast                     0.053  1.800 22.252
# PET_wavelet.LHL_gldm_LargeDependenceLowGrayLeve...  1.384  5.163 13.797
# PET_wavelet.HHL_glszm_LargeAreaLowGrayLevelEmph...  0.687  4.147 14.058
# PET_wavelet.LHH_glcm_ClusterShade                   0.128  3.321 17.344
# PET_exponential_firstorder_10Percentile             0.995  3.326 18.315
# PET_wavelet.LLH_firstorder_Energy                   1.250  4.092  8.671
# CT_lbp.3D.k_ngtdm_Busyness                          1.023  3.555 14.647
# PET_wavelet2.HLH_firstorder_Kurtosis                1.873  3.806 10.012
# PET_wavelet2.LHH_glszm_SmallAreaLowGrayLevelEmp...  2.357  3.711  4.397
# PET_log.sigma.1.0.mm.3D_firstorder_90Percentile     1.966  3.272  5.714
# PET_wavelet2.LHL_gldm_LargeDependenceLowGrayLev...  0.961  5.285 11.194
# PET_wavelet.LLH_firstorder_90Percentile             1.749  4.399  9.761
# CT_square_ngtdm_Coarseness                         -0.003 -0.003 24.202
# PET_wavelet.LHH_gldm_LargeDependenceHighGrayLev...  1.585  3.557  7.996
# CT_exponential_firstorder_90Percentile              0.112  0.243 24.125
# PET_wavelet.HHL_gldm_LargeDependenceLowGrayLeve...  1.755  4.826  7.534
# PET_exponential_gldm_DependenceNonUniformity        1.338  4.743  9.906
# PET_wavelet2.HLL_gldm_LargeDependenceLowGrayLev...  0.849  3.380 14.630
# PET_wavelet2.LLH_ngtdm_Contrast                     0.074  3.170 17.865
# CT_exponential_firstorder_10Percentile              2.284  4.715  7.101
# label                                               1.000  1.000  1.000

# %%
# Check for missing values
df.isnull().values.any()
df.isnull().sum().sort_values(ascending=False)
# Out:
# CT_lbp.3D.k_ngtdm_Coarseness                                 0
# PET_wavelet2.LHL_gldm_LargeDependenceLowGrayLevelEmphasis    0
# CT_exponential_firstorder_10Percentile                       0
# PET_wavelet2.LLH_ngtdm_Contrast                              0
# PET_wavelet2.HLL_gldm_LargeDependenceLowGrayLevelEmphasis    0
# PET_exponential_gldm_DependenceNonUniformity                 0
# PET_wavelet.HHL_gldm_LargeDependenceLowGrayLevelEmphasis     0
# CT_exponential_firstorder_90Percentile                       0
# PET_wavelet.LHH_gldm_LargeDependenceHighGrayLevelEmphasis    0
# CT_square_ngtdm_Coarseness                                   0
# PET_wavelet.LLH_firstorder_90Percentile                      0
# PET_log.sigma.1.0.mm.3D_firstorder_90Percentile              0
# PET_wavelet.LLH_glcm_ClusterProminence                       0
# PET_wavelet2.LHH_glszm_SmallAreaLowGrayLevelEmphasis         0
# PET_wavelet2.HLH_firstorder_Kurtosis                         0
# CT_lbp.3D.k_ngtdm_Busyness                                   0
# PET_wavelet.LLH_firstorder_Energy                            0
# PET_exponential_firstorder_10Percentile                      0
# PET_wavelet.LHH_glcm_ClusterShade                            0
# PET_wavelet.HHL_glszm_LargeAreaLowGrayLevelEmphasis          0
# PET_wavelet.LHL_gldm_LargeDependenceLowGrayLevelEmphasis     0
# PET_wavelet2.LLL_ngtdm_Contrast                              0
# label                                                        0
# dtype: int64

# %%
# MODELING


# Define dependent and independent variables
y = df["label"]
X = df.drop(["label"], axis=1)

# y = df["Outcome"]
# X = df.drop(["Outcome"], axis=1)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# See the results for base models

base_models = [('LogisticRegression', LogisticRegression()),
               ('Naive Bayes', GaussianNB()),
               ('KNN', KNeighborsClassifier()),
               ('SVM', SVC()),
               ('ANN', MLPClassifier()),
               ('CART', DecisionTreeClassifier()),
               ('BaggedTrees', BaggingClassifier()),
               ('RF', RandomForestClassifier()),
               ('AdaBoost', AdaBoostClassifier()),
               ('GBM', GradientBoostingClassifier()),
               ("XGBoost", XGBClassifier()),
               ("LightGBM", LGBMClassifier()),
               ("CatBoost", CatBoostClassifier(verbose=False)),
               ("NGBoost", NGBClassifier(verbose=False))]

# %%
evaluate_classification_model_holdout(base_models)
# LogisticRegression: 0.805195
# Naive Bayes: 0.603896
# KNN: 0.850649
# SVM: 0.837662
# ANN: 0.850649
# CART: 0.824675
# BaggedTrees: 0.857143
# RF: 0.876623
# AdaBoost: 0.883117
# GBM: 0.870130
# XGBoost: 0.883117
# LightGBM: 0.857143
# CatBoost: 0.863636
# NGBoost: 0.863636
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.598831
# Naive Bayes: 0.591818
# KNN: 0.566299
# SVM: 0.536364
# ANN: 0.629740
# CART: 0.553766
# BaggedTrees: 0.581234
# RF: 0.675714
# AdaBoost: 0.593247
# GBM: 0.625260
# XGBoost: 0.621234
# LightGBM: 0.601753
# CatBoost: 0.672727
# NGBoost: 0.648766
#
# ################ Train and test results for the model: ################
#
#                 models  accuracy_train  accuracy_test
# 0   LogisticRegression           0.603          0.599
# 1          Naive Bayes           0.608          0.592
# 2                  KNN           0.726          0.566
# 3                  SVM           0.637          0.536
# 4                  ANN           0.786          0.630
# 5                 CART           1.000          0.554
# 6          BaggedTrees           0.968          0.581
# 7                   RF           1.000          0.676
# 8             AdaBoost           0.860          0.593
# 9                  GBM           0.978          0.625
# 10             XGBoost           1.000          0.621
# 11            LightGBM           1.000          0.602
# 12            CatBoost           0.981          0.673
# 13             NGBoost           0.869          0.649

# %%
# For some distance-based models, we need to scale the features in order to
# increase the speed and the performance/accuracy level of the model.
# We can also see the effect of scaling type by changing the sclaer function.
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler

# %%
# Final Model
logreg_tuned = LogisticRegression(**logreg_cv_model.best_params_).fit(X_train, y_train)
y_pred = logreg_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8051948051948052
roc_auc_score(y_test, y_pred)  #0.6342857142857143
# Out:
# 0.6342857142857143

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LR-LR73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances
data1 = pd.read_csv("Inter-test-for-auc-dca-LR-LR73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.67      0.43      0.52        77
#  EGFR mutant       0.66      0.84      0.74       100
#
#     accuracy                           0.66       177
#    macro avg       0.66      0.63      0.63       177
# weighted avg       0.66      0.66      0.64       177
#
# precision 0.65625 accuracy 0.6610169491525424 recall 0.84

# %%
# Visualization of Results
# plot_feature_importances(logreg_tuned)
plot_results(logreg_tuned)
report_results_quickly(logreg_tuned)
plot_learning_curve(logreg_tuned)

# %%
# Final Model
rf_tuned = RandomForestClassifier(**rf_cv_model.best_params_).fit(X_train, y_train)
y_pred = rf_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.6892207792207792
roc_auc_score(y_test, y_pred)
# Out:
# 0.6342857142857143

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LR-RF73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-LR-RF73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)

#  precision    recall  f1-score   support

#    EGFR wild       0.70      0.56      0.62        77
#  EGFR mutant       0.71      0.82      0.76       100

#     accuracy                           0.71       177
#    macro avg       0.71      0.69      0.69       177
# weighted avg       0.71      0.71      0.70       177

# precision 0.7068965517241379 accuracy 0.7062146892655368 recall 0.82
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.67      0.43      0.52        77
#  EGFR mutant       0.66      0.84      0.74       100
#
#     accuracy                           0.66       177
#    macro avg       0.66      0.63      0.63       177
# weighted avg       0.66      0.66      0.64       177
#
# precision 0.65625 accuracy 0.6610169491525424 recall 0.84

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(rf_tuned)
report_results_quickly(rf_tuned)
plot_results(rf_tuned)
plot_learning_curve(rf_tuned)

# %%
# Final Model
xgb_tuned = XGBClassifier(**xgb_cv_model.best_params_).fit(X_train, y_train)
y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.672316384180791
# Out:
# 0.6271186440677966

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LR-XGB73.csv', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-LR-XGB73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.60      0.44      0.51        77
#  EGFR mutant       0.64      0.77      0.70       100
#
#     accuracy                           0.63       177
#    macro avg       0.62      0.61      0.60       177
# weighted avg       0.62      0.63      0.62       177
#
# precision 0.6416666666666667 accuracy 0.6271186440677966 recall 0.77

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(xgb_tuned)
report_results_quickly(xgb_tuned)
plot_results(xgb_tuned)
# plot_learning_curve(xgb_tuned)

# %%
# Final Model
lgbm_tuned = LGBMClassifier(**lgbm_cv_model.best_params_).fit(X_train, y_train)
y_pred = lgbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.6836158192090396

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-LR-lgb73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-LR-lgb73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.68      0.52      0.59        77
#  EGFR mutant       0.69      0.81      0.74       100
#
#     accuracy                           0.68       177
#    macro avg       0.68      0.66      0.67       177
# weighted avg       0.68      0.68      0.68       177
#
# precision 0.6864406779661016 accuracy 0.6836158192090396 recall 0.81

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(lgbm_tuned)
# report_results_quickly(lgbm_tuned)
plot_results(lgbm_tuned)
# plot_learning_curve(lgbm_tuned)

# %%
# Comparison of tuned models
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
tuned_models = [('LogisticRegression', logreg_tuned),
                ('RF', rf_tuned),
                ('XGBoost', xgb_tuned),
                ('LightGBM', lgbm_tuned)]


evaluate_classification_model_holdout(tuned_models)
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.634286
# RF: 0.674221
# XGBoost: 0.605779
# LightGBM: 0.664740
#
# ################ Train and test results for the model: ################
#
#                models  accuracy_train  accuracy_test
# 0  LogisticRegression           0.646          0.634
# 1                  RF           0.738          0.674
# 2             XGBoost           1.000          0.606
# 3            LightGBM           0.752          0.665

# %%
# Pickle Models --> Saving tuned models

# Create a folder named 'Models'
# save working directory
#
# cur_dir = os.getcwd()
# cur_dir
#
# # change working directory:
os.chdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/LR2023")
#
# # Save the models
for model in tuned_models:
    pickle.dump(model[1], open(str(model[0]) + ".pkl", 'wb'))

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
external_test=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-LR.csv")
external_test_label = external_test.label
# print(external_test_label)
external_test=external_test.drop(columns=['label'])

# %%
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB10.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17-42.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF11.csv",index=None)

external_test1=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-LR.csv")
external_test_label1 = external_test1.label
# print(external_test_label)
external_test1=external_test1.drop(columns=['label'])

# %%
######XGB  测试集1
import numpy as np
# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/LR/XGBoost.pkl', 'rb'))
external_test_pred=xgb.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-xgb-LR-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.35      0.81      0.49        26
#  EGFR mutant       0.84      0.41      0.55        66
#
#     accuracy                           0.52        92
#    macro avg       0.60      0.61      0.52        92
# weighted avg       0.70      0.52      0.53        92
#
# precision 0.84375 accuracy 0.5217391304347826 recall 0.4090909090909091

# %%
######XGB  测试集1
#############画图部分
# from sklearn.datasets import load_breast_cancer
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
import pylab as plt
import warnings;warnings.filterwarnings('ignore')
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for XbBoost')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
######XGB  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[21  5]
#  [39 27]]
# Normalized confusion matrix
# [[0.81 0.19]
#  [0.59 0.41]]

# %%
#####XGB  测试集2

import numpy as np

# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/LR/XGBoost.pkl', 'rb'))
external_test_pred1=xgb.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-xgb-LR-73.csv', external_test_pred1, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.59      0.38      0.46        42
#  EGFR mutant       0.57      0.76      0.65        46
#
#     accuracy                           0.58        88
#    macro avg       0.58      0.57      0.56        88
# weighted avg       0.58      0.58      0.56        88
#
# precision 0.5737704918032787 accuracy 0.5795454545454546 recall 0.7608695652173914

# %%
#####XGB  测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for XbBoost')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####XGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[16 26]
#  [11 35]]
# Normalized confusion matrix
# [[0.38 0.62]
#  [0.24 0.76]]

# %%
#####RF  测试集1
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/LR/RF.pkl', 'rb'))
external_test_pred=rft.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-RF-LR-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.36      0.73      0.48        26
#  EGFR mutant       0.82      0.48      0.61        66
#
#     accuracy                           0.55        92
#    macro avg       0.59      0.61      0.55        92
# weighted avg       0.69      0.55      0.57        92
#
# precision 0.8205128205128205 accuracy 0.5543478260869565 recall 0.48484848484848486

# %%
#####RF  测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####RF  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[19  7]
#  [34 32]]
# Normalized confusion matrix
# [[0.73 0.27]
#  [0.52 0.48]]

# %%
#####RF  测试集2
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/LR/RF.pkl', 'rb'))
external_test_pred1=rft.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-RF-LR-73.csv', external_test_pred1, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.64      0.33      0.44        42
#  EGFR mutant       0.58      0.83      0.68        46
#
#     accuracy                           0.59        88
#    macro avg       0.61      0.58      0.56        88
# weighted avg       0.60      0.59      0.56        88
#
# precision 0.5757575757575758 accuracy 0.5909090909090909 recall 0.8260869565217391

# %%
#####rf  测试集2

fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####rf  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[14 28]
#  [ 8 38]]
# Normalized confusion matrix
# [[0.33 0.67]
#  [0.17 0.83]]

# %%
######LR 测试集1
import numpy as np
# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/LR/LogisticRegression.pkl', 'rb'))
external_test_pred=lrt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-lr-LR-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.44      0.54      0.48        26
#  EGFR mutant       0.80      0.73      0.76        66
#
#     accuracy                           0.67        92
#    macro avg       0.62      0.63      0.62        92
# weighted avg       0.70      0.67      0.68        92
#
# precision 0.8 accuracy 0.6739130434782609 recall 0.7272727272727273

# %%
######LR 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[14 12]
#  [18 48]]
# Normalized confusion matrix
# [[0.54 0.46]
#  [0.27 0.73]]

# %%
######LR 测试集2
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/LR/LogisticRegression.pkl', 'rb'))
external_test_pred1=lrt.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-lr-LR-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.49      0.71      0.58        42
#  EGFR mutant       0.56      0.33      0.41        46
#
#     accuracy                           0.51        88
#    macro avg       0.52      0.52      0.50        88
# weighted avg       0.53      0.51      0.49        88
#
# precision 0.5555555555555556 accuracy 0.5113636363636364 recall 0.32608695652173914

# %%
######LR 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[30 12]
#  [31 15]]
# Normalized confusion matrix
# [[0.71 0.29]
#  [0.67 0.33]]

# %%
##lgb 测试集1
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/LR/LightGBM.pkl', 'rb'))
external_test_pred=lgbt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-lgb-LR-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.35      0.96      0.52        26
#  EGFR mutant       0.95      0.30      0.46        66
#
#     accuracy                           0.49        92
#    macro avg       0.65      0.63      0.49        92
# weighted avg       0.78      0.49      0.48        92
#
# precision 0.9523809523809523 accuracy 0.4891304347826087 recall 0.30303030303030304

# %%
##lgb 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
##lgb 测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[25  1]
#  [46 20]]
# Normalized confusion matrix
# [[0.96 0.04]
#  [0.7  0.3 ]]

# %%
#lgb 测试集2
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/LR/LightGBM.pkl', 'rb'))
external_test_pred1=lgbt.predict(external_test1)

np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-lgb-LR-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.60      0.67      0.63        42
#  EGFR mutant       0.66      0.59      0.62        46
#
#     accuracy                           0.62        88
#    macro avg       0.63      0.63      0.62        88
# weighted avg       0.63      0.62      0.62        88
#
# precision 0.6585365853658537 accuracy 0.625 recall 0.5869565217391305

# %%
#lgb 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[28 14]
#  [19 27]]
# Normalized confusion matrix
# [[0.67 0.33]
#  [0.41 0.59]]

# %%
# # Visualization of Results --> Feature Importances
# plot_feature_importances(lgbt)
# # report_results_quickly(lgbm_tuned)
# plot_results(lgbt)
# # plot_learning_curve(lgbm_tuned)
