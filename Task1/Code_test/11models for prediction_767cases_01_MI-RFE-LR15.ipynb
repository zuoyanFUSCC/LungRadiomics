# %%
# data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
import pandas as pd
import numpy as np
import os
data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/EGFR01-767cases-FS-results.xlsx", sheet_name='MIRFELR15')
data.keys()
train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore.csv")
test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv")
test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore.csv")
train=train[data.keys()]
train.shape
test=test[data.keys()]
test.shape
test1=test1[data.keys()]
test1.shape
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB10.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17-42.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF19.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-MIRFELR15.csv",index=None)

# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF17.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFEGB10.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFEGB18.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF17-42.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF18.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF19.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF5.csv",index=None)
test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-MIRFELR15.csv",index=None)

# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB10.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17-42.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-MIRFELR15.csv",index=None)

# %%
#%% load liabrary
import os
import numpy as np
import xlrd
import scipy.io as io
import pandas as pd
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFE
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit, train_test_split
from sklearn.linear_model import Lasso, Ridge, LassoCV,LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn import metrics
import itertools
import joblib
from scipy import stats
from sklearn import preprocessing
print("Import library done.\n")
# Out:
# Import library done.

# %%
# DIABETES PREDICTION MODEL

# CLASSIFICATION MODELS - HOLDOUT

'''
Steps to follow:
    - Load the saved dataset
    - General View
    - Modeling
        - Base models: LogisticRegression, GaussianNB, KNeighborsClassifier, SVC, MLPClassifier, DecisionTreeClassifier,
                       BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,
                       XGBClassifier, LGBMClassifier, CatBoostClassifier, NGBClassifier
    - Model Evaluation
    - Model Tuning
    - Model Results
'''

# Import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


# Load the preprocessed dataset
# diabetes_preprocessed = pd.read_csv('./diabetes_prepared.csv')

# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB10.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17-42.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF19.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF11.csv",index=None)

# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rferf17.csv")
# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rfegb5.csv")
diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-MIRFELR15.csv")




# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/Results_HRFS01/catboost/train.csv")
df = diabetes_preprocessed.copy()
# df = df.drop(columns="id",axis=1)

## GENERAL VIEW

df.head()
df.shape
df.info()
df.columns
df.index
df.describe([0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 16 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   CT_exponential_firstorder_90Percentile                     587 non-null    float64
#  1   CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized         587 non-null    float64
#  2   CT_lbp.3D.k_ngtdm_Coarseness                               587 non-null    float64
#  3   CT_log.sigma.1.0.mm.3D_firstorder_90Percentile             587 non-null    float64
#  4   CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis          587 non-null    float64
#  5   CT_square_ngtdm_Coarseness                                 587 non-null    float64
#  6   PET_exponential_glszm_ZoneVariance                         587 non-null    float64
#  7   PET_lbp.3D.k_firstorder_10Percentile                       587 non-null    float64
#  8   PET_wavelet.HLH_glcm_ClusterShade                          587 non-null    float64
#  9   PET_wavelet.HLH_gldm_LargeDependenceHighGrayLevelEmphasis  587 non-null    float64
#  10  PET_wavelet.LHL_glcm_Idmn                                  587 non-null    float64
#  11  PET_wavelet2.HHL_glcm_Idmn                                 587 non-null    float64
#  12  PET_exponential_gldm_DependenceEntropy                     587 non-null    float64
#  13  PET_wavelet.LLH_glcm_ClusterProminence                     587 non-null    float64
#  14  PET_wavelet2.HLH_glcm_ClusterShade                         587 non-null    float64
#  15  label                                                      587 non-null    int64
# dtypes: float64(15), int64(1)
# memory usage: 73.5 KB
#                                                      count   mean   std  \
# CT_exponential_firstorder_90Percentile             587.000  0.000 1.001
# CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized 587.000  0.000 1.001
# CT_lbp.3D.k_ngtdm_Coarseness                       587.000  0.000 1.001
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile     587.000 -0.000 1.001
# CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis  587.000 -0.000 1.001
# CT_square_ngtdm_Coarseness                         587.000 -0.000 1.001
# PET_exponential_glszm_ZoneVariance                 587.000 -0.000 1.001
# PET_lbp.3D.k_firstorder_10Percentile               587.000  0.000 1.001
# PET_wavelet.HLH_glcm_ClusterShade                  587.000  0.000 1.001
# PET_wavelet.HLH_gldm_LargeDependenceHighGrayLev... 587.000  0.000 1.001
# PET_wavelet.LHL_glcm_Idmn                          587.000 -0.000 1.001
# PET_wavelet2.HHL_glcm_Idmn                         587.000 -0.000 1.001
# PET_exponential_gldm_DependenceEntropy             587.000 -0.000 1.001
# PET_wavelet.LLH_glcm_ClusterProminence             587.000  0.000 1.001
# PET_wavelet2.HLH_glcm_ClusterShade                 587.000  0.000 1.001
# label                                              587.000  0.576 0.495
#
#                                                       min    10%    25%  \
# CT_exponential_firstorder_90Percentile             -0.409 -0.095 -0.057
# CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized -2.875 -1.641 -0.694
# CT_lbp.3D.k_ngtdm_Coarseness                       -0.088 -0.088 -0.047
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile     -3.240 -1.192 -0.581
# CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis  -0.199 -0.198 -0.198
# CT_square_ngtdm_Coarseness                         -0.053 -0.053 -0.053
# PET_exponential_glszm_ZoneVariance                 -0.241 -0.223 -0.184
# PET_lbp.3D.k_firstorder_10Percentile               -2.379 -1.733 -0.142
# PET_wavelet.HLH_glcm_ClusterShade                  -9.922 -0.079 -0.054
# PET_wavelet.HLH_gldm_LargeDependenceHighGrayLev... -0.513 -0.382 -0.320
# PET_wavelet.LHL_glcm_Idmn                          -5.360 -1.305 -0.617
# PET_wavelet2.HHL_glcm_Idmn                         -5.411 -1.325 -0.665
# PET_exponential_gldm_DependenceEntropy             -4.250 -1.134 -0.631
# PET_wavelet.LLH_glcm_ClusterProminence             -0.151 -0.151 -0.151
# PET_wavelet2.HLH_glcm_ClusterShade                 -5.645 -0.123 -0.101
# label                                               0.000  0.000  0.000
#
#                                                       50%    75%    90%  \
# CT_exponential_firstorder_90Percentile             -0.046 -0.040  0.046
# CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized  0.237  0.780  1.137
# CT_lbp.3D.k_ngtdm_Coarseness                       -0.047 -0.047 -0.047
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile      0.005  0.551  1.225
# CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis  -0.190 -0.167  0.069
# CT_square_ngtdm_Coarseness                         -0.053 -0.053 -0.003
# PET_exponential_glszm_ZoneVariance                 -0.164 -0.098  0.079
# PET_lbp.3D.k_firstorder_10Percentile                0.099  0.487  1.103
# PET_wavelet.HLH_glcm_ClusterShade                   0.035  0.043  0.098
# PET_wavelet.HLH_gldm_LargeDependenceHighGrayLev... -0.240  0.002  0.457
# PET_wavelet.LHL_glcm_Idmn                           0.263  0.787  1.024
# PET_wavelet2.HHL_glcm_Idmn                          0.215  0.769  1.160
# PET_exponential_gldm_DependenceEntropy             -0.023  0.586  1.223
# PET_wavelet.LLH_glcm_ClusterProminence             -0.148 -0.097 -0.069
# PET_wavelet2.HLH_glcm_ClusterShade                 -0.039 -0.035  0.013
# label                                               1.000  1.000  1.000
#
#                                                       95%    99%    max
# CT_exponential_firstorder_90Percentile              0.112  0.243 24.125
# CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized  1.338  1.624  1.740
# CT_lbp.3D.k_ngtdm_Coarseness                       -0.047 -0.047 21.031
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile      1.794  2.420  3.731
# CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis   0.549  3.507 12.726
# CT_square_ngtdm_Coarseness                         -0.003 -0.003 24.202
# PET_exponential_glszm_ZoneVariance                  0.318  2.746 13.946
# PET_lbp.3D.k_firstorder_10Percentile                1.500  2.493  3.528
# PET_wavelet.HLH_glcm_ClusterShade                   0.231  3.429 10.278
# PET_wavelet.HLH_gldm_LargeDependenceHighGrayLev...  0.922  3.391 16.447
# PET_wavelet.LHL_glcm_Idmn                           1.143  1.218  1.281
# PET_wavelet2.HHL_glcm_Idmn                          1.300  1.493  1.639
# PET_exponential_gldm_DependenceEntropy              1.695  2.620  4.045
# PET_wavelet.LLH_glcm_ClusterProminence              0.109  2.476 16.456
# PET_wavelet2.HLH_glcm_ClusterShade                  0.157  1.000 19.853
# label                                               1.000  1.000  1.000

# %%
# Check for missing values
df.isnull().values.any()
df.isnull().sum().sort_values(ascending=False)
# Out:
# CT_exponential_firstorder_90Percentile                       0
# CT_lbp.3D.k_glszm_GrayLevelNonUniformityNormalized           0
# CT_lbp.3D.k_ngtdm_Coarseness                                 0
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile               0
# CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis            0
# CT_square_ngtdm_Coarseness                                   0
# PET_exponential_glszm_ZoneVariance                           0
# PET_lbp.3D.k_firstorder_10Percentile                         0
# PET_wavelet.HLH_glcm_ClusterShade                            0
# PET_wavelet.HLH_gldm_LargeDependenceHighGrayLevelEmphasis    0
# PET_wavelet.LHL_glcm_Idmn                                    0
# PET_wavelet2.HHL_glcm_Idmn                                   0
# PET_exponential_gldm_DependenceEntropy                       0
# PET_wavelet.LLH_glcm_ClusterProminence                       0
# PET_wavelet2.HLH_glcm_ClusterShade                           0
# label                                                        0
# dtype: int64

# %%
# MODELING


# Define dependent and independent variables
y = df["label"]
X = df.drop(["label"], axis=1)

# y = df["Outcome"]
# X = df.drop(["Outcome"], axis=1)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# See the results for base models

base_models = [('LogisticRegression', LogisticRegression()),
               ('Naive Bayes', GaussianNB()),
               ('KNN', KNeighborsClassifier()),
               ('SVM', SVC()),
               ('ANN', MLPClassifier()),
               ('CART', DecisionTreeClassifier()),
               ('BaggedTrees', BaggingClassifier()),
               ('RF', RandomForestClassifier()),
               ('AdaBoost', AdaBoostClassifier()),
               ('GBM', GradientBoostingClassifier()),
               ("XGBoost", XGBClassifier()),
               ("LightGBM", LGBMClassifier()),
               ("CatBoost", CatBoostClassifier(verbose=False)),
               ("NGBoost", NGBClassifier(verbose=False))]

# %%
evaluate_classification_model_holdout(base_models)
# LogisticRegression: 0.805195
# Naive Bayes: 0.603896
# KNN: 0.850649
# SVM: 0.837662
# ANN: 0.850649
# CART: 0.824675
# BaggedTrees: 0.857143
# RF: 0.876623
# AdaBoost: 0.883117
# GBM: 0.870130
# XGBoost: 0.883117
# LightGBM: 0.857143
# CatBoost: 0.863636
# NGBoost: 0.863636
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.637273
# Naive Bayes: 0.584351
# KNN: 0.538312
# SVM: 0.584351
# ANN: 0.635779
# CART: 0.572727
# BaggedTrees: 0.586234
# RF: 0.644740
# AdaBoost: 0.569286
# GBM: 0.649740
# XGBoost: 0.629221
# LightGBM: 0.663701
# CatBoost: 0.633766
# NGBoost: 0.608766
#
# ################ Train and test results for the model: ################
#
#                 models  accuracy_train  accuracy_test
# 0   LogisticRegression           0.625          0.637
# 1          Naive Bayes           0.574          0.584
# 2                  KNN           0.703          0.538
# 3                  SVM           0.646          0.584
# 4                  ANN           0.717          0.636
# 5                 CART           1.000          0.573
# 6          BaggedTrees           0.980          0.586
# 7                   RF           1.000          0.645
# 8             AdaBoost           0.847          0.569
# 9                  GBM           0.956          0.650
# 10             XGBoost           1.000          0.629
# 11            LightGBM           1.000          0.664
# 12            CatBoost           0.973          0.634
# 13             NGBoost           0.848          0.609

# %%
# For some distance-based models, we need to scale the features in order to
# increase the speed and the performance/accuracy level of the model.
# We can also see the effect of scaling type by changing the sclaer function.
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler

# %%
# Final Model
logreg_tuned = LogisticRegression(**logreg_cv_model.best_params_).fit(X_train, y_train)
y_pred = logreg_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8051948051948052
roc_auc_score(y_test, y_pred)
# Out:
# 0.6517532467532469

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MIRFELR15-LR73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-MIRFELR15-LR73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.67      0.49      0.57        77
#  EGFR mutant       0.68      0.81      0.74       100
#
#     accuracy                           0.67       177
#    macro avg       0.67      0.65      0.65       177
# weighted avg       0.67      0.67      0.66       177
#
# precision 0.675 accuracy 0.672316384180791 recall 0.81

# %%
# Visualization of Results
# plot_feature_importances(logreg_tuned)
plot_results(logreg_tuned)
report_results_quickly(logreg_tuned)
plot_learning_curve(logreg_tuned)

# %%
# Final Model
rf_tuned = RandomForestClassifier(**rf_cv_model.best_params_).fit(X_train, y_train)
y_pred = rf_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8831168831168831
roc_auc_score(y_test, y_pred)
# Out:
# 0.6272727272727273

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MIRFELR15-RF73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MIRFELR15-RF73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.64      0.45      0.53        77
#  EGFR mutant       0.66      0.80      0.72       100
#
#     accuracy                           0.65       177
#    macro avg       0.65      0.63      0.63       177
# weighted avg       0.65      0.65      0.64       177
#
# precision 0.6557377049180327 accuracy 0.6497175141242938 recall 0.8

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(rf_tuned)
report_results_quickly(rf_tuned)
plot_results(rf_tuned)
plot_learning_curve(rf_tuned)

# %%
print(svm_model.best_params_)
# Out:
# {'C': 100, 'kernel': 'linear'}

# %%
# Final Model
svm_tuned = svm.SVC(**svm_model.best_params_).fit(X_train, y_train)
y_pred = svm_tuned.predict(X_test)
ACC = accuracy_score(y_test, y_pred) # 0.8831168831168831
roc_auc_score = roc_auc_score(y_test, y_pred)

print(ACC,roc_auc_score)
# Out:
# 0.6610169491525424 0.6357792207792208

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MIRFELR15-SVM73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MIRFELR15-SVM73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.67      0.44      0.53        77
#  EGFR mutant       0.66      0.83      0.73       100
#
#     accuracy                           0.66       177
#    macro avg       0.66      0.64      0.63       177
# weighted avg       0.66      0.66      0.65       177
#
# precision 0.6587301587301587 accuracy 0.6610169491525424 recall 0.83

# %%
# Visualization of Results --> Feature Importances
# plot_feature_importances(svm_tuned)
# report_results_quickly(svm_tuned)
plot_results(svm_tuned)
# plot_learning_curve(svm_tuned)
# Out:
# ---------------------------------------------------------------------------
# ModelError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31604\1389029473.py in <module>
#       2 # plot_feature_importances(svm_tuned)
#       3 # report_results_quickly(svm_tuned)
# ----> 4 plot_results(svm_tuned)
#       5 # plot_learning_curve(svm_tuned)
#
# ~\AppData\Local\Temp\ipykernel_31604\2712900522.py in plot_results(model)
#       3     plot_confusion_matrix_yb(model)
#       4     plot_classification_report_yb(model)
# ----> 5     plot_roc_auc_curve_yb(model)
#       6     plot_class_prediction_error_yb(model)
#
# ~\AppData\Local\Temp\ipykernel_31604\2207885490.py in plot_roc_auc_curve_yb(model)
#       5     visualizer = ROCAUC(model, classes=["EGFR Wild", "EGFR Mutated"])
#       6     visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
# ----> 7     visualizer.score(X_test, y_test)  # Evaluate the model on the test data
#       8     visualizer.show();  # Finalize and show the figure
#
# ~\.conda\envs\tf\lib\site-packages\yellowbrick\classifier\rocauc.py in score(self, X, y)
#     279             if (self.micro or self.macro) and len(y_pred.shape) == 1:
#     280                 raise ModelError(
# --> 281                     "no curves will be drawn; set binary=True.",
#     282                 )
#     283
#
# ModelError: no curves will be drawn; set binary=True.

# %%
# Final Model
xgb_tuned = XGBClassifier(**xgb_cv_model.best_params_).fit(X_train, y_train)
y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.655367231638418

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MIRFELR15-XGB73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MIRFELR15-XGB73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.65      0.44      0.53        77
#  EGFR mutant       0.66      0.82      0.73       100
#
#     accuracy                           0.66       177
#    macro avg       0.65      0.63      0.63       177
# weighted avg       0.66      0.66      0.64       177
#
# precision 0.656 accuracy 0.655367231638418 recall 0.82

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(xgb_tuned)
report_results_quickly(xgb_tuned)
plot_results(xgb_tuned)
# plot_learning_curve(xgb_tuned)

# %%
# Final Model
lgbm_tuned = LGBMClassifier(**lgbm_cv_model.best_params_).fit(X_train, y_train)
y_pred = lgbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.6666666666666666

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MIRFELR15-lgb73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MIRFELR15-lgb73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.65      0.52      0.58        77
#  EGFR mutant       0.68      0.78      0.73       100
#
#     accuracy                           0.67       177
#    macro avg       0.66      0.65      0.65       177
# weighted avg       0.66      0.67      0.66       177
#
# precision 0.6782608695652174 accuracy 0.6666666666666666 recall 0.78

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(lgbm_tuned)
# report_results_quickly(lgbm_tuned)
plot_results(lgbm_tuned)
# plot_learning_curve(lgbm_tuned)

# %%
# Comparison of tuned models
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
tuned_models = [('LogisticRegression', logreg_tuned),
                ('RF', rf_tuned),
                ('XGBoost', xgb_tuned),
                ('LightGBM', lgbm_tuned)]


evaluate_classification_model_holdout(tuned_models)
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.651753
# RF: 0.611299
# XGBoost: 0.630779
# LightGBM: 0.649740
#
# ################ Train and test results for the model: ################
#
#                models  accuracy_train  accuracy_test
# 0  LogisticRegression           0.721          0.652
# 1                  RF           0.752          0.611
# 2             XGBoost           0.745          0.631
# 3            LightGBM           0.915          0.650

# %%
# Stack models
from mlxtend.classifier import StackingCVClassifier
stack_gen = StackingCVClassifier(classifiers=(logreg_tuned, rf_tuned, xgb_tuned, lgbm_tuned), meta_classifier=xgb_tuned)
stack_gen_model = stack_gen.fit(X_train, y_train)

evaluate_classification_model_holdout([('stack model', stack_gen_model)]) # 0.890
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# stack model: 0.667727
#
# ################ Train and test results for the model: ################
#
#         models  accuracy_train  accuracy_test
# 0  stack model           0.776          0.668

# %%
# Function ot blend models
def blend_models_predict(X_test):
    return ((0.1 * logreg_tuned.predict(X_test)) +
            (0.2 * rf_tuned.predict(X_test)) +
            (0.2 * xgb_tuned.predict(X_test)) +
            (0.2 * lgbm_tuned.predict(X_test)) +
#             (0.1 * svm_tuned.predict(X_test)) +
            (0.3 * stack_gen_model.predict(X_test)))

# %%
accuracy_score(y_test, blend_models_predict(X_test).round())# 0.8701298701298701
# aucroc_score(y_test, blend_models_predict(X_test).round())# 0.8701298701298701
roc_auc_score(y_test, blend_models_predict(X_test).round())
# Out:
# 0.6452597402597403

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MIRFELR15-stack73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MIRFELR15-stack73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)

# %%
# Pickle Models --> Saving tuned models

# Create a folder named 'Models'
# save working directory
#
# cur_dir = os.getcwd()
# cur_dir
#
# # change working directory:
os.chdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MIRFELR15")
#
# # Save the models
for model in tuned_models:
    pickle.dump(model[1], open(str(model[0]) + ".pkl", 'wb'))

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
external_test=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-MIRFELR15.csv")
external_test_label = external_test.label
# print(external_test_label)
external_test=external_test.drop(columns=['label'])

# %%
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB10.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17-42.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF11.csv",index=None)

external_test1=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-MIRFELR15.csv")
external_test_label1 = external_test1.label
# print(external_test_label)
external_test1=external_test1.drop(columns=['label'])

# %%
######XGB  测试集1
import numpy as np
# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MIRFELR15/XGBoost.pkl', 'rb'))
external_test_pred=xgb.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-xgb-MIRFELR15-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.47      0.73      0.58        26
#  EGFR mutant       0.87      0.68      0.76        66
#
#     accuracy                           0.70        92
#    macro avg       0.67      0.71      0.67        92
# weighted avg       0.76      0.70      0.71        92
#
# precision 0.8653846153846154 accuracy 0.6956521739130435 recall 0.6818181818181818

# %%
######XGB  测试集1
#############画图部分
# from sklearn.datasets import load_breast_cancer
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
import pylab as plt
import warnings;warnings.filterwarnings('ignore')
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for XbBoost')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "white")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
######XGB  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[19  7]
#  [21 45]]
# Normalized confusion matrix
# [[0.73 0.27]
#  [0.32 0.68]]

# %%
#####XGB  测试集2

import numpy as np

# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MIRFELR15/XGBoost.pkl', 'rb'))
external_test_pred1=xgb.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-xgb-MIRFELR15-73.csv', external_test_pred1, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.47      0.40      0.44        42
#  EGFR mutant       0.52      0.59      0.55        46
#
#     accuracy                           0.50        88
#    macro avg       0.50      0.50      0.49        88
# weighted avg       0.50      0.50      0.50        88
#
# precision 0.5192307692307693 accuracy 0.5 recall 0.5869565217391305

# %%
#####XGB  测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for XbBoost')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####XGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[17 25]
#  [19 27]]
# Normalized confusion matrix
# [[0.4  0.6 ]
#  [0.41 0.59]]

# %%
#####RF  测试集1
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MIRFELR15/RF.pkl', 'rb'))
external_test_pred=rft.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-RF-MIRFELR15-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.45      0.50      0.47        26
#  EGFR mutant       0.79      0.76      0.78        66
#
#     accuracy                           0.68        92
#    macro avg       0.62      0.63      0.62        92
# weighted avg       0.70      0.68      0.69        92
#
# precision 0.7936507936507936 accuracy 0.6847826086956522 recall 0.7575757575757576

# %%
#####RF  测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####RF  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[13 13]
#  [16 50]]
# Normalized confusion matrix
# [[0.5  0.5 ]
#  [0.24 0.76]]

# %%
#####RF  测试集2
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MIRFELR15/RF.pkl', 'rb'))
external_test_pred1=rft.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-RF-MIRFELR15-73.csv', external_test_pred1, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.62      0.38      0.47        42
#  EGFR mutant       0.58      0.78      0.67        46
#
#     accuracy                           0.59        88
#    macro avg       0.60      0.58      0.57        88
# weighted avg       0.60      0.59      0.57        88
#
# precision 0.5806451612903226 accuracy 0.5909090909090909 recall 0.782608695652174

# %%
#####rf  测试集2

fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####rf  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[16 26]
#  [10 36]]
# Normalized confusion matrix
# [[0.38 0.62]
#  [0.22 0.78]]

# %%
######LR 测试集1
import numpy as np
# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MIRFELR15/LogisticRegression.pkl', 'rb'))
external_test_pred=lrt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-lr-MIRFELR15-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.25      0.23      0.24        26
#  EGFR mutant       0.71      0.73      0.72        66
#
#     accuracy                           0.59        92
#    macro avg       0.48      0.48      0.48        92
# weighted avg       0.58      0.59      0.58        92
#
# precision 0.7058823529411765 accuracy 0.5869565217391305 recall 0.7272727272727273

# %%
######LR 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 6 20]
#  [18 48]]
# Normalized confusion matrix
# [[0.23 0.77]
#  [0.27 0.73]]

# %%
######LR 测试集2
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MIRFELR15/LogisticRegression.pkl', 'rb'))
external_test_pred1=lrt.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-lr-MIRFELR15-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.46      0.79      0.58        42
#  EGFR mutant       0.47      0.17      0.25        46
#
#     accuracy                           0.47        88
#    macro avg       0.47      0.48      0.42        88
# weighted avg       0.47      0.47      0.41        88
#
# precision 0.47058823529411764 accuracy 0.4659090909090909 recall 0.17391304347826086

# %%
######LR 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[33  9]
#  [38  8]]
# Normalized confusion matrix
# [[0.79 0.21]
#  [0.83 0.17]]

# %%
##lgb 测试集1
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MIRFELR15/LightGBM.pkl', 'rb'))
external_test_pred=lgbt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-lgb-MIRFELR15-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.43      0.73      0.54        26
#  EGFR mutant       0.85      0.62      0.72        66
#
#     accuracy                           0.65        92
#    macro avg       0.64      0.68      0.63        92
# weighted avg       0.73      0.65      0.67        92
#
# precision 0.8541666666666666 accuracy 0.6521739130434783 recall 0.6212121212121212

# %%
##lgb 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
##lgb 测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[19  7]
#  [25 41]]
# Normalized confusion matrix
# [[0.73 0.27]
#  [0.38 0.62]]

# %%
#lgb 测试集2
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MIRFELR15/LightGBM.pkl', 'rb'))
external_test_pred1=lgbt.predict(external_test1)

np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-lgb-MIRFELR15-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.42      0.52      0.47        42
#  EGFR mutant       0.44      0.35      0.39        46
#
#     accuracy                           0.43        88
#    macro avg       0.43      0.44      0.43        88
# weighted avg       0.43      0.43      0.43        88
#
# precision 0.4444444444444444 accuracy 0.4318181818181818 recall 0.34782608695652173

# %%
#lgb 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[22 20]
#  [30 16]]
# Normalized confusion matrix
# [[0.52 0.48]
#  [0.65 0.35]]

# %%
# # Visualization of Results --> Feature Importances
# plot_feature_importances(lgbt)
# # report_results_quickly(lgbm_tuned)
# plot_results(lgbt)
# # plot_learning_curve(lgbm_tuned)
