# %%
# data = pd.read_excel("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/RFE.xlsx", sheet_name='g1rfegb12')
import pandas as pd
import numpy as np
import os
data = pd.read_excel("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/EGFR01-767cases-FS-results.xlsx",
                     sheet_name='MISBSLGB24')
data.keys()
train = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore.csv")
test = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore.csv")
test1 = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore.csv")
train=train[data.keys()]
train.shape
test=test[data.keys()]
test.shape
test1=test1[data.keys()]
test1.shape
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB10.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17-42.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF19.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-MISBSLGB24.csv",index=None)

# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF17.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFEGB10.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFEGB18.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF17-42.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF18.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF19.csv",index=None)
# test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-RFERF5.csv",index=None)
test.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-MISBSLGB24.csv",index=None)

# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB10.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17-42.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-MISBSLGB24.csv",index=None)

# %%
#%% load liabrary
import os
import numpy as np
import xlrd
import scipy.io as io
import pandas as pd
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import RFE
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit, train_test_split
from sklearn.linear_model import Lasso, Ridge, LassoCV,LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn import metrics
import itertools
import joblib
from scipy import stats
from sklearn import preprocessing
print("Import library done.\n")
# Out:
# Import library done.

# %%
# DIABETES PREDICTION MODEL

# CLASSIFICATION MODELS - HOLDOUT

'''
Steps to follow:
    - Load the saved dataset
    - General View
    - Modeling
        - Base models: LogisticRegression, GaussianNB, KNeighborsClassifier, SVC, MLPClassifier, DecisionTreeClassifier,
                       BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,
                       XGBClassifier, LGBMClassifier, CatBoostClassifier, NGBClassifier
    - Model Evaluation
    - Model Tuning
    - Model Results
'''

# Import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


# Load the preprocessed dataset
# diabetes_preprocessed = pd.read_csv('./diabetes_prepared.csv')

# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB10.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFEGB18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF17-42.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF18.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF19.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF5.csv",index=None)
# train.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-RFERF11.csv",index=None)

# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rferf17.csv")
# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/375cases_e/fs_pre_01/group1/new-auc/train_rfegb5.csv")
diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/trainZscore-MISBSLGB24.csv")




# diabetes_preprocessed = pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/Results_HRFS01/catboost/train.csv")
df = diabetes_preprocessed.copy()
# df = df.drop(columns="id",axis=1)

## GENERAL VIEW

df.head()
df.shape
df.info()
df.columns
df.index
df.describe([0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 587 entries, 0 to 586
# Data columns (total 25 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   CT_exponential_firstorder_Kurtosis                         587 non-null    float64
#  1   CT_gradient_glszm_GrayLevelNonUniformityNormalized         587 non-null    float64
#  2   CT_log.sigma.1.0.mm.3D_firstorder_90Percentile             587 non-null    float64
#  3   CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis           587 non-null    float64
#  4   CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis          587 non-null    float64
#  5   CT_original_shape_Sphericity                               587 non-null    float64
#  6   CT_square_ngtdm_Coarseness                                 587 non-null    float64
#  7   CT_wavelet.HLH_glszm_SmallAreaEmphasis                     587 non-null    float64
#  8   CT_wavelet2.HLL_firstorder_Median                          587 non-null    float64
#  9   PET_exponential_glszm_SizeZoneNonUniformityNormalized      587 non-null    float64
#  10  PET_log.sigma.1.0.mm.3D_ngtdm_Contrast                     587 non-null    float64
#  11  PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis                587 non-null    float64
#  12  PET_square_gldm_DependenceVariance                         587 non-null    float64
#  13  PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmphasis        587 non-null    float64
#  14  PET_wavelet.HLH_glcm_ClusterShade                          587 non-null    float64
#  15  PET_wavelet.HLL_firstorder_Median                          587 non-null    float64
#  16  PET_wavelet.LHH_glcm_Idmn                                  587 non-null    float64
#  17  PET_wavelet.LHL_firstorder_Mean                            587 non-null    float64
#  18  PET_wavelet.LHL_gldm_LargeDependenceLowGrayLevelEmphasis   587 non-null    float64
#  19  PET_wavelet2.HHH_gldm_SmallDependenceLowGrayLevelEmphasis  587 non-null    float64
#  20  PET_wavelet2.HHH_glszm_SmallAreaLowGrayLevelEmphasis       587 non-null    float64
#  21  PET_wavelet2.HLH_glcm_Correlation                          587 non-null    float64
#  22  PET_wavelet2.LHL_firstorder_Skewness                       587 non-null    float64
#  23  PET_wavelet2.LLL_firstorder_10Percentile                   587 non-null    float64
#  24  label                                                      587 non-null    int64
# dtypes: float64(24), int64(1)
# memory usage: 114.8 KB
#                                                      count   mean   std  \
# CT_exponential_firstorder_Kurtosis                 587.000  0.000 1.001
# CT_gradient_glszm_GrayLevelNonUniformityNormalized 587.000 -0.000 1.001
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile     587.000 -0.000 1.001
# CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis   587.000 -0.000 1.001
# CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis  587.000 -0.000 1.001
# CT_original_shape_Sphericity                       587.000  0.000 1.001
# CT_square_ngtdm_Coarseness                         587.000 -0.000 1.001
# CT_wavelet.HLH_glszm_SmallAreaEmphasis             587.000 -0.000 1.001
# CT_wavelet2.HLL_firstorder_Median                  587.000  0.000 1.001
# PET_exponential_glszm_SizeZoneNonUniformityNorm... 587.000  0.000 1.001
# PET_log.sigma.1.0.mm.3D_ngtdm_Contrast             587.000 -0.000 1.001
# PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis        587.000  0.000 1.001
# PET_square_gldm_DependenceVariance                 587.000 -0.000 1.001
# PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmph... 587.000 -0.000 1.001
# PET_wavelet.HLH_glcm_ClusterShade                  587.000  0.000 1.001
# PET_wavelet.HLL_firstorder_Median                  587.000 -0.000 1.001
# PET_wavelet.LHH_glcm_Idmn                          587.000 -0.000 1.001
# PET_wavelet.LHL_firstorder_Mean                    587.000 -0.000 1.001
# PET_wavelet.LHL_gldm_LargeDependenceLowGrayLeve... 587.000  0.000 1.001
# PET_wavelet2.HHH_gldm_SmallDependenceLowGrayLev... 587.000  0.000 1.001
# PET_wavelet2.HHH_glszm_SmallAreaLowGrayLevelEmp... 587.000 -0.000 1.001
# PET_wavelet2.HLH_glcm_Correlation                  587.000  0.000 1.001
# PET_wavelet2.LHL_firstorder_Skewness               587.000  0.000 1.001
# PET_wavelet2.LLL_firstorder_10Percentile           587.000 -0.000 1.001
# label                                              587.000  0.576 0.495
#
#                                                       min    10%    25%  \
# CT_exponential_firstorder_Kurtosis                 -0.242 -0.239 -0.184
# CT_gradient_glszm_GrayLevelNonUniformityNormalized -1.488 -0.562 -0.359
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile     -3.240 -1.192 -0.581
# CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis   -1.661 -0.781 -0.592
# CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis  -0.199 -0.198 -0.198
# CT_original_shape_Sphericity                       -3.160 -1.278 -0.636
# CT_square_ngtdm_Coarseness                         -0.053 -0.053 -0.053
# CT_wavelet.HLH_glszm_SmallAreaEmphasis             -5.026 -1.028 -0.414
# CT_wavelet2.HLL_firstorder_Median                  -6.913 -0.910 -0.220
# PET_exponential_glszm_SizeZoneNonUniformityNorm... -2.875 -1.260 -0.589
# PET_log.sigma.1.0.mm.3D_ngtdm_Contrast             -0.441 -0.391 -0.330
# PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis        -2.394 -0.834 -0.517
# PET_square_gldm_DependenceVariance                 -0.729 -0.469 -0.384
# PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmph... -1.056 -1.053 -0.875
# PET_wavelet.HLH_glcm_ClusterShade                  -9.922 -0.079 -0.054
# PET_wavelet.HLL_firstorder_Median                  -7.215 -1.059 -0.410
# PET_wavelet.LHH_glcm_Idmn                          -4.361 -1.806 -0.458
# PET_wavelet.LHL_firstorder_Mean                    -8.237 -0.681 -0.239
# PET_wavelet.LHL_gldm_LargeDependenceLowGrayLeve... -0.408 -0.384 -0.293
# PET_wavelet2.HHH_gldm_SmallDependenceLowGrayLev... -1.390 -0.856 -0.658
# PET_wavelet2.HHH_glszm_SmallAreaLowGrayLevelEmp... -1.056 -1.051 -0.944
# PET_wavelet2.HLH_glcm_Correlation                  -5.077 -1.060 -0.328
# PET_wavelet2.LHL_firstorder_Skewness               -8.125 -0.814 -0.277
# PET_wavelet2.LLL_firstorder_10Percentile           -1.514 -0.851 -0.639
# label                                               0.000  0.000  0.000
#
#                                                       50%    75%    90%  \
# CT_exponential_firstorder_Kurtosis                 -0.183 -0.178 -0.020
# CT_gradient_glszm_GrayLevelNonUniformityNormalized -0.177  0.090  0.538
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile      0.005  0.551  1.225
# CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis   -0.258  0.265  1.172
# CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis  -0.190 -0.167  0.069
# CT_original_shape_Sphericity                       -0.002  0.670  1.292
# CT_square_ngtdm_Coarseness                         -0.053 -0.053 -0.003
# CT_wavelet.HLH_glszm_SmallAreaEmphasis              0.098  0.596  1.073
# CT_wavelet2.HLL_firstorder_Median                   0.032  0.321  0.820
# PET_exponential_glszm_SizeZoneNonUniformityNorm...  0.037  0.574  1.125
# PET_log.sigma.1.0.mm.3D_ngtdm_Contrast             -0.257 -0.090  0.512
# PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis        -0.182  0.263  1.121
# PET_square_gldm_DependenceVariance                 -0.269 -0.019  0.665
# PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmph... -0.313  0.808  1.438
# PET_wavelet.HLH_glcm_ClusterShade                   0.035  0.043  0.098
# PET_wavelet.HLL_firstorder_Median                   0.025  0.398  0.955
# PET_wavelet.LHH_glcm_Idmn                           0.335  0.779  0.976
# PET_wavelet.LHL_firstorder_Mean                     0.012  0.246  0.658
# PET_wavelet.LHL_gldm_LargeDependenceLowGrayLeve... -0.278 -0.152  0.473
# PET_wavelet2.HHH_gldm_SmallDependenceLowGrayLev... -0.275  0.323  1.302
# PET_wavelet2.HHH_glszm_SmallAreaLowGrayLevelEmp... -0.289  0.599  1.608
# PET_wavelet2.HLH_glcm_Correlation                   0.135  0.533  0.900
# PET_wavelet2.LHL_firstorder_Skewness                0.030  0.299  0.644
# PET_wavelet2.LLL_firstorder_10Percentile           -0.242  0.254  1.097
# label                                               1.000  1.000  1.000
#
#                                                       95%    99%    max
# CT_exponential_firstorder_Kurtosis                  0.881  3.228 18.093
# CT_gradient_glszm_GrayLevelNonUniformityNormalized  1.061  3.304 11.195
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile      1.794  2.420  3.731
# CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis    1.787  3.740  9.260
# CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis   0.549  3.507 12.726
# CT_original_shape_Sphericity                        1.628  2.133  2.697
# CT_square_ngtdm_Coarseness                         -0.003 -0.003 24.202
# CT_wavelet.HLH_glszm_SmallAreaEmphasis              1.344  2.022  2.451
# CT_wavelet2.HLL_firstorder_Median                   1.487  2.547  5.694
# PET_exponential_glszm_SizeZoneNonUniformityNorm...  1.523  2.912  2.912
# PET_log.sigma.1.0.mm.3D_ngtdm_Contrast              0.887  4.994 11.538
# PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis         1.851  3.447  8.861
# PET_square_gldm_DependenceVariance                  1.241  3.859 10.974
# PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmph...  1.912  2.548  3.268
# PET_wavelet.HLH_glcm_ClusterShade                   0.231  3.429 10.278
# PET_wavelet.HLL_firstorder_Median                   1.498  2.971  4.358
# PET_wavelet.LHH_glcm_Idmn                           1.064  1.216  1.387
# PET_wavelet.LHL_firstorder_Mean                     0.995  2.624 10.244
# PET_wavelet.LHL_gldm_LargeDependenceLowGrayLeve...  1.384  5.163 13.797
# PET_wavelet2.HHH_gldm_SmallDependenceLowGrayLev...  1.832  4.159  5.405
# PET_wavelet2.HHH_glszm_SmallAreaLowGrayLevelEmp...  1.844  2.533  3.260
# PET_wavelet2.HLH_glcm_Correlation                   1.125  1.746  8.489
# PET_wavelet2.LHL_firstorder_Skewness                1.090  2.919  9.981
# PET_wavelet2.LLL_firstorder_10Percentile            1.754  3.920  6.213
# label                                               1.000  1.000  1.000

# %%
# Check for missing values
df.isnull().values.any()
df.isnull().sum().sort_values(ascending=False)
# Out:
# CT_exponential_firstorder_Kurtosis                           0
# PET_wavelet.HHH_glszm_SmallAreaLowGrayLevelEmphasis          0
# PET_wavelet2.LLL_firstorder_10Percentile                     0
# PET_wavelet2.LHL_firstorder_Skewness                         0
# PET_wavelet2.HLH_glcm_Correlation                            0
# PET_wavelet2.HHH_glszm_SmallAreaLowGrayLevelEmphasis         0
# PET_wavelet2.HHH_gldm_SmallDependenceLowGrayLevelEmphasis    0
# PET_wavelet.LHL_gldm_LargeDependenceLowGrayLevelEmphasis     0
# PET_wavelet.LHL_firstorder_Mean                              0
# PET_wavelet.LHH_glcm_Idmn                                    0
# PET_wavelet.HLL_firstorder_Median                            0
# PET_wavelet.HLH_glcm_ClusterShade                            0
# PET_square_gldm_DependenceVariance                           0
# CT_gradient_glszm_GrayLevelNonUniformityNormalized           0
# PET_log.sigma.3.0.mm.3D_firstorder_Kurtosis                  0
# PET_log.sigma.1.0.mm.3D_ngtdm_Contrast                       0
# PET_exponential_glszm_SizeZoneNonUniformityNormalized        0
# CT_wavelet2.HLL_firstorder_Median                            0
# CT_wavelet.HLH_glszm_SmallAreaEmphasis                       0
# CT_square_ngtdm_Coarseness                                   0
# CT_original_shape_Sphericity                                 0
# CT_logarithm_glszm_LargeAreaHighGrayLevelEmphasis            0
# CT_log.sigma.1.0.mm.3D_gldm_LowGrayLevelEmphasis             0
# CT_log.sigma.1.0.mm.3D_firstorder_90Percentile               0
# label                                                        0
# dtype: int64

# %%
# MODELING


# Define dependent and independent variables
y = df["label"]
X = df.drop(["label"], axis=1)

# y = df["Outcome"]
# X = df.drop(["Outcome"], axis=1)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# See the results for base models

base_models = [('LogisticRegression', LogisticRegression()),
               ('Naive Bayes', GaussianNB()),
               ('KNN', KNeighborsClassifier()),
               ('SVM', SVC()),
               ('ANN', MLPClassifier()),
               ('CART', DecisionTreeClassifier()),
               ('BaggedTrees', BaggingClassifier()),
               ('RF', RandomForestClassifier()),
               ('AdaBoost', AdaBoostClassifier()),
               ('GBM', GradientBoostingClassifier()),
               ("XGBoost", XGBClassifier()),
               ("LightGBM", LGBMClassifier()),
               ("CatBoost", CatBoostClassifier(verbose=False)),
               ("NGBoost", NGBClassifier(verbose=False))]

# %%
evaluate_classification_model_holdout(base_models)
# LogisticRegression: 0.805195
# Naive Bayes: 0.603896
# KNN: 0.850649
# SVM: 0.837662
# ANN: 0.850649
# CART: 0.824675
# BaggedTrees: 0.857143
# RF: 0.876623
# AdaBoost: 0.883117
# GBM: 0.870130
# XGBoost: 0.883117
# LightGBM: 0.857143
# CatBoost: 0.863636
# NGBoost: 0.863636
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.549286
# Naive Bayes: 0.625260
# KNN: 0.549221
# SVM: 0.508312
# ANN: 0.532792
# CART: 0.543247
# BaggedTrees: 0.623701
# RF: 0.599286
# AdaBoost: 0.534286
# GBM: 0.569805
# XGBoost: 0.580779
# LightGBM: 0.549286
# CatBoost: 0.581299
# NGBoost: 0.601299
#
# ################ Train and test results for the model: ################
#
#                 models  accuracy_train  accuracy_test
# 0   LogisticRegression           0.632          0.549
# 1          Naive Bayes           0.658          0.625
# 2                  KNN           0.717          0.549
# 3                  SVM           0.799          0.508
# 4                  ANN           0.861          0.533
# 5                 CART           1.000          0.543
# 6          BaggedTrees           0.984          0.624
# 7                   RF           1.000          0.599
# 8             AdaBoost           0.920          0.534
# 9                  GBM           0.994          0.570
# 10             XGBoost           1.000          0.581
# 11            LightGBM           1.000          0.549
# 12            CatBoost           1.000          0.581
# 13             NGBoost           0.897          0.601

# %%
# For some distance-based models, we need to scale the features in order to
# increase the speed and the performance/accuracy level of the model.
# We can also see the effect of scaling type by changing the sclaer function.
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler

# %%
# Final Model
logreg_tuned = LogisticRegression(**logreg_cv_model.best_params_).fit(X_train, y_train)
y_pred = logreg_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8051948051948052
roc_auc_score(y_test, y_pred)
# Out:
# 0.6047402597402597

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISBSLGB24-LR73', Save_format = 'csv',Save_type = 'col')

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from ngboost import NGBClassifier

import os
import pickle

from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, StratifiedKFold

from yellowbrick.classifier import ConfusionMatrix, ClassificationReport, ROCAUC, ClassPredictionError
from yellowbrick.model_selection import LearningCurve, FeatureImportances


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# # Load the model that we saved before
data1 = pd.read_csv("Inter-test-for-auc-dca-MISBSLGB24-LR73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.56      0.52      0.54        77
#  EGFR mutant       0.65      0.69      0.67       100
#
#     accuracy                           0.62       177
#    macro avg       0.61      0.60      0.61       177
# weighted avg       0.61      0.62      0.61       177
#
# precision 0.6509433962264151 accuracy 0.615819209039548 recall 0.69

# %%
# Visualization of Results
# plot_feature_importances(logreg_tuned)
plot_results(logreg_tuned)
report_results_quickly(logreg_tuned)
plot_learning_curve(logreg_tuned)

# %%
# Final Model
rf_tuned = RandomForestClassifier(**rf_cv_model.best_params_).fit(X_train, y_train)
y_pred = rf_tuned.predict(X_test)
# accuracy_score(y_test, y_pred) # 0.8831168831168831
roc_auc_score(y_test, y_pred)
# Out:
# 0.6242857142857143

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISBSLGB24-RF73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MISBSLGB24-RF73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.65      0.43      0.52        77
#  EGFR mutant       0.65      0.82      0.73       100
#
#     accuracy                           0.65       177
#    macro avg       0.65      0.62      0.62       177
# weighted avg       0.65      0.65      0.63       177
#
# precision 0.6507936507936508 accuracy 0.6497175141242938 recall 0.82

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(rf_tuned)
report_results_quickly(rf_tuned)
plot_results(rf_tuned)
plot_learning_curve(rf_tuned)

# %%
# Final Model
svm_tuned = svm.SVC(**svm_model.best_params_).fit(X_train, y_train)
y_pred = svm_tuned.predict(X_test)
ACC = accuracy_score(y_test, y_pred) # 0.8831168831168831
roc_auc_score = roc_auc_score(y_test, y_pred)

print(ACC,roc_auc_score)
# Out:
# 0.6440677966101694 0.6103246753246754

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISBSLGB24-SVM73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MISBSLGB24-SVM73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.68      0.35      0.46        77
#  EGFR mutant       0.64      0.87      0.73       100
#
#     accuracy                           0.64       177
#    macro avg       0.66      0.61      0.60       177
# weighted avg       0.65      0.64      0.62       177
#
# precision 0.635036496350365 accuracy 0.6440677966101694 recall 0.87

# %%
# Visualization of Results --> Feature Importances
# plot_feature_importances(svm_tuned)
# report_results_quickly(svm_tuned)
plot_results(svm_tuned)
# plot_learning_curve(svm_tuned)
# Out:
# ---------------------------------------------------------------------------
# ModelError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17868\1389029473.py in <module>
#       2 # plot_feature_importances(svm_tuned)
#       3 # report_results_quickly(svm_tuned)
# ----> 4 plot_results(svm_tuned)
#       5 # plot_learning_curve(svm_tuned)
#
# ~\AppData\Local\Temp\ipykernel_17868\2712900522.py in plot_results(model)
#       3     plot_confusion_matrix_yb(model)
#       4     plot_classification_report_yb(model)
# ----> 5     plot_roc_auc_curve_yb(model)
#       6     plot_class_prediction_error_yb(model)
#
# ~\AppData\Local\Temp\ipykernel_17868\2207885490.py in plot_roc_auc_curve_yb(model)
#       5     visualizer = ROCAUC(model, classes=["EGFR Wild", "EGFR Mutated"])
#       6     visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
# ----> 7     visualizer.score(X_test, y_test)  # Evaluate the model on the test data
#       8     visualizer.show();  # Finalize and show the figure
#
# ~\.conda\envs\tf\lib\site-packages\yellowbrick\classifier\rocauc.py in score(self, X, y)
#     279             if (self.micro or self.macro) and len(y_pred.shape) == 1:
#     280                 raise ModelError(
# --> 281                     "no curves will be drawn; set binary=True.",
#     282                 )
#     283
#
# ModelError: no curves will be drawn; set binary=True.

# %%
# Final Model
xgb_tuned = XGBClassifier(**xgb_cv_model.best_params_).fit(X_train, y_train)
y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.6271186440677966

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISBSLGB24-XGB73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MISBSLGB24-XGB73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.60      0.44      0.51        77
#  EGFR mutant       0.64      0.77      0.70       100
#
#     accuracy                           0.63       177
#    macro avg       0.62      0.61      0.60       177
# weighted avg       0.62      0.63      0.62       177
#
# precision 0.6416666666666667 accuracy 0.6271186440677966 recall 0.77

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(xgb_tuned)
report_results_quickly(xgb_tuned)
plot_results(xgb_tuned)
# plot_learning_curve(xgb_tuned)

# %%
# Final Model
lgbm_tuned = LGBMClassifier(**lgbm_cv_model.best_params_).fit(X_train, y_train)
y_pred = lgbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred) # 0.8766233766233766
# Out:
# 0.5875706214689266

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISBSLGB24-lgb73', Save_format = 'csv',Save_type = 'col')

# %%
data1 = pd.read_csv("Inter-test-for-auc-dca-MISBSLGB24-lgb73.csv")
external_test_pred=data1.y_pred
external_test_label=data1.label
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.53      0.47      0.50        77
#  EGFR mutant       0.62      0.68      0.65       100
#
#     accuracy                           0.59       177
#    macro avg       0.58      0.57      0.57       177
# weighted avg       0.58      0.59      0.58       177
#
# precision 0.6238532110091743 accuracy 0.5875706214689266 recall 0.68

# %%
# Visualization of Results --> Feature Importances
plot_feature_importances(lgbm_tuned)
# report_results_quickly(lgbm_tuned)
plot_results(lgbm_tuned)
# plot_learning_curve(lgbm_tuned)

# %%
# Comparison of tuned models
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, classification_report, confusion_matrix, plot_confusion_matrix
tuned_models = [('LogisticRegression', logreg_tuned),
                ('RF', rf_tuned),
                ('XGBoost', xgb_tuned),
                ('LightGBM', lgbm_tuned)]


evaluate_classification_model_holdout(tuned_models)
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# LogisticRegression: 0.604740
# RF: 0.609286
# XGBoost: 0.605779
# LightGBM: 0.573766
#
# ################ Train and test results for the model: ################
#
#                models  accuracy_train  accuracy_test
# 0  LogisticRegression           0.685          0.605
# 1                  RF           1.000          0.609
# 2             XGBoost           1.000          0.606
# 3            LightGBM           1.000          0.574

# %%
# Stack models
from mlxtend.classifier import StackingCVClassifier
stack_gen = StackingCVClassifier(classifiers=(logreg_tuned, rf_tuned, xgb_tuned, lgbm_tuned), meta_classifier=xgb_tuned)
stack_gen_model = stack_gen.fit(X_train, y_train)

evaluate_classification_model_holdout([('stack model', stack_gen_model)]) # 0.890
# Out:
# ################ Accuracy scores for test set for the models: ################
#
# stack model: 0.610779
#
# ################ Train and test results for the model: ################
#
#         models  accuracy_train  accuracy_test
# 0  stack model           1.000          0.611

# %%
# Function ot blend models
def blend_models_predict(X_test):
    return ((0.1 * logreg_tuned.predict(X_test)) +
            (0.2 * rf_tuned.predict(X_test)) +
            (0.2 * xgb_tuned.predict(X_test)) +
            (0.2 * lgbm_tuned.predict(X_test)) +
#             (0.1 * svm_tuned.predict(X_test)) +
            (0.3 * stack_gen_model.predict(X_test)))

# %%
accuracy_score(y_test, blend_models_predict(X_test).round())# 0.8701298701298701
# aucroc_score(y_test, blend_models_predict(X_test).round())# 0.8701298701298701
roc_auc_score(y_test, blend_models_predict(X_test).round())
# Out:
# 0.6122727272727273

# %%
Data = {'label':y_test, 'y_pred':y_pred}
Save_to_Csv(data = Data, file_name = 'Inter-test-for-auc-dca-MISBSLGB24-stack73', Save_format = 'csv',Save_type = 'col')

# %%
# Pickle Models --> Saving tuned models

# Create a folder named 'Models'
# save working directory
#
# cur_dir = os.getcwd()
# cur_dir
#
# # change working directory:
os.chdir("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISBSLGB24")
#
# # Save the models
for model in tuned_models:
    pickle.dump(model[1], open(str(model[0]) + ".pkl", 'wb'))

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
external_test=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/testZscore-MISBSLGB24.csv")
external_test_label = external_test.label
# print(external_test_label)
external_test=external_test.drop(columns=['label'])

# %%
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB10.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFEGB18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF17-42.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF18.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF19.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF5.csv",index=None)
# test1.to_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-RFERF11.csv",index=None)

external_test1=pd.read_csv("C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/egfr01_467/test1Zscore-MISBSLGB24.csv")
external_test_label1 = external_test1.label
# print(external_test_label)
external_test1=external_test1.drop(columns=['label'])

# %%
######XGB  测试集1
import numpy as np
# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISBSLGB24/XGBoost.pkl', 'rb'))
external_test_pred=xgb.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-xgb-MISBSLGB24-73.csv', external_test_pred, delimiter = ',')
auc = roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.25      0.19      0.22        26
#  EGFR mutant       0.71      0.77      0.74        66
#
#     accuracy                           0.61        92
#    macro avg       0.48      0.48      0.48        92
# weighted avg       0.58      0.61      0.59        92
#
# precision 0.7083333333333334 accuracy 0.6086956521739131 recall 0.7727272727272727

# %%
######XGB  测试集1
#############画图部分
# from sklearn.datasets import load_breast_cancer
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
import pylab as plt
import warnings;warnings.filterwarnings('ignore')
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for XbBoost')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
######XGB  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 5 21]
#  [15 51]]
# Normalized confusion matrix
# [[0.19 0.81]
#  [0.23 0.77]]

# %%
#####XGB  测试集2

import numpy as np

# # Load the model that we saved before
xgb = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISBSLGB24/XGBoost.pkl', 'rb'))
external_test_pred1=xgb.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-xgb-MISBSLGB24-73.csv', external_test_pred1, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.74      0.33      0.46        42
#  EGFR mutant       0.59      0.89      0.71        46
#
#     accuracy                           0.62        88
#    macro avg       0.67      0.61      0.59        88
# weighted avg       0.66      0.62      0.59        88
#
# precision 0.5942028985507246 accuracy 0.625 recall 0.8913043478260869

# %%
#####XGB  测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for XbBoost')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####XGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[14 28]
#  [ 5 41]]
# Normalized confusion matrix
# [[0.33 0.67]
#  [0.11 0.89]]

# %%
#####RF  测试集1
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISBSLGB24/RF.pkl', 'rb'))
external_test_pred=rft.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-RF-MISBSLGB24-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.25      0.35      0.29        26
#  EGFR mutant       0.70      0.59      0.64        66
#
#     accuracy                           0.52        92
#    macro avg       0.47      0.47      0.46        92
# weighted avg       0.57      0.52      0.54        92
#
# precision 0.6964285714285714 accuracy 0.5217391304347826 recall 0.5909090909090909

# %%
#####RF  测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####RF  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 9 17]
#  [27 39]]
# Normalized confusion matrix
# [[0.35 0.65]
#  [0.41 0.59]]

# %%
#####RF  测试集2
import numpy as np
# # Load the model that we saved before
rft = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISBSLGB24/RF.pkl', 'rb'))
external_test_pred1=rft.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-RF-MISBSLGB24-73.csv', external_test_pred1, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.59      0.62      0.60        42
#  EGFR mutant       0.64      0.61      0.62        46
#
#     accuracy                           0.61        88
#    macro avg       0.61      0.61      0.61        88
# weighted avg       0.61      0.61      0.61        88
#
# precision 0.6363636363636364 accuracy 0.6136363636363636 recall 0.6086956521739131

# %%
#####rf  测试集2

fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for RF')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####rf  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[26 16]
#  [18 28]]
# Normalized confusion matrix
# [[0.62 0.38]
#  [0.39 0.61]]

# %%
######LR 测试集1
import numpy as np
# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISBSLGB24/LogisticRegression.pkl', 'rb'))
external_test_pred=lrt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-lr-MISBSLGB24-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.08      0.08      0.08        26
#  EGFR mutant       0.65      0.67      0.66        66
#
#     accuracy                           0.50        92
#    macro avg       0.37      0.37      0.37        92
# weighted avg       0.49      0.50      0.49        92
#
# precision 0.6470588235294118 accuracy 0.5 recall 0.6666666666666666

# %%
######LR 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 2 24]
#  [22 44]]
# Normalized confusion matrix
# [[0.08 0.92]
#  [0.33 0.67]]

# %%
######LR 测试集2
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# # Load the model that we saved before
lrt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISBSLGB24/LogisticRegression.pkl', 'rb'))
external_test_pred1=lrt.predict(external_test1)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-lr-MISBSLGB24-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.50      0.02      0.05        42
#  EGFR mutant       0.52      0.98      0.68        46
#
#     accuracy                           0.52        88
#    macro avg       0.51      0.50      0.36        88
# weighted avg       0.51      0.52      0.38        88
#
# precision 0.5232558139534884 accuracy 0.5227272727272727 recall 0.9782608695652174

# %%
######LR 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LR')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LR  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 1 41]
#  [ 1 45]]
# Normalized confusion matrix
# [[0.02 0.98]
#  [0.02 0.98]]

# %%
##lgb 测试集1
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISBSLGB24/LightGBM.pkl', 'rb'))
external_test_pred=lgbt.predict(external_test)
np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test-for-auc-dca-lgb-MISBSLGB24-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label, external_test_pred)
precision = precision_score(external_test_label, external_test_pred, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label, external_test_pred)
recall = recall_score(external_test_label, external_test_pred, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label, external_test_pred, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.23      0.23      0.23        26
#  EGFR mutant       0.70      0.70      0.70        66
#
#     accuracy                           0.57        92
#    macro avg       0.46      0.46      0.46        92
# weighted avg       0.57      0.57      0.57        92
#
# precision 0.696969696969697 accuracy 0.5652173913043478 recall 0.696969696969697

# %%
##lgb 测试集1
fpr, tpr, threshold = metrics.roc_curve(external_test_label, external_test_pred)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group1 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
##lgb 测试集1
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label, external_test_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group1')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 6 20]
#  [20 46]]
# Normalized confusion matrix
# [[0.23 0.77]
#  [0.3  0.7 ]]

# %%
#lgb 测试集2
import numpy as np
# # Load the model that we saved before
lgbt = pickle.load(open('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/MISBSLGB24/LightGBM.pkl', 'rb'))
external_test_pred1=lgbt.predict(external_test1)

np.savetxt('C:/Users/zuoya/Desktop/Code/ipypb-fs/08_Catboost/Catboost/767cases/EGFR-01-FS/RFE-RF-GB/ex-test1-for-auc-dca-lgb-MISBSLGB24-73.csv', external_test_pred, delimiter = ',')
roc_auc_score(external_test_label1, external_test_pred1)
precision = precision_score(external_test_label1, external_test_pred1, pos_label=1, average='binary', sample_weight=None)
accuracy = accuracy_score(external_test_label1, external_test_pred1)
recall = recall_score(external_test_label1, external_test_pred1, average="binary", pos_label=1)
# f1_score = f1_score(external_test_label, external_test_pred)
# f1_score = f1_score(external_test_label, external_test_pred, average='weighted')
class_names = ['EGFR wild', 'EGFR mutant']
print(classification_report(external_test_label1, external_test_pred1, target_names=class_names))
print('precision',precision,'accuracy',accuracy,'recall',recall)
# Out:
#               precision    recall  f1-score   support
#
#    EGFR wild       0.65      0.40      0.50        42
#  EGFR mutant       0.60      0.80      0.69        46
#
#     accuracy                           0.61        88
#    macro avg       0.63      0.60      0.59        88
# weighted avg       0.62      0.61      0.60        88
#
# precision 0.5967741935483871 accuracy 0.6136363636363636 recall 0.8043478260869565

# %%
#lgb 测试集2
fpr, tpr, threshold = metrics.roc_curve(external_test_label1, external_test_pred1)
roc_auc = metrics.auc(fpr, tpr)
plt.figure(figsize=(6,6))
plt.title('External Test Group2 ROC for LightGBM')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
#####LGB  测试集2
# Compute confusion matrix
cnf_matrix = confusion_matrix(external_test_label1, external_test_pred1)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix for External Test Group2')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[17 25]
#  [ 9 37]]
# Normalized confusion matrix
# [[0.4 0.6]
#  [0.2 0.8]]

# %%
# # Visualization of Results --> Feature Importances
# plot_feature_importances(lgbt)
# # report_results_quickly(lgbm_tuned)
# plot_results(lgbt)
# # plot_learning_curve(lgbm_tuned)
